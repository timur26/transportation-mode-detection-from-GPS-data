# %%
import numpy as np
import pandas as pd
import json
import folium
import os
from datetime import datetime
from datetime import timedelta
import scipy.spatial
import geopy
from geopy.distance import distance
import pytz
from math import radians, cos, sin, asin, sqrt, pi
import random

import matplotlib.pyplot as plt

# %% [markdown]
# # Load GPS Data

# %%
with open('./TPF/tao&marced/response_marced_260319_fribourg.json') as f:
    data = json.load(f)

user_gps_df = pd.DataFrame.from_dict(data['userLocationTrace'])

# %%
timezone = pytz.timezone("Europe/Zurich")

# %%
def convert_timestamp(ts):
    if len(ts) > 20:
        return timezone.localize(datetime.strptime(ts, "%Y-%m-%dT%H:%M:%S.%fZ")).timestamp()
    else:
        return timezone.localize(datetime.strptime(ts, "%Y-%m-%dT%H:%M:%SZ")).timestamp()

# %%
user_gps_df = user_gps_df.astype({'altitude': float, 
                                  'latitude': float,
                                  'longitude': float,
                                  'speed': float, 
                                  'accuracy': float, 
                                  'altitudeAccuracy': float,
                                  'heading': float})

user_gps_df['timestamp_unix'] = user_gps_df.apply(lambda x: convert_timestamp(x.timestamp), axis=1)

# Remove innacurate readings
user_gps_df = user_gps_df[(user_gps_df.accuracy<30) & (user_gps_df.altitudeAccuracy<30)]

user_gps_df = user_gps_df.sort_values('timestamp_unix').reset_index(drop=True)
user_gps_df['id'] = range(user_gps_df.shape[0])

# %% [markdown]
# # Public Transport Network

# %% [markdown]
# Load TPC stops data

# %%
tpc_stops = pd.read_csv('./TPF/Planned/stops_extend.txt')
tpc_stops.head()
# Out:
#      stop_id  stop_code                         stop_name  stop_desc  \
# 0  850488110        NaN  Fribourg/Freiburg, gare routière        NaN
# 1  858916300        NaN         Fribourg, Stade-Patinoire        NaN
# 2  850023801        NaN                     Bulle, Verdel        NaN
# 3  850343501        NaN                          Riaz, CO        NaN
# 4  850371801        NaN               Avry-sur-Matran, CO        NaN
#
#     stop_lat  stop_lon  zone_id  stop_url  location_type parent_station  \
# 0  46.803239  7.150122      NaN       NaN              0   place_FRIgar
# 1  46.817895  7.154564      NaN       NaN              0            NaN
# 2  46.624838  7.065969      NaN       NaN              0            NaN
# 3  46.645104  7.065568      NaN       NaN              0            NaN
# 4  46.786202  7.077425      NaN       NaN              0            NaN
#
#   stp_correspondances mp3_filename  stop_area stop_shortname  thoreb_no
# 0                 NaN     2021.mp3    8504881         FRIgar    15000.0
# 1                 NaN     1084.mp3    8589163            Sta    14999.0
# 2                 NaN     4152.mp3    8500238         BULrtv    17903.0
# 3                 NaN     4159.mp3    8503435         RIA-CO    17935.0
# 4                 NaN     4083.mp3    8503718         AVSmco    16590.0

# %% [markdown]
# After investigation, decided to use SBB gtfs data instead as there were missing data points in TPC dataset

# %%
def read_sbb(filename, path):
    with open(path + filename) as f:
        raw = f.readlines()
    
    col_names = raw[0][1:-1].split(',')
    data = [l[:-1].replace('","', ';').replace('"', '').split(';') for l in raw[1:]]
    
    df = pd.DataFrame(data, columns=col_names)
    
    return df

# %%
path = 'gtfsfp20192019-03-20/'

# %%
stops_df = read_sbb('stops.txt', path)
stop_times_df = read_sbb('stop_times.txt', path)
routes_df = read_sbb('routes.txt', path)
trips_df = read_sbb('trips.txt', path)

# %% [markdown]
# Initial approach to include all stops within 10km radius of Fribourg but decided to stick with those stops the TPF network covers instead for simplicity as the initial dataset was only within this network.

# %%
def haversine(lon1, lat1, lon2, lat2):
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers
    return c * r

# %%
# hardcoded Fribourg gare coordinates
stops_df['from_FB'] = np.vectorize(haversine)(7.161817, 46.806477, 
                                              stops_df.stop_lon.astype('float64'), 
                                              stops_df.stop_lat.astype('float64'))

# %%
# Filter to TPF
routes_df = routes_df.astype({'agency_id': str})
routes_df = routes_df[routes_df.agency_id=='834'][['route_id', 'route_desc', 'route_short_name']]

fribourg_sbb = pd.merge(trips_df, routes_df, on='route_id')
fribourg_sbb = pd.merge(stop_times_df, fribourg_sbb, on='trip_id')
fribourg_sbb = pd.merge(fribourg_sbb, stops_df, on='stop_id')
fribourg_sbb = fribourg_sbb.drop(columns=['pickup_type', 'drop_off_type','location_type', 'parent_station'])
fribourg_sbb = fribourg_sbb.astype({'stop_sequence': int})
fribourg_sbb.head()
# Out:
#                   trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0  1.TA.6-260-A-j19-1.1.H     06:59:00       06:59:00  8504938              1
# 1  2.TA.6-260-A-j19-1.1.H     07:31:00       07:31:00  8504938              1
# 2  4.TA.6-260-A-j19-1.1.H     08:31:00       08:31:00  8504938              1
# 3  6.TA.6-260-A-j19-1.1.H     09:31:00       09:31:00  8504938              1
# 4  7.TA.6-260-A-j19-1.1.H     11:08:00       11:08:00  8504938              1
#
#         route_id service_id      trip_headsign trip_short_name direction_id  \
# 0  6-260-A-j19-1   TA+b002a  Boltigen, Bahnhof           26003            0
# 1  6-260-A-j19-1   TA+b08x0  Boltigen, Bahnhof           26005            0
# 2  6-260-A-j19-1   TA+b06uz  Boltigen, Bahnhof           26009            0
# 3  6-260-A-j19-1   TA+b0cnb  Boltigen, Bahnhof           26013            0
# 4  6-260-A-j19-1   TA+b0023  Boltigen, Bahnhof           26017            0
#
#   route_desc route_short_name          stop_name          stop_lat  \
# 0        Bus              260  Jaun, Kappelboden  46.6102353307346
# 1        Bus              260  Jaun, Kappelboden  46.6102353307346
# 2        Bus              260  Jaun, Kappelboden  46.6102353307346
# 3        Bus              260  Jaun, Kappelboden  46.6102353307346
# 4        Bus              260  Jaun, Kappelboden  46.6102353307346
#
#            stop_lon    from_FB
# 0  7.28713358579193  23.821399
# 1  7.28713358579193  23.821399
# 2  7.28713358579193  23.821399
# 3  7.28713358579193  23.821399
# 4  7.28713358579193  23.821399

# %%
fribourg_stops = fribourg_sbb[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']].drop_duplicates().reset_index(drop=True)

# %%
def get_closest_stop(lat, lon, id_, stops=fribourg_stops):
    temp = stops.copy()
    temp = temp.astype({'stop_lat': float, 'stop_lon': float})
    temp['diff'] = abs(temp['stop_lat'] - lat) + abs(temp['stop_lon'] - lon)
    temp = temp.sort_values('diff')
    return [id_, temp.iloc[0].stop_name, temp.iloc[0].stop_lat, temp.iloc[0].stop_lon]

# %%
user_gps_to_stops = pd.DataFrame(list(user_gps_df.apply(lambda x: get_closest_stop(x.latitude, x.longitude, x.id), 
                                                        axis=1)), 
                                 columns=['id', 'closest_stop_name', 'closest_stop_lat', 'closest_stop_lon'])

user_gps_df = pd.merge(user_gps_df, user_gps_to_stops, on='id')

# %%
def calc_dist(lat_s, long_s, lat_f, long_f, alt_s=None, alt_f=None):
    dist_2d = distance((lat_s, long_s), (lat_f, long_f)).m
    if alt_f is None or alt_s is None:
        return dist_2d
    else:
        dist_3d = (dist_2d**2 + (alt_s-alt_f)**2)**0.5
        return dist_3d

# %%
user_gps_df['closest_stop_dist'] = user_gps_df.apply(lambda x: calc_dist(x.latitude, x.longitude, x.closest_stop_lat, x.closest_stop_lon), axis=1)

# %% [markdown]
# ## GPS to Edges

# %%
user_gps_df = user_gps_df.drop(columns={'uuid', 'id', 'user'}).drop_duplicates()
user_gps_df = user_gps_df.sort_values('timestamp_unix').reset_index(drop=True)

# %%
def points_to_edges(df):
    
    df = df.reset_index(drop=True)
    df['temp_id'] = range(0, df.shape[0])
    df['temp_id'] = df.temp_id - 1 

    temp_df = df[df.temp_id>=0]

    edge_df = pd.merge(df, temp_df, right_on='temp_id', left_index=True, how='inner', suffixes=('_s', '_f'))
    edge_df = edge_df.drop(columns={'temp_id', 'temp_id_s'})
    edge_df = edge_df.reset_index(drop=True)

    edge_df['duration'] = edge_df.timestamp_unix_f - edge_df.timestamp_unix_s

    edge_df['distance'] = edge_df.apply(lambda x: calc_dist(x.latitude_s, x.longitude_s, x.latitude_f, 
                                                            x.longitude_f, x.altitude_s, x.altitude_f), 
                                        axis=1)

    edge_df['meters_per_s'] = edge_df['distance'] / edge_df['duration']

    edge_df = edge_df.drop(columns=['temp_id_f'])

    edge_df['index_s'] = range(0, edge_df.shape[0])
    edge_df['index_f'] = edge_df.index_s + 1
    
    return edge_df

# %%
edge_df = points_to_edges(user_gps_df)

# %% [markdown]
# ## Split walk/non-walk segments

# %%
def generate_segment_ids(df, distance_thershold=50, duration_threshold=60):
    # define walk edges as ones where speed is below threshold
    df['is_walk'] = False
    df.loc[(df.meters_per_s<2.79)&(df.speed_s<2.79)&(df.speed_f<2.79), 'is_walk'] = True
    
    # obtain certain walk and non walk segments
    walk_segments, non_walk_segments = get_segments(df, distance_thershold, duration_threshold)
    
    df['is_walk'] = None
    df.loc[[x for y in walk_segments for x in y], 'is_walk'] = True
    df.loc[[x for y in non_walk_segments for x in y], 'is_walk'] = False
    
    # for uncertain edges, merge them into preceding segment
    uncertain_points = []
    last_certain_point = df[~df.is_walk.isnull()].is_walk.iloc[0]
    
    for i, r in df.iterrows():
        if r.is_walk is None:
            uncertain_points.append(i)
            if i == df.index.max():
                df.loc[uncertain_points, 'is_walk'] = last_certain_point
        else:
            if len(uncertain_points) == 0:
                last_certain_point = r.is_walk
            else:
                df.loc[uncertain_points, 'is_walk'] = last_certain_point
                uncertain_points = []
    
    walk_segments, non_walk_segments = get_segments(df, distance_thershold, duration_threshold)
    
    return df, walk_segments, non_walk_segments

# %%
def get_segments(df, distance_thershold=50, duration_threshold=60):
    distance, duration = 0, 0
    walk_segments, non_walk_segments = [], []
    w_seg, nw_seg = [], []
    max_i = df.index.max()
    
    for i, l in df.iterrows():
        if l.is_walk:
            duration += l.duration
            w_seg.append(i)
            
            # if previous non walk segment exceeds distance threshold, record it
            if distance >= distance_thershold:
                non_walk_segments.append(nw_seg)

            distance = 0
            nw_seg = []
        else:
            distance += l.distance
            nw_seg.append(i)
            
            # if previous walk segment exceeds duration threshold, record it
            if duration >= duration_threshold:
                walk_segments.append(w_seg)
            duration = 0
            w_seg = []
            
    # verify if last segment meets its respective threshold
    if distance >= distance_thershold:
        non_walk_segments.append(nw_seg)
    if duration >= duration_threshold:
        walk_segments.append(w_seg)
                
    return walk_segments, non_walk_segments

# %%
edge_df, walk_segments, non_walk_segments = generate_segment_ids(edge_df)

# %%
for ws in walk_segments:
    print('-'*100 + 'SEGMENT')
    for p in ws:
        print('EDGE')
        print('Start Time: ' + edge_df.loc[p].timestamp_s)
        print('Start Point: ' + str(edge_df.loc[p].index_s) + ' ' + edge_df.loc[p].closest_stop_name_s + ', '
              + 'Distance from stop:' +str(edge_df.loc[p].closest_stop_dist_s))
        print('Speed: '+str(edge_df.loc[p].meters_per_s))
        print('Duration: ' +str(edge_df.loc[p].duration))
        print('Distance: ' +str(edge_df.loc[p].distance))
        print('End Time: ' + edge_df.loc[p].timestamp_f)
        print('Finish Point: ' + str(edge_df.loc[p].index_f) + ' ' + edge_df.loc[p].closest_stop_name_f + ', '
              + 'Distance from stop:' +str(edge_df.loc[p].closest_stop_dist_f)+ ' \n')
# Out:
# ----------------------------------------------------------------------------------------------------SEGMENT
# EDGE
# Start Time: 2019-03-26T08:57:58Z
# Start Point: 8 Villars-sur-Glâne, Moncor, Distance from stop:160.81077739256236
# Speed: 0.9195393188332593
# Duration: 14.0
# Distance: 12.87355046366563
# End Time: 2019-03-26T08:58:12Z
# Finish Point: 9 Villars-sur-Glâne, Moncor, Distance from stop:161.89463159180514
#
# EDGE
# Start Time: 2019-03-26T08:58:12Z
# Start Point: 9 Villars-sur-Glâne, Moncor, Distance from stop:161.89463159180514
# Speed: 0.47517947495153734
# Duration: 798.239000082016
# Distance: 379.3067889448125
# End Time: 2019-03-26T09:11:30.239000Z
# Finish Point: 10 Villars-sur-Glâne, Rte Soleil, Distance from stop:130.46514260185205
#
# EDGE
# Start Time: 2019-03-26T09:11:30.239000Z
# Start Point: 10 Villars-sur-Glâne, Rte Soleil, Distance from stop:130.46514260185205
# Speed: 1.0746626911491606
# Duration: 11.855999946594238
# Distance: 12.741200808871268
# End Time: 2019-03-26T09:11:42.095000Z
# Finish Point: 11 Villars-sur-Glâne, Rte Soleil, Distance from stop:136.31326384359934
#
# EDGE
# Start Time: 2019-03-26T09:11:42.095000Z
# Start Point: 11 Villars-sur-Glâne, Rte Soleil, Distance from stop:136.31326384359934
# Speed: 1.293797351074099
# Duration: 7.9040000438690186
# Distance: 10.2261743196473
# End Time: 2019-03-26T09:11:49.999000Z
# Finish Point: 12 Villars-sur-Glâne, Rte Soleil, Distance from stop:141.21835608212226
#
# EDGE
# Start Time: 2019-03-26T09:11:49.999000Z
# Start Point: 12 Villars-sur-Glâne, Rte Soleil, Distance from stop:141.21835608212226
# Speed: 1.6419785870802854
# Duration: 7.0
# Distance: 11.493850109561999
# End Time: 2019-03-26T09:11:56.999000Z
# Finish Point: 13 Villars-sur-Glâne, Rte Soleil, Distance from stop:147.68255687334172
#
# EDGE
# Start Time: 2019-03-26T09:11:56.999000Z
# Start Point: 13 Villars-sur-Glâne, Rte Soleil, Distance from stop:147.68255687334172
# Speed: 1.5347743673942893
# Duration: 7.0
# Distance: 10.743420571760025
# End Time: 2019-03-26T09:12:03.999000Z
# Finish Point: 14 Villars-sur-Glâne, Rte Soleil, Distance from stop:152.57522218666682
#
# EDGE
# Start Time: 2019-03-26T09:12:03.999000Z
# Start Point: 14 Villars-sur-Glâne, Rte Soleil, Distance from stop:152.57522218666682
# Speed: 1.3438152676221071
# Duration: 8.0
# Distance: 10.750522140976857
# End Time: 2019-03-26T09:12:11.999000Z
# Finish Point: 15 Villars-sur-Glâne, Rte Soleil, Distance from stop:157.82748044940377
#
# EDGE
# Start Time: 2019-03-26T09:12:11.999000Z
# Start Point: 15 Villars-sur-Glâne, Rte Soleil, Distance from stop:157.82748044940377
# Speed: 1.368308358571633
# Duration: 8.0
# Distance: 10.946466868573063
# End Time: 2019-03-26T09:12:19.999000Z
# Finish Point: 16 Villars-sur-Glâne, Rte Soleil, Distance from stop:163.00800804064284
#
# EDGE
# Start Time: 2019-03-26T09:12:19.999000Z
# Start Point: 16 Villars-sur-Glâne, Rte Soleil, Distance from stop:163.00800804064284
# Speed: 1.19858268805188
# Duration: 9.0
# Distance: 10.78724419246692
# End Time: 2019-03-26T09:12:28.999000Z
# Finish Point: 17 Villars-sur-Glâne, Rte Soleil, Distance from stop:173.64296426280234
#
# EDGE
# Start Time: 2019-03-26T09:12:28.999000Z
# Start Point: 17 Villars-sur-Glâne, Rte Soleil, Distance from stop:173.64296426280234
# Speed: 1.8508142659218356
# Duration: 6.0
# Distance: 11.104885595531014
# End Time: 2019-03-26T09:12:34.999000Z
# Finish Point: 18 Villars-sur-Glâne, Rte Soleil, Distance from stop:183.7799413081448
#
# EDGE
# Start Time: 2019-03-26T09:12:34.999000Z
# Start Point: 18 Villars-sur-Glâne, Rte Soleil, Distance from stop:183.7799413081448
# Speed: 1.5283591798740228
# Duration: 7.0
# Distance: 10.69851425911816
# End Time: 2019-03-26T09:12:41.999000Z
# Finish Point: 19 Villars-sur-Glâne, Rte Soleil, Distance from stop:193.51770630265588
#
# EDGE
# Start Time: 2019-03-26T09:12:41.999000Z
# Start Point: 19 Villars-sur-Glâne, Rte Soleil, Distance from stop:193.51770630265588
# Speed: 1.4537336992391023
# Duration: 7.0
# Distance: 10.176135894673717
# End Time: 2019-03-26T09:12:48.999000Z
# Finish Point: 20 Villars-sur-Glâne, Rte Soleil, Distance from stop:201.8545493464737
#
# EDGE
# Start Time: 2019-03-26T09:12:48.999000Z
# Start Point: 20 Villars-sur-Glâne, Rte Soleil, Distance from stop:201.8545493464737
# Speed: 1.960185007699055
# Duration: 6.0
# Distance: 11.76111004619433
# End Time: 2019-03-26T09:12:54.999000Z
# Finish Point: 21 Villars-sur-Glâne, Rte Soleil, Distance from stop:212.3084439108529
#
# EDGE
# Start Time: 2019-03-26T09:12:54.999000Z
# Start Point: 21 Villars-sur-Glâne, Rte Soleil, Distance from stop:212.3084439108529
# Speed: 1.4964792927637802
# Duration: 7.0
# Distance: 10.475355049346462
# End Time: 2019-03-26T09:13:01.999000Z
# Finish Point: 22 Villars-sur-Glâne, Rte Soleil, Distance from stop:221.71056594162363
#
# EDGE
# Start Time: 2019-03-26T09:13:01.999000Z
# Start Point: 22 Villars-sur-Glâne, Rte Soleil, Distance from stop:221.71056594162363
# Speed: 1.3999954595085007
# Duration: 8.0
# Distance: 11.199963676068005
# End Time: 2019-03-26T09:13:09.999000Z
# Finish Point: 23 Villars-sur-Glâne, Rte Soleil, Distance from stop:232.7937661890414
#
# EDGE
# Start Time: 2019-03-26T09:13:09.999000Z
# Start Point: 23 Villars-sur-Glâne, Rte Soleil, Distance from stop:232.7937661890414
# Speed: 1.6722564926478736
# Duration: 6.0
# Distance: 10.033538955887241
# End Time: 2019-03-26T09:13:15.999000Z
# Finish Point: 24 Villars-sur-Glâne, Rte Soleil, Distance from stop:242.3840650688548
#
# EDGE
# Start Time: 2019-03-26T09:13:15.999000Z
# Start Point: 24 Villars-sur-Glâne, Rte Soleil, Distance from stop:242.3840650688548
# Speed: 1.0537099859769727
# Duration: 10.0
# Distance: 10.537099859769727
# End Time: 2019-03-26T09:13:25.999000Z
# Finish Point: 25 Villars-sur-Glâne,Rte Préalpes, Distance from stop:212.6450098504411
#
# EDGE
# Start Time: 2019-03-26T09:13:25.999000Z
# Start Point: 25 Villars-sur-Glâne,Rte Préalpes, Distance from stop:212.6450098504411
# Speed: 0.09006959264137498
# Duration: 116.0
# Distance: 10.448072746399498
# End Time: 2019-03-26T09:15:21.999000Z
# Finish Point: 26 Villars-sur-Glâne,Rte Préalpes, Distance from stop:213.36033192110497
#
# EDGE
# Start Time: 2019-03-26T09:15:21.999000Z
# Start Point: 26 Villars-sur-Glâne,Rte Préalpes, Distance from stop:213.36033192110497
# Speed: 0.03228288380177417
# Duration: 869.941999912262
# Distance: 28.084236497450593
# End Time: 2019-03-26T09:29:51.941000Z
# Finish Point: 27 Villars-sur-Glâne, Rte Soleil, Distance from stop:220.82461715018857
#
# EDGE
# Start Time: 2019-03-26T09:29:51.941000Z
# Start Point: 27 Villars-sur-Glâne, Rte Soleil, Distance from stop:220.82461715018857
# Speed: 1.4200243394477858
# Duration: 7.1600000858306885
# Distance: 10.167374392327813
# End Time: 2019-03-26T09:29:59.101000Z
# Finish Point: 28 Villars-sur-Glâne, Rte Soleil, Distance from stop:214.3230292347273
#
# EDGE
# Start Time: 2019-03-26T09:29:59.101000Z
# Start Point: 28 Villars-sur-Glâne, Rte Soleil, Distance from stop:214.3230292347273
# Speed: 1.0948894501957431
# Duration: 10.006999969482422
# Distance: 10.956558694695428
# End Time: 2019-03-26T09:30:09.108000Z
# Finish Point: 29 Villars-sur-Glâne, Rte Soleil, Distance from stop:203.75414619116887
#
# EDGE
# Start Time: 2019-03-26T09:30:09.108000Z
# Start Point: 29 Villars-sur-Glâne, Rte Soleil, Distance from stop:203.75414619116887
# Speed: 1.6575698508512344
# Duration: 7.034999847412109
# Distance: 11.661003647813347
# End Time: 2019-03-26T09:30:16.143000Z
# Finish Point: 30 Villars-sur-Glâne, Rte Soleil, Distance from stop:193.05532416209175
#
# EDGE
# Start Time: 2019-03-26T09:30:16.143000Z
# Start Point: 30 Villars-sur-Glâne, Rte Soleil, Distance from stop:193.05532416209175
# Speed: 1.3446505248399616
# Duration: 7.990000009536743
# Distance: 10.74375770629488
# End Time: 2019-03-26T09:30:24.133000Z
# Finish Point: 31 Villars-sur-Glâne, Rte Soleil, Distance from stop:182.50017343521748
#
# EDGE
# Start Time: 2019-03-26T09:30:24.133000Z
# Start Point: 31 Villars-sur-Glâne, Rte Soleil, Distance from stop:182.50017343521748
# Speed: 1.2765909773926098
# Duration: 9.005000114440918
# Distance: 11.495701897514694
# End Time: 2019-03-26T09:30:33.138000Z
# Finish Point: 32 Villars-sur-Glâne, Rte Soleil, Distance from stop:173.3836651916603
#
# EDGE
# Start Time: 2019-03-26T09:30:33.138000Z
# Start Point: 32 Villars-sur-Glâne, Rte Soleil, Distance from stop:173.3836651916603
# Speed: 1.1231843870097082
# Duration: 8.996000051498413
# Distance: 10.104166803381549
# End Time: 2019-03-26T09:30:42.134000Z
# Finish Point: 33 Villars-sur-Glâne, Rte Soleil, Distance from stop:174.39062700540111
#
# EDGE
# Start Time: 2019-03-26T09:30:42.134000Z
# Start Point: 33 Villars-sur-Glâne, Rte Soleil, Distance from stop:174.39062700540111
# Speed: 1.0033221758801916
# Duration: 10.000999927520752
# Distance: 10.034225008257758
# End Time: 2019-03-26T09:30:52.135000Z
# Finish Point: 34 Villars-sur-Glâne, Rte Soleil, Distance from stop:183.93321806223662
#
# EDGE
# Start Time: 2019-03-26T09:30:52.135000Z
# Start Point: 34 Villars-sur-Glâne, Rte Soleil, Distance from stop:183.93321806223662
# Speed: 0.9847090483729782
# Duration: 11.003000020980835
# Distance: 10.834753679907898
# End Time: 2019-03-26T09:31:03.138000Z
# Finish Point: 35 Villars-sur-Glâne, Rte Soleil, Distance from stop:193.35216514953476
#
# EDGE
# Start Time: 2019-03-26T09:31:03.138000Z
# Start Point: 35 Villars-sur-Glâne, Rte Soleil, Distance from stop:193.35216514953476
# Speed: 1.50032321984603
# Duration: 6.997999906539917
# Distance: 10.499261752262184
# End Time: 2019-03-26T09:31:10.136000Z
# Finish Point: 36 Villars-sur-Glâne, Rte Soleil, Distance from stop:202.15112953963003
#
# EDGE
# Start Time: 2019-03-26T09:31:10.136000Z
# Start Point: 36 Villars-sur-Glâne, Rte Soleil, Distance from stop:202.15112953963003
# Speed: 1.5130067459929764
# Duration: 7.001000165939331
# Distance: 10.592560479764154
# End Time: 2019-03-26T09:31:17.137000Z
# Finish Point: 37 Villars-sur-Glâne, Rte Soleil, Distance from stop:212.56671233085822
#
# EDGE
# Start Time: 2019-03-26T09:31:17.137000Z
# Start Point: 37 Villars-sur-Glâne, Rte Soleil, Distance from stop:212.56671233085822
# Speed: 1.7898106378863101
# Duration: 7.004999876022339
# Distance: 12.537623296497065
# End Time: 2019-03-26T09:31:24.142000Z
# Finish Point: 38 Villars-sur-Glâne, Rte Soleil, Distance from stop:224.8960964255931
#
# EDGE
# Start Time: 2019-03-26T09:31:24.142000Z
# Start Point: 38 Villars-sur-Glâne, Rte Soleil, Distance from stop:224.8960964255931
# Speed: 2.153929114864939
# Duration: 5.002000093460083
# Distance: 10.773953633860819
# End Time: 2019-03-26T09:31:29.144000Z
# Finish Point: 39 Villars-sur-Glâne, Rte Soleil, Distance from stop:235.37412546487252
#
# EDGE
# Start Time: 2019-03-26T09:31:29.144000Z
# Start Point: 39 Villars-sur-Glâne, Rte Soleil, Distance from stop:235.37412546487252
# Speed: 1.2176387691382509
# Duration: 8.99399995803833
# Distance: 10.951443038535272
# End Time: 2019-03-26T09:31:38.138000Z
# Finish Point: 40 Villars-sur-Glâne,Rte Préalpes, Distance from stop:213.243517316991
#
# EDGE
# Start Time: 2019-03-26T09:31:38.138000Z
# Start Point: 40 Villars-sur-Glâne,Rte Préalpes, Distance from stop:213.243517316991
# Speed: 1.44600135890578
# Duration: 7.002000093460083
# Distance: 10.124901650201679
# End Time: 2019-03-26T09:31:45.140000Z
# Finish Point: 41 Villars-sur-Glâne,Rte Préalpes, Distance from stop:204.68922200483638
#
# EDGE
# Start Time: 2019-03-26T09:31:45.140000Z
# Start Point: 41 Villars-sur-Glâne,Rte Préalpes, Distance from stop:204.68922200483638
# Speed: 2.054957935171544
# Duration: 5.998999834060669
# Distance: 12.32769231209575
# End Time: 2019-03-26T09:31:51.139000Z
# Finish Point: 42 Villars-sur-Glâne,Rte Préalpes, Distance from stop:193.4473417920644
#
# EDGE
# Start Time: 2019-03-26T09:31:51.139000Z
# Start Point: 42 Villars-sur-Glâne,Rte Préalpes, Distance from stop:193.4473417920644
# Speed: 2.030165530491983
# Duration: 4.992000102996826
# Distance: 10.134586537316585
# End Time: 2019-03-26T09:31:56.131000Z
# Finish Point: 43 Villars-sur-Glâne,Rte Préalpes, Distance from stop:184.87869805234087
#
# EDGE
# Start Time: 2019-03-26T09:31:56.131000Z
# Start Point: 43 Villars-sur-Glâne,Rte Préalpes, Distance from stop:184.87869805234087
# Speed: 1.6984336033027814
# Duration: 6.003000020980835
# Distance: 10.195696956261152
# End Time: 2019-03-26T09:32:02.134000Z
# Finish Point: 44 Villars-sur-Glâne,Rte Préalpes, Distance from stop:175.21276452481627
#
# EDGE
# Start Time: 2019-03-26T09:32:02.134000Z
# Start Point: 44 Villars-sur-Glâne,Rte Préalpes, Distance from stop:175.21276452481627
# Speed: 1.807361190479832
# Duration: 7.0
# Distance: 12.651528333358824
# End Time: 2019-03-26T09:32:09.134000Z
# Finish Point: 45 Villars-sur-Glâne,Rte Préalpes, Distance from stop:163.31493788232163
#
# EDGE
# Start Time: 2019-03-26T09:32:09.134000Z
# Start Point: 45 Villars-sur-Glâne,Rte Préalpes, Distance from stop:163.31493788232163
# Speed: 0.6548111346455968
# Duration: 16.00600004196167
# Distance: 10.480907048614391
# End Time: 2019-03-26T09:32:25.140000Z
# Finish Point: 46 Villars-sur-Glâne,Rte Préalpes, Distance from stop:154.56837624884787
#
# EDGE
# Start Time: 2019-03-26T09:32:25.140000Z
# Start Point: 46 Villars-sur-Glâne,Rte Préalpes, Distance from stop:154.56837624884787
# Speed: 0.8007575954692463
# Duration: 15.990999937057495
# Distance: 12.804914658747029
# End Time: 2019-03-26T09:32:41.131000Z
# Finish Point: 47 Villars-sur-Glâne,Rte Préalpes, Distance from stop:164.87378761349183
#
# EDGE
# Start Time: 2019-03-26T09:32:41.131000Z
# Start Point: 47 Villars-sur-Glâne,Rte Préalpes, Distance from stop:164.87378761349183
# Speed: 1.9044363250461633
# Duration: 5.996000051498413
# Distance: 11.419000303052243
# End Time: 2019-03-26T09:32:47.127000Z
# Finish Point: 48 Villars-sur-Glâne,Rte Préalpes, Distance from stop:171.44990080674995
#
# EDGE
# Start Time: 2019-03-26T09:32:47.127000Z
# Start Point: 48 Villars-sur-Glâne,Rte Préalpes, Distance from stop:171.44990080674995
# Speed: 1.5113257838274508
# Duration: 7.003999948501587
# Distance: 10.585325712096585
# End Time: 2019-03-26T09:32:54.131000Z
# Finish Point: 49 Villars-sur-Glâne,Rte Préalpes, Distance from stop:180.16690560425636
#
# EDGE
# Start Time: 2019-03-26T09:32:54.131000Z
# Start Point: 49 Villars-sur-Glâne,Rte Préalpes, Distance from stop:180.16690560425636
# Speed: 0.6850547086308139
# Duration: 15.001999855041504
# Distance: 10.27719063957497
# End Time: 2019-03-26T09:33:09.133000Z
# Finish Point: 50 Villars-sur-Glâne,Rte Préalpes, Distance from stop:189.381775826332
#
# EDGE
# Start Time: 2019-03-26T09:33:09.133000Z
# Start Point: 50 Villars-sur-Glâne,Rte Préalpes, Distance from stop:189.381775826332
# Speed: 0.18723523915984763
# Duration: 56.97699999809265
# Distance: 10.668102221253516
# End Time: 2019-03-26T09:34:06.110000Z
# Finish Point: 51 Villars-sur-Glâne,Rte Préalpes, Distance from stop:198.45714297526763
#
# EDGE
# Start Time: 2019-03-26T09:34:06.110000Z
# Start Point: 51 Villars-sur-Glâne,Rte Préalpes, Distance from stop:198.45714297526763
# Speed: 1.5275598626495313
# Duration: 7.022000074386597
# Distance: 10.726525469154987
# End Time: 2019-03-26T09:34:13.132000Z
# Finish Point: 52 Villars-sur-Glâne,Rte Préalpes, Distance from stop:208.81943155938467
#
# EDGE
# Start Time: 2019-03-26T09:34:13.132000Z
# Start Point: 52 Villars-sur-Glâne,Rte Préalpes, Distance from stop:208.81943155938467
# Speed: 1.6075252882210869
# Duration: 7.002000093460083
# Distance: 11.255892218363497
# End Time: 2019-03-26T09:34:20.134000Z
# Finish Point: 53 Villars-sur-Glâne,Rte Préalpes, Distance from stop:218.14676098667397
#
# EDGE
# Start Time: 2019-03-26T09:34:20.134000Z
# Start Point: 53 Villars-sur-Glâne,Rte Préalpes, Distance from stop:218.14676098667397
# Speed: 0.5332865432297427
# Duration: 19.001999855041504
# Distance: 10.133510817147155
# End Time: 2019-03-26T09:34:39.136000Z
# Finish Point: 54 Villars-sur-Glâne,Rte Préalpes, Distance from stop:212.45371001555674
#
# EDGE
# Start Time: 2019-03-26T09:34:39.136000Z
# Start Point: 54 Villars-sur-Glâne,Rte Préalpes, Distance from stop:212.45371001555674
# Speed: 1.805193983724641
# Duration: 5.999000072479248
# Distance: 10.829358839203223
# End Time: 2019-03-26T09:34:45.135000Z
# Finish Point: 55 Villars-sur-Glâne,Rte Préalpes, Distance from stop:203.41842215134565
#
# EDGE
# Start Time: 2019-03-26T09:34:45.135000Z
# Start Point: 55 Villars-sur-Glâne,Rte Préalpes, Distance from stop:203.41842215134565
# Speed: 1.2519741013203967
# Duration: 8.002000093460083
# Distance: 10.018296875775418
# End Time: 2019-03-26T09:34:53.137000Z
# Finish Point: 56 Villars-sur-Glâne,Rte Préalpes, Distance from stop:194.52143170884023
#
# EDGE
# Start Time: 2019-03-26T09:34:53.137000Z
# Start Point: 56 Villars-sur-Glâne,Rte Préalpes, Distance from stop:194.52143170884023
# Speed: 1.3760158201106765
# Duration: 7.990999937057495
# Distance: 10.995742331894533
# End Time: 2019-03-26T09:35:01.128000Z
# Finish Point: 57 Villars-sur-Glâne,Rte Préalpes, Distance from stop:184.29645406933636
#
# EDGE
# Start Time: 2019-03-26T09:35:01.128000Z
# Start Point: 57 Villars-sur-Glâne,Rte Préalpes, Distance from stop:184.29645406933636
# Speed: 1.7303921566420013
# Duration: 6.013999938964844
# Distance: 10.40657832443024
# End Time: 2019-03-26T09:35:07.142000Z
# Finish Point: 58 Villars-sur-Glâne,Rte Préalpes, Distance from stop:175.957460324884
#
# EDGE
# Start Time: 2019-03-26T09:35:07.142000Z
# Start Point: 58 Villars-sur-Glâne,Rte Préalpes, Distance from stop:175.957460324884
# Speed: 1.4761528113801141
# Duration: 7.0
# Distance: 10.333069679660799
# End Time: 2019-03-26T09:35:14.142000Z
# Finish Point: 59 Villars-sur-Glâne,Rte Préalpes, Distance from stop:166.80934889362882
#
# EDGE
# Start Time: 2019-03-26T09:35:14.142000Z
# Start Point: 59 Villars-sur-Glâne,Rte Préalpes, Distance from stop:166.80934889362882
# Speed: 1.435340748746429
# Duration: 7.999000072479248
# Distance: 11.481290753255102
# End Time: 2019-03-26T09:35:22.141000Z
# Finish Point: 60 Villars-sur-Glâne,Rte Préalpes, Distance from stop:155.88265670535895
#
# EDGE
# Start Time: 2019-03-26T09:35:22.141000Z
# Start Point: 60 Villars-sur-Glâne,Rte Préalpes, Distance from stop:155.88265670535895
# Speed: 1.4447327862929764
# Duration: 7.999000072479248
# Distance: 11.556417662270665
# End Time: 2019-03-26T09:35:30.140000Z
# Finish Point: 61 Villars-sur-Glâne,Rte Préalpes, Distance from stop:144.86707655674337
#
# EDGE
# Start Time: 2019-03-26T09:35:30.140000Z
# Start Point: 61 Villars-sur-Glâne,Rte Préalpes, Distance from stop:144.86707655674337
# Speed: 1.5169175520397837
# Duration: 7.000999927520752
# Distance: 10.619939671885483
# End Time: 2019-03-26T09:35:37.141000Z
# Finish Point: 62 Villars-sur-Glâne,Rte Préalpes, Distance from stop:137.28797849182794
#
# EDGE
# Start Time: 2019-03-26T09:35:37.141000Z
# Start Point: 62 Villars-sur-Glâne,Rte Préalpes, Distance from stop:137.28797849182794
# Speed: 1.5785027081525118
# Duration: 7.006999969482422
# Distance: 11.060568427852571
# End Time: 2019-03-26T09:35:44.148000Z
# Finish Point: 63 Villars-sur-Glâne,Rte Préalpes, Distance from stop:128.3585189255081
#
# EDGE
# Start Time: 2019-03-26T09:35:44.148000Z
# Start Point: 63 Villars-sur-Glâne,Rte Préalpes, Distance from stop:128.3585189255081
# Speed: 1.557246229139998
# Duration: 6.992000102996826
# Distance: 10.888265794538285
# End Time: 2019-03-26T09:35:51.140000Z
# Finish Point: 64 Villars-sur-Glâne,Rte Préalpes, Distance from stop:119.65602221694299
#
# EDGE
# Start Time: 2019-03-26T09:35:51.140000Z
# Start Point: 64 Villars-sur-Glâne,Rte Préalpes, Distance from stop:119.65602221694299
# Speed: 1.5349033474328908
# Duration: 7.000999927520752
# Distance: 10.745858224129028
# End Time: 2019-03-26T09:35:58.141000Z
# Finish Point: 65 Villars-sur-Glâne,Rte Préalpes, Distance from stop:112.1938662715704
#
# EDGE
# Start Time: 2019-03-26T09:35:58.141000Z
# Start Point: 65 Villars-sur-Glâne,Rte Préalpes, Distance from stop:112.1938662715704
# Speed: 1.6686331318695844
# Duration: 6.999000072479248
# Distance: 11.678763410896496
# End Time: 2019-03-26T09:36:05.140000Z
# Finish Point: 66 Villars-sur-Glâne,Rte Préalpes, Distance from stop:104.23587630607648
#
# EDGE
# Start Time: 2019-03-26T09:36:05.140000Z
# Start Point: 66 Villars-sur-Glâne,Rte Préalpes, Distance from stop:104.23587630607648
# Speed: 1.5231511471308394
# Duration: 7.005999803543091
# Distance: 10.671196637565094
# End Time: 2019-03-26T09:36:12.146000Z
# Finish Point: 67 Villars-sur-Glâne,Rte Préalpes, Distance from stop:97.14288235443027
#
# EDGE
# Start Time: 2019-03-26T09:36:12.146000Z
# Start Point: 67 Villars-sur-Glâne,Rte Préalpes, Distance from stop:97.14288235443027
# Speed: 1.5835650989107382
# Duration: 6.991000175476074
# Distance: 11.070703884362757
# End Time: 2019-03-26T09:36:19.137000Z
# Finish Point: 68 Villars-sur-Glâne,Rte Préalpes, Distance from stop:89.60238306251999
#
# EDGE
# Start Time: 2019-03-26T09:36:19.137000Z
# Start Point: 68 Villars-sur-Glâne,Rte Préalpes, Distance from stop:89.60238306251999
# Speed: 1.847704818675897
# Duration: 6.001999855041504
# Distance: 11.089924053852222
# End Time: 2019-03-26T09:36:25.139000Z
# Finish Point: 69 Villars-sur-Glâne,Rte Préalpes, Distance from stop:82.40652231436127
#
# EDGE
# Start Time: 2019-03-26T09:36:25.139000Z
# Start Point: 69 Villars-sur-Glâne,Rte Préalpes, Distance from stop:82.40652231436127
# Speed: 1.578459027518249
# Duration: 7.005000114440918
# Distance: 11.057105668405635
# End Time: 2019-03-26T09:36:32.144000Z
# Finish Point: 70 Villars-sur-Glâne,Rte Préalpes, Distance from stop:76.02406184605036
#
# EDGE
# Start Time: 2019-03-26T09:36:32.144000Z
# Start Point: 70 Villars-sur-Glâne,Rte Préalpes, Distance from stop:76.02406184605036
# Speed: 1.2972975572620924
# Duration: 7.996000051498413
# Distance: 10.373191334676456
# End Time: 2019-03-26T09:36:40.140000Z
# Finish Point: 71 Villars-sur-Glâne,Rte Préalpes, Distance from stop:73.31181241211407
#
# EDGE
# Start Time: 2019-03-26T09:36:40.140000Z
# Start Point: 71 Villars-sur-Glâne,Rte Préalpes, Distance from stop:73.31181241211407
# Speed: 1.2274076253169117
# Duration: 8.995999813079834
# Distance: 11.041758767923701
# End Time: 2019-03-26T09:36:49.136000Z
# Finish Point: 72 Villars-sur-Glâne,Rte Préalpes, Distance from stop:72.01150309949114
#
# EDGE
# Start Time: 2019-03-26T09:36:49.136000Z
# Start Point: 72 Villars-sur-Glâne,Rte Préalpes, Distance from stop:72.01150309949114
# Speed: 1.5994407428334525
# Duration: 6.860000133514404
# Distance: 10.972163709385862
# End Time: 2019-03-26T09:36:55.996000Z
# Finish Point: 73 Villars-sur-Glâne,Rte Préalpes, Distance from stop:75.3727270442695
#
# EDGE
# Start Time: 2019-03-26T09:36:55.996000Z
# Start Point: 73 Villars-sur-Glâne,Rte Préalpes, Distance from stop:75.3727270442695
# Speed: 1.3004085540682018
# Duration: 8.000999927520752
# Distance: 10.404568746847048
# End Time: 2019-03-26T09:37:03.997000Z
# Finish Point: 74 Villars-sur-Glâne,Rte Préalpes, Distance from stop:73.46097059776056
#
# EDGE
# Start Time: 2019-03-26T09:37:03.997000Z
# Start Point: 74 Villars-sur-Glâne,Rte Préalpes, Distance from stop:73.46097059776056
# Speed: 2.9986345070835276
# Duration: 4.000999927520752
# Distance: 11.99753644550242
# End Time: 2019-03-26T09:37:07.998000Z
# Finish Point: 75 Villars-sur-Glâne,Rte Préalpes, Distance from stop:72.79143075259677
#
# EDGE
# Start Time: 2019-03-26T09:37:07.998000Z
# Start Point: 75 Villars-sur-Glâne,Rte Préalpes, Distance from stop:72.79143075259677
# Speed: 3.6546377546810636
# Duration: 3.0
# Distance: 10.96391326404319
# End Time: 2019-03-26T09:37:10.998000Z
# Finish Point: 76 Villars-sur-Glâne,Rte Préalpes, Distance from stop:75.34251100239894
#
# EDGE
# Start Time: 2019-03-26T09:37:10.998000Z
# Start Point: 76 Villars-sur-Glâne,Rte Préalpes, Distance from stop:75.34251100239894
# Speed: 3.074045705967218
# Duration: 4.0
# Distance: 12.296182823868872
# End Time: 2019-03-26T09:37:14.998000Z
# Finish Point: 77 Villars-sur-Glâne,Rte Préalpes, Distance from stop:77.55888644920975
#
# EDGE
# Start Time: 2019-03-26T09:37:14.998000Z
# Start Point: 77 Villars-sur-Glâne,Rte Préalpes, Distance from stop:77.55888644920975
# Speed: 3.5553556336032948
# Duration: 3.0
# Distance: 10.666066900809884
# End Time: 2019-03-26T09:37:17.998000Z
# Finish Point: 78 Villars-sur-Glâne,Rte Préalpes, Distance from stop:80.85197306949625
#
# EDGE
# Start Time: 2019-03-26T09:37:17.998000Z
# Start Point: 78 Villars-sur-Glâne,Rte Préalpes, Distance from stop:80.85197306949625
# Speed: 1.5939118088135955
# Duration: 13.001000165939331
# Distance: 20.722447690878216
# End Time: 2019-03-26T09:37:30.999000Z
# Finish Point: 79 Villars-sur-Glâne,Rte Préalpes, Distance from stop:68.8943151151046
#
# EDGE
# Start Time: 2019-03-26T09:37:30.999000Z
# Start Point: 79 Villars-sur-Glâne,Rte Préalpes, Distance from stop:68.8943151151046
# Speed: 1.3705861213920307
# Duration: 8.0
# Distance: 10.964688971136246
# End Time: 2019-03-26T09:37:38.999000Z
# Finish Point: 80 Villars-sur-Glâne,Rte Préalpes, Distance from stop:58.36059675223115
#
# EDGE
# Start Time: 2019-03-26T09:37:38.999000Z
# Start Point: 80 Villars-sur-Glâne,Rte Préalpes, Distance from stop:58.36059675223115
# Speed: 1.8443995730826668
# Duration: 6.0
# Distance: 11.066397438496
# End Time: 2019-03-26T09:37:44.999000Z
# Finish Point: 81 Villars-sur-Glâne,Rte Préalpes, Distance from stop:47.5572668997791
#
# EDGE
# Start Time: 2019-03-26T09:37:44.999000Z
# Start Point: 81 Villars-sur-Glâne,Rte Préalpes, Distance from stop:47.5572668997791
# Speed: 1.5393456070409037
# Duration: 7.0
# Distance: 10.775419249286326
# End Time: 2019-03-26T09:37:51.999000Z
# Finish Point: 82 Villars-sur-Glâne,Rte Préalpes, Distance from stop:36.803678843129205
#
# EDGE
# Start Time: 2019-03-26T09:37:51.999000Z
# Start Point: 82 Villars-sur-Glâne,Rte Préalpes, Distance from stop:36.803678843129205
# Speed: 1.5755838680015093
# Duration: 7.0
# Distance: 11.029087076010565
# End Time: 2019-03-26T09:37:58.999000Z
# Finish Point: 83 Villars-sur-Glâne,Rte Préalpes, Distance from stop:26.055240920513334
#
# EDGE
# Start Time: 2019-03-26T09:37:58.999000Z
# Start Point: 83 Villars-sur-Glâne,Rte Préalpes, Distance from stop:26.055240920513334
# Speed: 2.0986331527336377
# Duration: 5.0
# Distance: 10.493165763668188
# End Time: 2019-03-26T09:38:03.999000Z
# Finish Point: 84 Villars-sur-Glâne,Rte Préalpes, Distance from stop:15.660050547204357
#
# EDGE
# Start Time: 2019-03-26T09:38:03.999000Z
# Start Point: 84 Villars-sur-Glâne,Rte Préalpes, Distance from stop:15.660050547204357
# Speed: 1.4370584741422068
# Duration: 8.0
# Distance: 11.496467793137654
# End Time: 2019-03-26T09:38:11.999000Z
# Finish Point: 85 Villars-sur-Glâne,Rte Préalpes, Distance from stop:4.238411675627585
#
# EDGE
# Start Time: 2019-03-26T09:38:11.999000Z
# Start Point: 85 Villars-sur-Glâne,Rte Préalpes, Distance from stop:4.238411675627585
# Speed: 0.06110774671472579
# Duration: 68.0
# Distance: 4.1553267766013535
# End Time: 2019-03-26T09:39:19.999000Z
# Finish Point: 86 Villars-sur-Glâne,Rte Préalpes, Distance from stop:5.870598075517811
#
# ----------------------------------------------------------------------------------------------------SEGMENT
# EDGE
# Start Time: 2019-03-26T09:53:38Z
# Start Point: 192 Fribourg, gare CFF, Distance from stop:60.30905288808251
# Speed: 0.7921615664354598
# Duration: 13.0
# Distance: 10.298100363660977
# End Time: 2019-03-26T09:53:51Z
# Finish Point: 193 Fribourg, gare CFF, Distance from stop:50.28451425178975
#
# EDGE
# Start Time: 2019-03-26T09:53:51Z
# Start Point: 193 Fribourg, gare CFF, Distance from stop:50.28451425178975
# Speed: 1.1049749716377202
# Duration: 10.0
# Distance: 11.049749716377201
# End Time: 2019-03-26T09:54:01Z
# Finish Point: 194 Fribourg, gare CFF, Distance from stop:39.591136352239154
#
# EDGE
# Start Time: 2019-03-26T09:54:01Z
# Start Point: 194 Fribourg, gare CFF, Distance from stop:39.591136352239154
# Speed: 0.4112139731851979
# Duration: 27.0
# Distance: 11.102777276000344
# End Time: 2019-03-26T09:54:28Z
# Finish Point: 195 Fribourg, gare CFF, Distance from stop:28.691754601572004
#
# EDGE
# Start Time: 2019-03-26T09:54:28Z
# Start Point: 195 Fribourg, gare CFF, Distance from stop:28.691754601572004
# Speed: 0.3170715289400085
# Duration: 32.0
# Distance: 10.146288926080272
# End Time: 2019-03-26T09:55:00Z
# Finish Point: 196 Fribourg, gare CFF, Distance from stop:20.264073530786725
#
# EDGE
# Start Time: 2019-03-26T09:55:00Z
# Start Point: 196 Fribourg, gare CFF, Distance from stop:20.264073530786725
# Speed: 1.0708226991042138
# Duration: 10.0
# Distance: 10.708226991042137
# End Time: 2019-03-26T09:55:10Z
# Finish Point: 197 Fribourg, gare CFF, Distance from stop:12.905277114905939
#
# EDGE
# Start Time: 2019-03-26T09:55:10Z
# Start Point: 197 Fribourg, gare CFF, Distance from stop:12.905277114905939
# Speed: 0.4084868489156742
# Duration: 31.0
# Distance: 12.663092316385901
# End Time: 2019-03-26T09:55:41Z
# Finish Point: 198 Fribourg, gare CFF, Distance from stop:13.100134280428064
#
# ----------------------------------------------------------------------------------------------------SEGMENT
# EDGE
# Start Time: 2019-03-26T09:57:27.001000Z
# Start Point: 220 Fribourg, St-Pierre, Distance from stop:33.18244103001232
# Speed: 1.439278725220588
# Duration: 7.0
# Distance: 10.074951076544117
# End Time: 2019-03-26T09:57:34.001000Z
# Finish Point: 221 Fribourg, St-Pierre, Distance from stop:41.07442299550048
#
# EDGE
# Start Time: 2019-03-26T09:57:34.001000Z
# Start Point: 221 Fribourg, St-Pierre, Distance from stop:41.07442299550048
# Speed: 1.7522889298827877
# Duration: 6.0
# Distance: 10.513733579296726
# End Time: 2019-03-26T09:57:40.001000Z
# Finish Point: 222 Fribourg, Place Georges Python, Distance from stop:46.5783352009006
#
# EDGE
# Start Time: 2019-03-26T09:57:40.001000Z
# Start Point: 222 Fribourg, Place Georges Python, Distance from stop:46.5783352009006
# Speed: 1.3218485220246081
# Duration: 8.0
# Distance: 10.574788176196865
# End Time: 2019-03-26T09:57:48.001000Z
# Finish Point: 223 Fribourg, Place Georges Python, Distance from stop:54.09983397821033
#
# EDGE
# Start Time: 2019-03-26T09:57:48.001000Z
# Start Point: 223 Fribourg, Place Georges Python, Distance from stop:54.09983397821033
# Speed: 1.595439007193495
# Duration: 7.0
# Distance: 11.168073050354465
# End Time: 2019-03-26T09:57:55.001000Z
# Finish Point: 224 Fribourg, St-Pierre, Distance from stop:47.84907772069174
#
# EDGE
# Start Time: 2019-03-26T09:57:55.001000Z
# Start Point: 224 Fribourg, St-Pierre, Distance from stop:47.84907772069174
# Speed: 0.8088714328977529
# Duration: 13.0
# Distance: 10.515328627670787
# End Time: 2019-03-26T09:58:08.001000Z
# Finish Point: 225 Fribourg, Place Georges Python, Distance from stop:55.58385185640111
#
# EDGE
# Start Time: 2019-03-26T09:58:08.001000Z
# Start Point: 225 Fribourg, Place Georges Python, Distance from stop:55.58385185640111
# Speed: 0.4818181479671928
# Duration: 23.0
# Distance: 11.081817403245434
# End Time: 2019-03-26T09:58:31.001000Z
# Finish Point: 226 Fribourg, Place Georges Python, Distance from stop:44.51043277937523
#
# EDGE
# Start Time: 2019-03-26T09:58:31.001000Z
# Start Point: 226 Fribourg, Place Georges Python, Distance from stop:44.51043277937523
# Speed: 1.4981051348560066
# Duration: 7.0
# Distance: 10.486735943992047
# End Time: 2019-03-26T09:58:38.001000Z
# Finish Point: 227 Fribourg, Place Georges Python, Distance from stop:34.202060666227574
#
# EDGE
# Start Time: 2019-03-26T09:58:38.001000Z
# Start Point: 227 Fribourg, Place Georges Python, Distance from stop:34.202060666227574
# Speed: 2.1896143831537636
# Duration: 5.0
# Distance: 10.948071915768818
# End Time: 2019-03-26T09:58:43.001000Z
# Finish Point: 228 Fribourg, Place Georges Python, Distance from stop:23.571773110948605
#
# EDGE
# Start Time: 2019-03-26T09:58:43.001000Z
# Start Point: 228 Fribourg, Place Georges Python, Distance from stop:23.571773110948605
# Speed: 2.3166727970480974
# Duration: 4.999000072479248
# Distance: 11.58104748035414
# End Time: 2019-03-26T09:58:48Z
# Finish Point: 229 Fribourg, Place Georges Python, Distance from stop:13.172415928007757
#
# EDGE
# Start Time: 2019-03-26T09:58:48Z
# Start Point: 229 Fribourg, Place Georges Python, Distance from stop:13.172415928007757
# Speed: 1.4961990398676976
# Duration: 7.0
# Distance: 10.473393279073884
# End Time: 2019-03-26T09:58:55Z
# Finish Point: 230 Fribourg, Place Georges Python, Distance from stop:6.443276240150688
#
# EDGE
# Start Time: 2019-03-26T09:58:55Z
# Start Point: 230 Fribourg, Place Georges Python, Distance from stop:6.443276240150688
# Speed: 1.3018693447956167
# Duration: 8.0
# Distance: 10.414954758364933
# End Time: 2019-03-26T09:59:03Z
# Finish Point: 231 Fribourg, Place Georges Python, Distance from stop:12.566966653738637
#
# EDGE
# Start Time: 2019-03-26T09:59:03Z
# Start Point: 231 Fribourg, Place Georges Python, Distance from stop:12.566966653738637
# Speed: 1.4991903817551242
# Duration: 7.0
# Distance: 10.49433267228587
# End Time: 2019-03-26T09:59:10Z
# Finish Point: 232 Fribourg, Place Georges Python, Distance from stop:21.87465391310707
#
# EDGE
# Start Time: 2019-03-26T09:59:10Z
# Start Point: 232 Fribourg, Place Georges Python, Distance from stop:21.87465391310707
# Speed: 1.2814319907536664
# Duration: 8.0
# Distance: 10.251455926029331
# End Time: 2019-03-26T09:59:18Z
# Finish Point: 233 Fribourg, Place Georges Python, Distance from stop:31.98959759238136
#
# EDGE
# Start Time: 2019-03-26T09:59:18Z
# Start Point: 233 Fribourg, Place Georges Python, Distance from stop:31.98959759238136
# Speed: 1.3677630032840449
# Duration: 8.0
# Distance: 10.942104026272359
# End Time: 2019-03-26T09:59:26Z
# Finish Point: 234 Fribourg, Place Georges Python, Distance from stop:42.53765165035079
#
# EDGE
# Start Time: 2019-03-26T09:59:26Z
# Start Point: 234 Fribourg, Place Georges Python, Distance from stop:42.53765165035079
# Speed: 1.7458068058809306
# Duration: 6.0
# Distance: 10.474840835285583
# End Time: 2019-03-26T09:59:32Z
# Finish Point: 235 Fribourg, Place Georges Python, Distance from stop:52.41310510898859
#
# EDGE
# Start Time: 2019-03-26T09:59:32Z
# Start Point: 235 Fribourg, Place Georges Python, Distance from stop:52.41310510898859
# Speed: 1.732811266613041
# Duration: 6.0
# Distance: 10.396867599678247
# End Time: 2019-03-26T09:59:38Z
# Finish Point: 236 Fribourg, Place Georges Python, Distance from stop:62.66220274874859
#
# EDGE
# Start Time: 2019-03-26T09:59:38Z
# Start Point: 236 Fribourg, Place Georges Python, Distance from stop:62.66220274874859
# Speed: 1.4002969859558987
# Duration: 8.0
# Distance: 11.20237588764719
# End Time: 2019-03-26T09:59:46Z
# Finish Point: 237 Fribourg, Place Georges Python, Distance from stop:73.63633649732128
#
# EDGE
# Start Time: 2019-03-26T09:59:46Z
# Start Point: 237 Fribourg, Place Georges Python, Distance from stop:73.63633649732128
# Speed: 1.1520242234777198
# Duration: 9.0
# Distance: 10.36821801129948
# End Time: 2019-03-26T09:59:55Z
# Finish Point: 238 Fribourg, Place Georges Python, Distance from stop:83.62917666323543
#
# EDGE
# Start Time: 2019-03-26T09:59:55Z
# Start Point: 238 Fribourg, Place Georges Python, Distance from stop:83.62917666323543
# Speed: 1.8375844913855006
# Duration: 6.0
# Distance: 11.025506948313003
# End Time: 2019-03-26T10:00:01Z
# Finish Point: 239 Fribourg, Place Georges Python, Distance from stop:94.24609977458472
#
# EDGE
# Start Time: 2019-03-26T10:00:01Z
# Start Point: 239 Fribourg, Place Georges Python, Distance from stop:94.24609977458472
# Speed: 1.6940637610451323
# Duration: 7.0
# Distance: 11.858446327315926
# End Time: 2019-03-26T10:00:08Z
# Finish Point: 240 Fribourg, Place Georges Python, Distance from stop:105.29209858477638
#
# EDGE
# Start Time: 2019-03-26T10:00:08Z
# Start Point: 240 Fribourg, Place Georges Python, Distance from stop:105.29209858477638
# Speed: 1.5585684512654903
# Duration: 7.0
# Distance: 10.909979158858432
# End Time: 2019-03-26T10:00:15Z
# Finish Point: 241 Fribourg, Place Georges Python, Distance from stop:113.89954559515965
#
# EDGE
# Start Time: 2019-03-26T10:00:15Z
# Start Point: 241 Fribourg, Place Georges Python, Distance from stop:113.89954559515965
# Speed: 1.6924266007420583
# Duration: 6.0
# Distance: 10.15455960445235
# End Time: 2019-03-26T10:00:21Z
# Finish Point: 242 Fribourg, Place Georges Python, Distance from stop:121.04197379803475
#
# EDGE
# Start Time: 2019-03-26T10:00:21Z
# Start Point: 242 Fribourg, Place Georges Python, Distance from stop:121.04197379803475
# Speed: 0.9142950130195385
# Duration: 11.0
# Distance: 10.057245143214924
# End Time: 2019-03-26T10:00:32Z
# Finish Point: 243 Fribourg, Place Georges Python, Distance from stop:129.78664626951957
#
# EDGE
# Start Time: 2019-03-26T10:00:32Z
# Start Point: 243 Fribourg, Place Georges Python, Distance from stop:129.78664626951957
# Speed: 1.8398116632372286
# Duration: 6.0
# Distance: 11.038869979423371
# End Time: 2019-03-26T10:00:38Z
# Finish Point: 244 Fribourg, Place Georges Python, Distance from stop:139.42845081119626
#
# EDGE
# Start Time: 2019-03-26T10:00:38Z
# Start Point: 244 Fribourg, Place Georges Python, Distance from stop:139.42845081119626
# Speed: 1.8005514543738197
# Duration: 6.0
# Distance: 10.803308726242918
# End Time: 2019-03-26T10:00:44Z
# Finish Point: 245 Fribourg, Place Georges Python, Distance from stop:149.34455557828318
#
# EDGE
# Start Time: 2019-03-26T10:00:44Z
# Start Point: 245 Fribourg, Place Georges Python, Distance from stop:149.34455557828318
# Speed: 2.548250540977136
# Duration: 4.0
# Distance: 10.193002163908544
# End Time: 2019-03-26T10:00:48Z
# Finish Point: 246 Fribourg, Place Georges Python, Distance from stop:157.86029671784502
#
# EDGE
# Start Time: 2019-03-26T10:00:48Z
# Start Point: 246 Fribourg, Place Georges Python, Distance from stop:157.86029671784502
# Speed: 2.0266570793690004
# Duration: 5.0
# Distance: 10.133285396845002
# End Time: 2019-03-26T10:00:53Z
# Finish Point: 247 Fribourg, Place Georges Python, Distance from stop:166.723054554424
#
# EDGE
# Start Time: 2019-03-26T10:00:53Z
# Start Point: 247 Fribourg, Place Georges Python, Distance from stop:166.723054554424
# Speed: 1.5585879002585212
# Duration: 7.0
# Distance: 10.910115301809649
# End Time: 2019-03-26T10:01:00Z
# Finish Point: 248 Fribourg, Place Georges Python, Distance from stop:175.04928366706545
#
# EDGE
# Start Time: 2019-03-26T10:01:00Z
# Start Point: 248 Fribourg, Place Georges Python, Distance from stop:175.04928366706545
# Speed: 1.335600330060362
# Duration: 8.0
# Distance: 10.684802640482896
# End Time: 2019-03-26T10:01:08Z
# Finish Point: 249 Fribourg, Université, Distance from stop:147.38504096280843
#
# EDGE
# Start Time: 2019-03-26T10:01:08Z
# Start Point: 249 Fribourg, Université, Distance from stop:147.38504096280843
# Speed: 0.9867277802844275
# Duration: 11.0
# Distance: 10.854005583128703
# End Time: 2019-03-26T10:01:19Z
# Finish Point: 250 Fribourg, Université, Distance from stop:136.75717784994606
#
# EDGE
# Start Time: 2019-03-26T10:01:19Z
# Start Point: 250 Fribourg, Université, Distance from stop:136.75717784994606
# Speed: 1.6755569552606169
# Duration: 6.0
# Distance: 10.053341731563702
# End Time: 2019-03-26T10:01:25Z
# Finish Point: 251 Fribourg, Université, Distance from stop:127.71733097529444
#
# EDGE
# Start Time: 2019-03-26T10:01:25Z
# Start Point: 251 Fribourg, Université, Distance from stop:127.71733097529444
# Speed: 1.353604521698193
# Duration: 8.0
# Distance: 10.828836173585543
# End Time: 2019-03-26T10:01:33Z
# Finish Point: 252 Fribourg, Université, Distance from stop:116.98130329423576
#
# EDGE
# Start Time: 2019-03-26T10:01:33Z
# Start Point: 252 Fribourg, Université, Distance from stop:116.98130329423576
# Speed: 1.080314519095336
# Duration: 10.0
# Distance: 10.80314519095336
# End Time: 2019-03-26T10:01:43Z
# Finish Point: 253 Fribourg, Université, Distance from stop:106.23923824778053
#
# EDGE
# Start Time: 2019-03-26T10:01:43Z
# Start Point: 253 Fribourg, Université, Distance from stop:106.23923824778053
# Speed: 1.9181358982998749
# Duration: 7.0
# Distance: 13.426951288099124
# End Time: 2019-03-26T10:01:50Z
# Finish Point: 254 Fribourg, Université, Distance from stop:93.10353040959197
#
# EDGE
# Start Time: 2019-03-26T10:01:50Z
# Start Point: 254 Fribourg, Université, Distance from stop:93.10353040959197
# Speed: 2.217168734288321
# Duration: 5.0
# Distance: 11.085843671441605
# End Time: 2019-03-26T10:01:55Z
# Finish Point: 255 Fribourg, Université, Distance from stop:82.1596918981352
#
# EDGE
# Start Time: 2019-03-26T10:01:55Z
# Start Point: 255 Fribourg, Université, Distance from stop:82.1596918981352
# Speed: 2.0134546316345223
# Duration: 5.0
# Distance: 10.067273158172611
# End Time: 2019-03-26T10:02:00Z
# Finish Point: 256 Fribourg, Université, Distance from stop:72.23440307758777
#
# EDGE
# Start Time: 2019-03-26T10:02:00Z
# Start Point: 256 Fribourg, Université, Distance from stop:72.23440307758777
# Speed: 1.0001302973325137
# Duration: 10.0
# Distance: 10.001302973325137
# End Time: 2019-03-26T10:02:10Z
# Finish Point: 257 Fribourg, Université, Distance from stop:62.951968205908564
#
# EDGE
# Start Time: 2019-03-26T10:02:10Z
# Start Point: 257 Fribourg, Université, Distance from stop:62.951968205908564
# Speed: 1.1805693662791727
# Duration: 10.0
# Distance: 11.805693662791727
# End Time: 2019-03-26T10:02:20Z
# Finish Point: 258 Fribourg, Université, Distance from stop:53.079675853634804
#
# EDGE
# Start Time: 2019-03-26T10:02:20Z
# Start Point: 258 Fribourg, Université, Distance from stop:53.079675853634804
# Speed: 1.697717538203041
# Duration: 6.0
# Distance: 10.186305229218245
# End Time: 2019-03-26T10:02:26Z
# Finish Point: 259 Fribourg, Université, Distance from stop:50.229759494306556
#
# EDGE
# Start Time: 2019-03-26T10:02:26Z
# Start Point: 259 Fribourg, Université, Distance from stop:50.229759494306556
# Speed: 2.125090258455752
# Duration: 5.0
# Distance: 10.62545129227876
# End Time: 2019-03-26T10:02:31Z
# Finish Point: 260 Fribourg, Université, Distance from stop:43.64001010373572
#
# EDGE
# Start Time: 2019-03-26T10:02:31Z
# Start Point: 260 Fribourg, Université, Distance from stop:43.64001010373572
# Speed: 1.2347407884909307
# Duration: 9.0
# Distance: 11.112667096418377
# End Time: 2019-03-26T10:02:40Z
# Finish Point: 261 Fribourg, Université, Distance from stop:35.4153349343186
#
# EDGE
# Start Time: 2019-03-26T10:02:40Z
# Start Point: 261 Fribourg, Université, Distance from stop:35.4153349343186
# Speed: 1.5829572464567827
# Duration: 7.0
# Distance: 11.08070072519748
# End Time: 2019-03-26T10:02:47Z
# Finish Point: 262 Fribourg, Université, Distance from stop:26.10269231532653
#
# EDGE
# Start Time: 2019-03-26T10:02:47Z
# Start Point: 262 Fribourg, Université, Distance from stop:26.10269231532653
# Speed: 0.14969883364863804
# Duration: 13.0
# Distance: 1.9460848374322945
# End Time: 2019-03-26T10:03:00Z
# Finish Point: 263 Fribourg, Université, Distance from stop:24.180262588390924
#
# EDGE
# Start Time: 2019-03-26T10:03:00Z
# Start Point: 263 Fribourg, Université, Distance from stop:24.180262588390924
# Speed: 0.19110999190127126
# Duration: 120.92600011825562
# Distance: 23.110166903252956
# End Time: 2019-03-26T10:05:00.926000Z
# Finish Point: 264 Fribourg, Université, Distance from stop:16.71476234447324
#
# EDGE
# Start Time: 2019-03-26T10:05:00.926000Z
# Start Point: 264 Fribourg, Université, Distance from stop:16.71476234447324
# Speed: 1.6858966486173692
# Duration: 9.072999954223633
# Distance: 15.296140215731167
# End Time: 2019-03-26T10:05:09.999000Z
# Finish Point: 265 Fribourg, Université, Distance from stop:2.3370694083666694
#
# EDGE
# Start Time: 2019-03-26T10:05:09.999000Z
# Start Point: 265 Fribourg, Université, Distance from stop:2.3370694083666694
# Speed: 0.1465876090484364
# Duration: 37.0
# Distance: 5.423741534792147
# End Time: 2019-03-26T10:05:46.999000Z
# Finish Point: 266 Fribourg, Université, Distance from stop:4.624426754904689
#
# ----------------------------------------------------------------------------------------------------SEGMENT
# EDGE
# Start Time: 2019-03-26T10:14:24.001000Z
# Start Point: 273 Fribourg, gare CFF, Distance from stop:17.124881402754156
# Speed: 0.3025657443816557
# Duration: 71.0
# Distance: 21.482167851097554
# End Time: 2019-03-26T10:15:35.001000Z
# Finish Point: 274 Fribourg, gare CFF, Distance from stop:24.418313268115543
#
# EDGE
# Start Time: 2019-03-26T10:15:35.001000Z
# Start Point: 274 Fribourg, gare CFF, Distance from stop:24.418313268115543
# Speed: 0.18654290227208883
# Duration: 58.0
# Distance: 10.819488331781152
# End Time: 2019-03-26T10:16:33.001000Z
# Finish Point: 275 Fribourg, gare CFF, Distance from stop:33.93757147829237
#
# EDGE
# Start Time: 2019-03-26T10:16:33.001000Z
# Start Point: 275 Fribourg, gare CFF, Distance from stop:33.93757147829237
# Speed: 1.0350182835121
# Duration: 10.0
# Distance: 10.350182835121
# End Time: 2019-03-26T10:16:43.001000Z
# Finish Point: 276 Fribourg, gare CFF, Distance from stop:44.22544538838721
#
# EDGE
# Start Time: 2019-03-26T10:16:43.001000Z
# Start Point: 276 Fribourg, gare CFF, Distance from stop:44.22544538838721
# Speed: 0.035129911139709244
# Duration: 17.0
# Distance: 0.5972084893750571
# End Time: 2019-03-26T10:17:00.001000Z
# Finish Point: 277 Fribourg, gare CFF, Distance from stop:44.62316989560614
#
# EDGE
# Start Time: 2019-03-26T10:17:00.001000Z
# Start Point: 277 Fribourg, gare CFF, Distance from stop:44.62316989560614
# Speed: 0.0992909167864493
# Duration: 6.0
# Distance: 0.5957455007186958
# End Time: 2019-03-26T10:17:06.001000Z
# Finish Point: 278 Fribourg, gare CFF, Distance from stop:44.51484556753066
#
# EDGE
# Start Time: 2019-03-26T10:17:06.001000Z
# Start Point: 278 Fribourg, gare CFF, Distance from stop:44.51484556753066
# Speed: 0.0
# Duration: 8.0
# Distance: 0.0
# End Time: 2019-03-26T10:17:14.001000Z
# Finish Point: 279 Fribourg, gare CFF, Distance from stop:44.51484556753066
#
# ----------------------------------------------------------------------------------------------------SEGMENT
# EDGE
# Start Time: 2019-03-26T10:28:47.003000Z
# Start Point: 332 Fribourg, Petit-St-Jean, Distance from stop:9.12354976494374
# Speed: 1.0751011409023599
# Duration: 1.0
# Distance: 1.0751011409023599
# End Time: 2019-03-26T10:28:48.003000Z
# Finish Point: 333 Fribourg, Petit-St-Jean, Distance from stop:8.971265392749725
#
# EDGE
# Start Time: 2019-03-26T10:28:48.003000Z
# Start Point: 333 Fribourg, Petit-St-Jean, Distance from stop:8.971265392749725
# Speed: 0.855885581126644
# Duration: 12.0
# Distance: 10.270626973519729
# End Time: 2019-03-26T10:29:00.003000Z
# Finish Point: 334 Fribourg, Petit-St-Jean, Distance from stop:11.266875059621936
#
# EDGE
# Start Time: 2019-03-26T10:29:00.003000Z
# Start Point: 334 Fribourg, Petit-St-Jean, Distance from stop:11.266875059621936
# Speed: 2.0897960552836192
# Duration: 5.0
# Distance: 10.448980276418096
# End Time: 2019-03-26T10:29:05.003000Z
# Finish Point: 335 Fribourg, Petit-St-Jean, Distance from stop:18.179386911144018
#
# EDGE
# Start Time: 2019-03-26T10:29:05.003000Z
# Start Point: 335 Fribourg, Petit-St-Jean, Distance from stop:18.179386911144018
# Speed: 0.16199864399409838
# Duration: 63.0
# Distance: 10.205914571628199
# End Time: 2019-03-26T10:30:08.003000Z
# Finish Point: 336 Fribourg, Petit-St-Jean, Distance from stop:28.374895978352157
#
# EDGE
# Start Time: 2019-03-26T10:30:08.003000Z
# Start Point: 336 Fribourg, Petit-St-Jean, Distance from stop:28.374895978352157
# Speed: 0.16977627542765425
# Duration: 483.15899991989136
# Distance: 82.02893544574945
# End Time: 2019-03-26T10:38:11.162000Z
# Finish Point: 337 Fribourg, Petit-St-Jean, Distance from stop:96.20087830111143
#
# EDGE
# Start Time: 2019-03-26T10:38:11.162000Z
# Start Point: 337 Fribourg, Petit-St-Jean, Distance from stop:96.20087830111143
# Speed: 2.0639102560779503
# Duration: 6.005000114440918
# Distance: 12.393781323943877
# End Time: 2019-03-26T10:38:17.167000Z
# Finish Point: 338 Fribourg, Karrweg, Distance from stop:74.23454419786775
#
# EDGE
# Start Time: 2019-03-26T10:38:17.167000Z
# Start Point: 338 Fribourg, Karrweg, Distance from stop:74.23454419786775
# Speed: 1.6124882120013455
# Duration: 4.986000061035156
# Distance: 8.03986632345718
# End Time: 2019-03-26T10:38:22.153000Z
# Finish Point: 339 Fribourg, Karrweg, Distance from stop:66.81814383504438
#
# EDGE
# Start Time: 2019-03-26T10:38:22.153000Z
# Start Point: 339 Fribourg, Karrweg, Distance from stop:66.81814383504438
# Speed: 1.035577562793042
# Duration: 11.002999782562256
# Distance: 11.394459698238192
# End Time: 2019-03-26T10:38:33.156000Z
# Finish Point: 340 Fribourg, Karrweg, Distance from stop:55.87200380546467
#
# EDGE
# Start Time: 2019-03-26T10:38:33.156000Z
# Start Point: 340 Fribourg, Karrweg, Distance from stop:55.87200380546467
# Speed: 1.2608274742079448
# Duration: 8.00600004196167
# Distance: 10.094184811415232
# End Time: 2019-03-26T10:38:41.162000Z
# Finish Point: 341 Fribourg, Karrweg, Distance from stop:45.97785110932876
#
# EDGE
# Start Time: 2019-03-26T10:38:41.162000Z
# Start Point: 341 Fribourg, Karrweg, Distance from stop:45.97785110932876
# Speed: 1.2844623278202496
# Duration: 8.002000093460083
# Distance: 10.278267667263593
# End Time: 2019-03-26T10:38:49.164000Z
# Finish Point: 342 Fribourg, Karrweg, Distance from stop:35.85661613560415
#
# EDGE
# Start Time: 2019-03-26T10:38:49.164000Z
# Start Point: 342 Fribourg, Karrweg, Distance from stop:35.85661613560415
# Speed: 1.141541525922551
# Duration: 8.999000072479248
# Distance: 10.272732274515107
# End Time: 2019-03-26T10:38:58.163000Z
# Finish Point: 343 Fribourg, Karrweg, Distance from stop:25.918416670118884
#
# EDGE
# Start Time: 2019-03-26T10:38:58.163000Z
# Start Point: 343 Fribourg, Karrweg, Distance from stop:25.918416670118884
# Speed: 1.6131403890525697
# Duration: 7.001999855041504
# Distance: 11.295208770307688
# End Time: 2019-03-26T10:39:05.165000Z
# Finish Point: 344 Fribourg, Karrweg, Distance from stop:14.799949581118348
#
# EDGE
# Start Time: 2019-03-26T10:39:05.165000Z
# Start Point: 344 Fribourg, Karrweg, Distance from stop:14.799949581118348
# Speed: 1.466626384650592
# Duration: 7.998000144958496
# Distance: 11.73007803703539
# End Time: 2019-03-26T10:39:13.163000Z
# Finish Point: 345 Fribourg, Karrweg, Distance from stop:14.767780206456147
#
# EDGE
# Start Time: 2019-03-26T10:39:13.163000Z
# Start Point: 345 Fribourg, Karrweg, Distance from stop:14.767780206456147
# Speed: 1.3755637294871603
# Duration: 7.996999979019165
# Distance: 11.000383115848345
# End Time: 2019-03-26T10:39:21.160000Z
# Finish Point: 346 Fribourg, Karrweg, Distance from stop:22.231751466931804
#
# EDGE
# Start Time: 2019-03-26T10:39:21.160000Z
# Start Point: 346 Fribourg, Karrweg, Distance from stop:22.231751466931804
# Speed: 1.369235384143907
# Duration: 7.997999906539917
# Distance: 10.951144474414116
# End Time: 2019-03-26T10:39:29.158000Z
# Finish Point: 347 Fribourg, Karrweg, Distance from stop:31.968965964962884
#
# EDGE
# Start Time: 2019-03-26T10:39:29.158000Z
# Start Point: 347 Fribourg, Karrweg, Distance from stop:31.968965964962884
# Speed: 1.5344986910501628
# Duration: 7.0
# Distance: 10.74149083735114
# End Time: 2019-03-26T10:39:36.158000Z
# Finish Point: 348 Fribourg, Karrweg, Distance from stop:41.558473418221645
#
# EDGE
# Start Time: 2019-03-26T10:39:36.158000Z
# Start Point: 348 Fribourg, Karrweg, Distance from stop:41.558473418221645
# Speed: 1.799963712911809
# Duration: 6.997999906539917
# Distance: 12.59614589473208
# End Time: 2019-03-26T10:39:43.156000Z
# Finish Point: 349 Fribourg, Karrweg, Distance from stop:51.442339152680816
#
# EDGE
# Start Time: 2019-03-26T10:39:43.156000Z
# Start Point: 349 Fribourg, Karrweg, Distance from stop:51.442339152680816
# Speed: 1.6000002837976992
# Duration: 7.003000020980835
# Distance: 11.20480202100463
# End Time: 2019-03-26T10:39:50.159000Z
# Finish Point: 350 Fribourg, Planche-Inférieure, Distance from stop:59.595372879773784
#
# EDGE
# Start Time: 2019-03-26T10:39:50.159000Z
# Start Point: 350 Fribourg, Planche-Inférieure, Distance from stop:59.595372879773784
# Speed: 0.4377304519073833
# Duration: 23.999000072479248
# Distance: 10.505093147051666
# End Time: 2019-03-26T10:40:14.158000Z
# Finish Point: 351 Fribourg, Planche-Inférieure, Distance from stop:49.40518032348135
#
# EDGE
# Start Time: 2019-03-26T10:40:14.158000Z
# Start Point: 351 Fribourg, Planche-Inférieure, Distance from stop:49.40518032348135
# Speed: 1.3761471657047284
# Duration: 8.00600004196167
# Distance: 11.017434266377489
# End Time: 2019-03-26T10:40:22.164000Z
# Finish Point: 352 Fribourg, Planche-Inférieure, Distance from stop:38.48850501503248
#
# EDGE
# Start Time: 2019-03-26T10:40:22.164000Z
# Start Point: 352 Fribourg, Planche-Inférieure, Distance from stop:38.48850501503248
# Speed: 1.7354786739217
# Duration: 6.003999948501587
# Distance: 10.41981386885149
# End Time: 2019-03-26T10:40:28.168000Z
# Finish Point: 353 Fribourg, Planche-Inférieure, Distance from stop:28.768727612097372
#
# EDGE
# Start Time: 2019-03-26T10:40:28.168000Z
# Start Point: 353 Fribourg, Planche-Inférieure, Distance from stop:28.768727612097372
# Speed: 2.041702785587386
# Duration: 5.990999937057495
# Distance: 12.231841259944142
# End Time: 2019-03-26T10:40:34.159000Z
# Finish Point: 354 Fribourg, Planche-Inférieure, Distance from stop:18.01542160015201
#
# EDGE
# Start Time: 2019-03-26T10:40:34.159000Z
# Start Point: 354 Fribourg, Planche-Inférieure, Distance from stop:18.01542160015201
# Speed: 1.6693337220786828
# Duration: 6.001000165939331
# Distance: 10.017671943202297
# End Time: 2019-03-26T10:40:40.160000Z
# Finish Point: 355 Fribourg, Planche-Inférieure, Distance from stop:10.672184027608566
#
# EDGE
# Start Time: 2019-03-26T10:40:40.160000Z
# Start Point: 355 Fribourg, Planche-Inférieure, Distance from stop:10.672184027608566
# Speed: 1.1464127260627546
# Duration: 9.006999969482422
# Distance: 10.325739388661491
# End Time: 2019-03-26T10:40:49.167000Z
# Finish Point: 356 Fribourg, Planche-Inférieure, Distance from stop:9.393747028470205
#
# EDGE
# Start Time: 2019-03-26T10:40:49.167000Z
# Start Point: 356 Fribourg, Planche-Inférieure, Distance from stop:9.393747028470205
# Speed: 1.5120846016931864
# Duration: 6.997999906539917
# Distance: 10.581567901329366
# End Time: 2019-03-26T10:40:56.165000Z
# Finish Point: 357 Fribourg, Planche-Inférieure, Distance from stop:14.449151728036783
#
# EDGE
# Start Time: 2019-03-26T10:40:56.165000Z
# Start Point: 357 Fribourg, Planche-Inférieure, Distance from stop:14.449151728036783
# Speed: 1.978729305775114
# Duration: 6.003000020980835
# Distance: 11.878312064083403
# End Time: 2019-03-26T10:41:02.168000Z
# Finish Point: 358 Fribourg, Planche-Inférieure, Distance from stop:25.608023678111298
#
# EDGE
# Start Time: 2019-03-26T10:41:02.168000Z
# Start Point: 358 Fribourg, Planche-Inférieure, Distance from stop:25.608023678111298
# Speed: 1.2056366566460668
# Duration: 8.989000082015991
# Distance: 10.83746800547298
# End Time: 2019-03-26T10:41:11.157000Z
# Finish Point: 359 Fribourg, Planche-Inférieure, Distance from stop:35.901247621127425
#
# EDGE
# Start Time: 2019-03-26T10:41:11.157000Z
# Start Point: 359 Fribourg, Planche-Inférieure, Distance from stop:35.901247621127425
# Speed: 1.2817232947258086
# Duration: 8.001999855041504
# Distance: 10.25634961859924
# End Time: 2019-03-26T10:41:19.159000Z
# Finish Point: 360 Fribourg, Planche-Inférieure, Distance from stop:45.783797790102234
#
# EDGE
# Start Time: 2019-03-26T10:41:19.159000Z
# Start Point: 360 Fribourg, Planche-Inférieure, Distance from stop:45.783797790102234
# Speed: 1.2030054794196372
# Duration: 9.006999969482422
# Distance: 10.835470316419858
# End Time: 2019-03-26T10:41:28.166000Z
# Finish Point: 361 Fribourg, Planche-Inférieure, Distance from stop:56.61727738987214
#
# EDGE
# Start Time: 2019-03-26T10:41:28.166000Z
# Start Point: 361 Fribourg, Planche-Inférieure, Distance from stop:56.61727738987214
# Speed: 1.2885949477403562
# Duration: 8.001000165939331
# Distance: 10.310048390699174
# End Time: 2019-03-26T10:41:36.167000Z
# Finish Point: 362 Fribourg, Planche-Inférieure, Distance from stop:66.85579872764552
#
# EDGE
# Start Time: 2019-03-26T10:41:36.167000Z
# Start Point: 362 Fribourg, Planche-Inférieure, Distance from stop:66.85579872764552
# Speed: 1.5601488779681343
# Duration: 6.997999906539917
# Distance: 10.91792170220936
# End Time: 2019-03-26T10:41:43.165000Z
# Finish Point: 363 Fribourg, Planche-Inférieure, Distance from stop:77.71433280366374
#
# EDGE
# Start Time: 2019-03-26T10:41:43.165000Z
# Start Point: 363 Fribourg, Planche-Inférieure, Distance from stop:77.71433280366374
# Speed: 1.314242480778736
# Duration: 7.998000144958496
# Distance: 10.511311551778945
# End Time: 2019-03-26T10:41:51.163000Z
# Finish Point: 364 Fribourg, Planche-Inférieure, Distance from stop:87.44150594414073
#
# EDGE
# Start Time: 2019-03-26T10:41:51.163000Z
# Start Point: 364 Fribourg, Planche-Inférieure, Distance from stop:87.44150594414073
# Speed: 0.4505611531141579
# Duration: 23.000999927520752
# Distance: 10.363357050122412
# End Time: 2019-03-26T10:42:14.164000Z
# Finish Point: 365 Fribourg, Planche-Inférieure, Distance from stop:97.75437712974126
#
# EDGE
# Start Time: 2019-03-26T10:42:14.164000Z
# Start Point: 365 Fribourg, Planche-Inférieure, Distance from stop:97.75437712974126
# Speed: 1.0143247932862207
# Duration: 10.003000020980835
# Distance: 10.146290928523447
# End Time: 2019-03-26T10:42:24.167000Z
# Finish Point: 366 Fribourg, Planche-Inférieure, Distance from stop:107.61172435772738
#
# EDGE
# Start Time: 2019-03-26T10:42:24.167000Z
# Start Point: 366 Fribourg, Planche-Inférieure, Distance from stop:107.61172435772738
# Speed: 1.205207118654453
# Duration: 8.998999834060669
# Distance: 10.84565866078016
# End Time: 2019-03-26T10:42:33.166000Z
# Finish Point: 367 Fribourg, Eglise-St-Jean, Distance from stop:106.93974981929475
#
# EDGE
# Start Time: 2019-03-26T10:42:33.166000Z
# Start Point: 367 Fribourg, Eglise-St-Jean, Distance from stop:106.93974981929475
# Speed: 0.6930856627795511
# Duration: 17.005000114440918
# Distance: 11.785921774883626
# End Time: 2019-03-26T10:42:50.171000Z
# Finish Point: 368 Fribourg, Eglise-St-Jean, Distance from stop:95.19313088277507
#
# EDGE
# Start Time: 2019-03-26T10:42:50.171000Z
# Start Point: 368 Fribourg, Eglise-St-Jean, Distance from stop:95.19313088277507
# Speed: 1.1340999302844708
# Duration: 8.993000030517578
# Distance: 10.198960707658228
# End Time: 2019-03-26T10:42:59.164000Z
# Finish Point: 369 Fribourg, Eglise-St-Jean, Distance from stop:85.17649994535887
#
# EDGE
# Start Time: 2019-03-26T10:42:59.164000Z
# Start Point: 369 Fribourg, Eglise-St-Jean, Distance from stop:85.17649994535887
# Speed: 1.3274779188279733
# Duration: 9.003000020980835
# Distance: 11.951283731059839
# End Time: 2019-03-26T10:43:08.167000Z
# Finish Point: 370 Fribourg, Eglise-St-Jean, Distance from stop:75.01581029045266
#
# EDGE
# Start Time: 2019-03-26T10:43:08.167000Z
# Start Point: 370 Fribourg, Eglise-St-Jean, Distance from stop:75.01581029045266
# Speed: 1.1711050143370376
# Duration: 8.993000030517578
# Distance: 10.531747429672269
# End Time: 2019-03-26T10:43:17.160000Z
# Finish Point: 371 Fribourg, Eglise-St-Jean, Distance from stop:65.01930517307287
#
# EDGE
# Start Time: 2019-03-26T10:43:17.160000Z
# Start Point: 371 Fribourg, Eglise-St-Jean, Distance from stop:65.01930517307287
# Speed: 1.4442026148219977
# Duration: 7.0
# Distance: 10.109418303753984
# End Time: 2019-03-26T10:43:24.160000Z
# Finish Point: 372 Fribourg, Eglise-St-Jean, Distance from stop:56.10899266711632
#
# EDGE
# Start Time: 2019-03-26T10:43:24.160000Z
# Start Point: 372 Fribourg, Eglise-St-Jean, Distance from stop:56.10899266711632
# Speed: 1.1168388582891433
# Duration: 10.004999876022339
# Distance: 11.173972638719809
# End Time: 2019-03-26T10:43:34.165000Z
# Finish Point: 373 Fribourg, Eglise-St-Jean, Distance from stop:47.62879276785559
#
# EDGE
# Start Time: 2019-03-26T10:43:34.165000Z
# Start Point: 373 Fribourg, Eglise-St-Jean, Distance from stop:47.62879276785559
# Speed: 1.3214332153815502
# Duration: 7.993000030517578
# Distance: 10.562215730871673
# End Time: 2019-03-26T10:43:42.158000Z
# Finish Point: 374 Fribourg, Eglise-St-Jean, Distance from stop:44.417939971098235
#
# EDGE
# Start Time: 2019-03-26T10:43:42.158000Z
# Start Point: 374 Fribourg, Eglise-St-Jean, Distance from stop:44.417939971098235
# Speed: 0.9201300039736408
# Duration: 11.006999969482422
# Distance: 10.127870925657724
# End Time: 2019-03-26T10:43:53.165000Z
# Finish Point: 375 Fribourg, Eglise-St-Jean, Distance from stop:35.431903436930945
#
# EDGE
# Start Time: 2019-03-26T10:43:53.165000Z
# Start Point: 375 Fribourg, Eglise-St-Jean, Distance from stop:35.431903436930945
# Speed: 0.2974038662096927
# Duration: 36.99300003051758
# Distance: 11.001861231771208
# End Time: 2019-03-26T10:44:30.158000Z
# Finish Point: 376 Fribourg, Eglise-St-Jean, Distance from stop:24.48587563035638
#
# EDGE
# Start Time: 2019-03-26T10:44:30.158000Z
# Start Point: 376 Fribourg, Eglise-St-Jean, Distance from stop:24.48587563035638
# Speed: 1.2079796336501838
# Duration: 9.003999948501587
# Distance: 10.876648559177221
# End Time: 2019-03-26T10:44:39.162000Z
# Finish Point: 377 Fribourg, Eglise-St-Jean, Distance from stop:14.179696751223688
#
# EDGE
# Start Time: 2019-03-26T10:44:39.162000Z
# Start Point: 377 Fribourg, Eglise-St-Jean, Distance from stop:14.179696751223688
# Speed: 1.2502912991645705
# Duration: 8.99399995803833
# Distance: 11.245119892221837
# End Time: 2019-03-26T10:44:48.156000Z
# Finish Point: 378 Fribourg, Eglise-St-Jean, Distance from stop:5.631068273931019
#
# EDGE
# Start Time: 2019-03-26T10:44:48.156000Z
# Start Point: 378 Fribourg, Eglise-St-Jean, Distance from stop:5.631068273931019
# Speed: 1.3385473904000975
# Duration: 7.8490002155303955
# Distance: 10.506258755748014
# End Time: 2019-03-26T10:44:56.005000Z
# Finish Point: 379 Fribourg, Eglise-St-Jean, Distance from stop:13.301381490104655
#
# EDGE
# Start Time: 2019-03-26T10:44:56.005000Z
# Start Point: 379 Fribourg, Eglise-St-Jean, Distance from stop:13.301381490104655
# Speed: 3.2497764220342478
# Duration: 3.998999834060669
# Distance: 12.995855372449231
# End Time: 2019-03-26T10:45:00.004000Z
# Finish Point: 380 Fribourg, Eglise-St-Jean, Distance from stop:25.323938750020638
#
# EDGE
# Start Time: 2019-03-26T10:45:00.004000Z
# Start Point: 380 Fribourg, Eglise-St-Jean, Distance from stop:25.323938750020638
# Speed: 1.3693316079888103
# Duration: 7.998000144958496
# Distance: 10.951914399190755
# End Time: 2019-03-26T10:45:08.002000Z
# Finish Point: 381 Fribourg, Eglise-St-Jean, Distance from stop:33.73447726800601
#
# EDGE
# Start Time: 2019-03-26T10:45:08.002000Z
# Start Point: 381 Fribourg, Eglise-St-Jean, Distance from stop:33.73447726800601
# Speed: 0.9213525912356175
# Duration: 10.997999906539917
# Distance: 10.133035712299632
# End Time: 2019-03-26T10:45:19Z
# Finish Point: 382 Fribourg, Eglise-St-Jean, Distance from stop:42.95917978814305
#
# EDGE
# Start Time: 2019-03-26T10:45:19Z
# Start Point: 382 Fribourg, Eglise-St-Jean, Distance from stop:42.95917978814305
# Speed: 0.35311835163723226
# Duration: 534.4649999141693
# Distance: 188.72939977748496
# End Time: 2019-03-26T10:54:13.465000Z
# Finish Point: 383 Fribourg, Neuveville, Distance from stop:7.991357937608585

# %%
for ws in non_walk_segments:
    print('-'*100 + 'SEGMENT')
    for p in ws:
        print('EDGE')
        print('Start Time: ' + edge_df.loc[p].timestamp_s)
        print('Start Point: ' + str(edge_df.loc[p].index_s) + ' ' + edge_df.loc[p].closest_stop_name_s + ', '
              + 'Distance from stop:' +str(edge_df.loc[p].closest_stop_dist_s))
        print('Speed: '+str(edge_df.loc[p].meters_per_s))
        print('Duration: ' +str(edge_df.loc[p].duration))
        print('Distance: ' +str(edge_df.loc[p].distance))
        print('End Time: ' + edge_df.loc[p].timestamp_f)
        print('Finish Point: ' + str(edge_df.loc[p].index_f) + ' ' + edge_df.loc[p].closest_stop_name_f + ', '
              + 'Distance from stop:' +str(edge_df.loc[p].closest_stop_dist_f)+ ' \n')
# Out:
# ----------------------------------------------------------------------------------------------------SEGMENT
# EDGE
# Start Time: 2019-03-26T08:50:43Z
# Start Point: 0 Fribourg, Bethléem, Distance from stop:23.98997402080832
# Speed: 4.09118830246827
# Duration: 192.99900007247925
# Distance: 789.5952514845999
# End Time: 2019-03-26T08:53:55.999000Z
# Finish Point: 1 Villars-sur-Glâne,Villars-Vert, Distance from stop:209.9769425775891
#
# EDGE
# Start Time: 2019-03-26T08:53:55.999000Z
# Start Point: 1 Villars-sur-Glâne,Villars-Vert, Distance from stop:209.9769425775891
# Speed: 6.667774540100744
# Duration: 28.000999927520752
# Distance: 186.70435441408566
# End Time: 2019-03-26T08:54:24Z
# Finish Point: 2 Villars-sur-Glâne,Villars-Vert, Distance from stop:26.994024261590894
#
# EDGE
# Start Time: 2019-03-26T08:54:24Z
# Start Point: 2 Villars-sur-Glâne,Villars-Vert, Distance from stop:26.994024261590894
# Speed: 3.66594217108648
# Duration: 30.325999975204468
# Distance: 111.1733621894696
# End Time: 2019-03-26T08:54:54.326000Z
# Finish Point: 3 Villars-sur-Glâne,Villars-Vert, Distance from stop:56.241835727691104
#
# EDGE
# Start Time: 2019-03-26T08:54:54.326000Z
# Start Point: 3 Villars-sur-Glâne,Villars-Vert, Distance from stop:56.241835727691104
# Speed: 7.535847803242791
# Duration: 35.79699993133545
# Distance: 269.7607432952366
# End Time: 2019-03-26T08:55:30.123000Z
# Finish Point: 4 Villars-sur-Glâne, Belle-Croix, Distance from stop:221.44612757961596
#
# EDGE
# Start Time: 2019-03-26T08:55:30.123000Z
# Start Point: 4 Villars-sur-Glâne, Belle-Croix, Distance from stop:221.44612757961596
# Speed: 9.095013297345654
# Duration: 5.876000165939331
# Distance: 53.44229964442348
# End Time: 2019-03-26T08:55:35.999000Z
# Finish Point: 5 Villars-sur-Glâne, Belle-Croix, Distance from stop:169.2357816706549
#
# EDGE
# Start Time: 2019-03-26T08:55:35.999000Z
# Start Point: 5 Villars-sur-Glâne, Belle-Croix, Distance from stop:169.2357816706549
# Speed: 0.0
# Duration: 8.0
# Distance: 0.0
# End Time: 2019-03-26T08:55:43.999000Z
# Finish Point: 6 Villars-sur-Glâne, Belle-Croix, Distance from stop:169.2357816706549
#
# EDGE
# Start Time: 2019-03-26T08:55:43.999000Z
# Start Point: 6 Villars-sur-Glâne, Belle-Croix, Distance from stop:169.2357816706549
# Speed: 5.287976727468378
# Duration: 73.0
# Distance: 386.0223011051916
# End Time: 2019-03-26T08:56:56.999000Z
# Finish Point: 7 Villars-sur-Glâne, Moncor, Distance from stop:89.71673897894016
#
# EDGE
# Start Time: 2019-03-26T08:56:56.999000Z
# Start Point: 7 Villars-sur-Glâne, Moncor, Distance from stop:89.71673897894016
# Speed: 4.1056618230432
# Duration: 61.00099992752075
# Distance: 250.449476569883
# End Time: 2019-03-26T08:57:58Z
# Finish Point: 8 Villars-sur-Glâne, Moncor, Distance from stop:160.81077739256236
#
# ----------------------------------------------------------------------------------------------------SEGMENT
# EDGE
# Start Time: 2019-03-26T09:39:19.999000Z
# Start Point: 86 Villars-sur-Glâne,Rte Préalpes, Distance from stop:5.870598075517811
# Speed: 0.10787494785843495
# Duration: 97.0
# Distance: 10.46386994226819
# End Time: 2019-03-26T09:40:56.999000Z
# Finish Point: 87 Villars-sur-Glâne,Rte Préalpes, Distance from stop:15.015739390017423
#
# EDGE
# Start Time: 2019-03-26T09:40:56.999000Z
# Start Point: 87 Villars-sur-Glâne,Rte Préalpes, Distance from stop:15.015739390017423
# Speed: 5.402636465617666
# Duration: 4.0
# Distance: 21.610545862470666
# End Time: 2019-03-26T09:41:00.999000Z
# Finish Point: 88 Villars-sur-Glâne,Rte Préalpes, Distance from stop:36.44811182560444
#
# EDGE
# Start Time: 2019-03-26T09:41:00.999000Z
# Start Point: 88 Villars-sur-Glâne,Rte Préalpes, Distance from stop:36.44811182560444
# Speed: 6.915749922674608
# Duration: 3.0
# Distance: 20.747249768023824
# End Time: 2019-03-26T09:41:03.999000Z
# Finish Point: 89 Villars-sur-Glâne,Rte Préalpes, Distance from stop:56.50829749409107
#
# EDGE
# Start Time: 2019-03-26T09:41:03.999000Z
# Start Point: 89 Villars-sur-Glâne,Rte Préalpes, Distance from stop:56.50829749409107
# Speed: 7.96966978485116
# Duration: 4.0
# Distance: 31.87867913940464
# End Time: 2019-03-26T09:41:07.999000Z
# Finish Point: 90 Villars-sur-Glâne,Rte Préalpes, Distance from stop:87.84035247350627
#
# EDGE
# Start Time: 2019-03-26T09:41:07.999000Z
# Start Point: 90 Villars-sur-Glâne,Rte Préalpes, Distance from stop:87.84035247350627
# Speed: 10.731511594434352
# Duration: 3.0
# Distance: 32.194534783303055
# End Time: 2019-03-26T09:41:10.999000Z
# Finish Point: 91 Villars-sur-Glâne,Rte Préalpes, Distance from stop:119.5239243343685
#
# EDGE
# Start Time: 2019-03-26T09:41:10.999000Z
# Start Point: 91 Villars-sur-Glâne,Rte Préalpes, Distance from stop:119.5239243343685
# Speed: 11.549460247993812
# Duration: 3.0
# Distance: 34.648380743981434
# End Time: 2019-03-26T09:41:13.999000Z
# Finish Point: 92 Villars-sur-Glâne,Rte Préalpes, Distance from stop:153.84688622633948
#
# EDGE
# Start Time: 2019-03-26T09:41:13.999000Z
# Start Point: 92 Villars-sur-Glâne,Rte Préalpes, Distance from stop:153.84688622633948
# Speed: 11.895965111494045
# Duration: 3.0
# Distance: 35.687895334482135
# End Time: 2019-03-26T09:41:16.999000Z
# Finish Point: 93 Villars-sur-Glâne,Rte Préalpes, Distance from stop:189.2978436797685
#
# EDGE
# Start Time: 2019-03-26T09:41:16.999000Z
# Start Point: 93 Villars-sur-Glâne,Rte Préalpes, Distance from stop:189.2978436797685
# Speed: 11.55613699414247
# Duration: 3.0
# Distance: 34.66841098242741
# End Time: 2019-03-26T09:41:19.999000Z
# Finish Point: 94 Villars-sur-Glâne, Fenetta, Distance from stop:233.85756104570402
#
# EDGE
# Start Time: 2019-03-26T09:41:19.999000Z
# Start Point: 94 Villars-sur-Glâne, Fenetta, Distance from stop:233.85756104570402
# Speed: 11.22900369033295
# Duration: 3.0
# Distance: 33.68701107099885
# End Time: 2019-03-26T09:41:22.999000Z
# Finish Point: 95 Villars-sur-Glâne, Fenetta, Distance from stop:201.6930632160784
#
# EDGE
# Start Time: 2019-03-26T09:41:22.999000Z
# Start Point: 95 Villars-sur-Glâne, Fenetta, Distance from stop:201.6930632160784
# Speed: 11.836432107975762
# Duration: 3.0
# Distance: 35.50929632392729
# End Time: 2019-03-26T09:41:25.999000Z
# Finish Point: 96 Villars-sur-Glâne, Fenetta, Distance from stop:168.59300266004257
#
# EDGE
# Start Time: 2019-03-26T09:41:25.999000Z
# Start Point: 96 Villars-sur-Glâne, Fenetta, Distance from stop:168.59300266004257
# Speed: 11.905008744881265
# Duration: 3.0
# Distance: 35.715026234643794
# End Time: 2019-03-26T09:41:28.999000Z
# Finish Point: 97 Villars-sur-Glâne, Fenetta, Distance from stop:136.71906339858955
#
# EDGE
# Start Time: 2019-03-26T09:41:28.999000Z
# Start Point: 97 Villars-sur-Glâne, Fenetta, Distance from stop:136.71906339858955
# Speed: 10.939358318446821
# Duration: 3.0
# Distance: 32.818074955340464
# End Time: 2019-03-26T09:41:31.999000Z
# Finish Point: 98 Villars-sur-Glâne, Fenetta, Distance from stop:109.96451901396715
#
# EDGE
# Start Time: 2019-03-26T09:41:31.999000Z
# Start Point: 98 Villars-sur-Glâne, Fenetta, Distance from stop:109.96451901396715
# Speed: 9.535142011735793
# Duration: 4.0
# Distance: 38.14056804694317
# End Time: 2019-03-26T09:41:35.999000Z
# Finish Point: 99 Villars-sur-Glâne, Fenetta, Distance from stop:85.02843947785979
#
# EDGE
# Start Time: 2019-03-26T09:41:35.999000Z
# Start Point: 99 Villars-sur-Glâne, Fenetta, Distance from stop:85.02843947785979
# Speed: 6.341648874533242
# Duration: 5.0
# Distance: 31.70824437266621
# End Time: 2019-03-26T09:41:40.999000Z
# Finish Point: 100 Villars-sur-Glâne, Fenetta, Distance from stop:73.43640147250633
#
# EDGE
# Start Time: 2019-03-26T09:41:40.999000Z
# Start Point: 100 Villars-sur-Glâne, Fenetta, Distance from stop:73.43640147250633
# Speed: 3.2866133531795336
# Duration: 7.0
# Distance: 23.006293472256736
# End Time: 2019-03-26T09:41:47.999000Z
# Finish Point: 101 Villars-sur-Glâne, Fenetta, Distance from stop:68.9347594990625
#
# EDGE
# Start Time: 2019-03-26T09:41:47.999000Z
# Start Point: 101 Villars-sur-Glâne, Fenetta, Distance from stop:68.9347594990625
# Speed: 2.4637499091128103
# Duration: 6.0
# Distance: 14.782499454676861
# End Time: 2019-03-26T09:41:53.999000Z
# Finish Point: 102 Villars-sur-Glâne, Fenetta, Distance from stop:54.258835401830446
#
# EDGE
# Start Time: 2019-03-26T09:41:53.999000Z
# Start Point: 102 Villars-sur-Glâne, Fenetta, Distance from stop:54.258835401830446
# Speed: 6.895511612586773
# Duration: 3.0
# Distance: 20.68653483776032
# End Time: 2019-03-26T09:41:56.999000Z
# Finish Point: 103 Villars-sur-Glâne, Fenetta, Distance from stop:33.6321629926725
#
# EDGE
# Start Time: 2019-03-26T09:41:56.999000Z
# Start Point: 103 Villars-sur-Glâne, Fenetta, Distance from stop:33.6321629926725
# Speed: 8.848352879507917
# Duration: 4.000999927520752
# Distance: 35.40225922958921
# End Time: 2019-03-26T09:42:01Z
# Finish Point: 104 Villars-sur-Glâne, Fenetta, Distance from stop:1.8230778234920242
#
# EDGE
# Start Time: 2019-03-26T09:42:01Z
# Start Point: 104 Villars-sur-Glâne, Fenetta, Distance from stop:1.8230778234920242
# Speed: 9.611320022468766
# Duration: 4.0
# Distance: 38.44528008987506
# End Time: 2019-03-26T09:42:05Z
# Finish Point: 105 Villars-sur-Glâne, Fenetta, Distance from stop:40.12796762984589
#
# EDGE
# Start Time: 2019-03-26T09:42:05Z
# Start Point: 105 Villars-sur-Glâne, Fenetta, Distance from stop:40.12796762984589
# Speed: 10.214244067538369
# Duration: 3.0
# Distance: 30.642732202615104
# End Time: 2019-03-26T09:42:08Z
# Finish Point: 106 Villars-sur-Glâne, Coulat, Distance from stop:63.63123121084995
#
# EDGE
# Start Time: 2019-03-26T09:42:08Z
# Start Point: 106 Villars-sur-Glâne, Coulat, Distance from stop:63.63123121084995
# Speed: 8.836448010001131
# Duration: 4.0
# Distance: 35.345792040004525
# End Time: 2019-03-26T09:42:12Z
# Finish Point: 107 Villars-sur-Glâne, Coulat, Distance from stop:28.38055547778408
#
# EDGE
# Start Time: 2019-03-26T09:42:12Z
# Start Point: 107 Villars-sur-Glâne, Coulat, Distance from stop:28.38055547778408
# Speed: 8.20994362129587
# Duration: 4.0
# Distance: 32.83977448518348
# End Time: 2019-03-26T09:42:16Z
# Finish Point: 108 Villars-sur-Glâne, Coulat, Distance from stop:4.536200741023986
#
# EDGE
# Start Time: 2019-03-26T09:42:16Z
# Start Point: 108 Villars-sur-Glâne, Coulat, Distance from stop:4.536200741023986
# Speed: 7.060976308836363
# Duration: 3.0
# Distance: 21.18292892650909
# End Time: 2019-03-26T09:42:19Z
# Finish Point: 109 Villars-sur-Glâne, Coulat, Distance from stop:25.6089483147516
#
# EDGE
# Start Time: 2019-03-26T09:42:19Z
# Start Point: 109 Villars-sur-Glâne, Coulat, Distance from stop:25.6089483147516
# Speed: 6.573536068163682
# Duration: 4.0
# Distance: 26.294144272654727
# End Time: 2019-03-26T09:42:23Z
# Finish Point: 110 Villars-sur-Glâne, Coulat, Distance from stop:51.47916545448345
#
# EDGE
# Start Time: 2019-03-26T09:42:23Z
# Start Point: 110 Villars-sur-Glâne, Coulat, Distance from stop:51.47916545448345
# Speed: 7.4031209120532795
# Duration: 4.0
# Distance: 29.612483648213118
# End Time: 2019-03-26T09:42:27Z
# Finish Point: 111 Villars-sur-Glâne, Coulat, Distance from stop:79.93773555581204
#
# EDGE
# Start Time: 2019-03-26T09:42:27Z
# Start Point: 111 Villars-sur-Glâne, Coulat, Distance from stop:79.93773555581204
# Speed: 6.775441265027735
# Duration: 3.0
# Distance: 20.326323795083205
# End Time: 2019-03-26T09:42:30Z
# Finish Point: 112 Villars-sur-Glâne, Coulat, Distance from stop:100.20604332275616
#
# EDGE
# Start Time: 2019-03-26T09:42:30Z
# Start Point: 112 Villars-sur-Glâne, Coulat, Distance from stop:100.20604332275616
# Speed: 6.808691953404547
# Duration: 4.0
# Distance: 27.234767813618188
# End Time: 2019-03-26T09:42:34Z
# Finish Point: 113 Villars-sur-Glâne, Blés-d'Or, Distance from stop:80.17115733367571
#
# EDGE
# Start Time: 2019-03-26T09:42:34Z
# Start Point: 113 Villars-sur-Glâne, Blés-d'Or, Distance from stop:80.17115733367571
# Speed: 4.796596911772403
# Duration: 5.0
# Distance: 23.982984558862018
# End Time: 2019-03-26T09:42:39Z
# Finish Point: 114 Villars-sur-Glâne, Blés-d'Or, Distance from stop:64.80832676003185
#
# EDGE
# Start Time: 2019-03-26T09:42:39Z
# Start Point: 114 Villars-sur-Glâne, Blés-d'Or, Distance from stop:64.80832676003185
# Speed: 7.88235350651978
# Duration: 3.0
# Distance: 23.64706051955934
# End Time: 2019-03-26T09:42:42Z
# Finish Point: 115 Villars-sur-Glâne, Blés-d'Or, Distance from stop:54.65977505002423
#
# EDGE
# Start Time: 2019-03-26T09:42:42Z
# Start Point: 115 Villars-sur-Glâne, Blés-d'Or, Distance from stop:54.65977505002423
# Speed: 4.794494924117613
# Duration: 5.0
# Distance: 23.972474620588066
# End Time: 2019-03-26T09:42:47Z
# Finish Point: 116 Villars-sur-Glâne, Blés-d'Or, Distance from stop:30.77916168387261
#
# EDGE
# Start Time: 2019-03-26T09:42:47Z
# Start Point: 116 Villars-sur-Glâne, Blés-d'Or, Distance from stop:30.77916168387261
# Speed: 5.69054385346839
# Duration: 4.0
# Distance: 22.76217541387356
# End Time: 2019-03-26T09:42:51Z
# Finish Point: 117 Villars-sur-Glâne, Blés-d'Or, Distance from stop:8.632163416272515
#
# EDGE
# Start Time: 2019-03-26T09:42:51Z
# Start Point: 117 Villars-sur-Glâne, Blés-d'Or, Distance from stop:8.632163416272515
# Speed: 1.026664682773171
# Duration: 20.0
# Distance: 20.533293655463417
# End Time: 2019-03-26T09:43:11Z
# Finish Point: 118 Villars-sur-Glâne, Blés-d'Or, Distance from stop:13.029247250147442
#
# EDGE
# Start Time: 2019-03-26T09:43:11Z
# Start Point: 118 Villars-sur-Glâne, Blés-d'Or, Distance from stop:13.029247250147442
# Speed: 7.9344803436109785
# Duration: 3.0
# Distance: 23.803441030832936
# End Time: 2019-03-26T09:43:14Z
# Finish Point: 119 Villars-sur-Glâne, Blés-d'Or, Distance from stop:36.520462086465045
#
# EDGE
# Start Time: 2019-03-26T09:43:14Z
# Start Point: 119 Villars-sur-Glâne, Blés-d'Or, Distance from stop:36.520462086465045
# Speed: 10.30768554651973
# Duration: 3.0
# Distance: 30.923056639559192
# End Time: 2019-03-26T09:43:17Z
# Finish Point: 120 Villars-sur-Glâne, Blés-d'Or, Distance from stop:66.77789325234048
#
# EDGE
# Start Time: 2019-03-26T09:43:17Z
# Start Point: 120 Villars-sur-Glâne, Blés-d'Or, Distance from stop:66.77789325234048
# Speed: 11.264454513613943
# Duration: 3.0
# Distance: 33.79336354084183
# End Time: 2019-03-26T09:43:20Z
# Finish Point: 121 Villars-sur-Glâne, Berra, Distance from stop:61.152603355759545
#
# EDGE
# Start Time: 2019-03-26T09:43:20Z
# Start Point: 121 Villars-sur-Glâne, Berra, Distance from stop:61.152603355759545
# Speed: 10.780034229904238
# Duration: 3.0
# Distance: 32.340102689712715
# End Time: 2019-03-26T09:43:23Z
# Finish Point: 122 Villars-sur-Glâne, Berra, Distance from stop:28.858380502018157
#
# EDGE
# Start Time: 2019-03-26T09:43:23Z
# Start Point: 122 Villars-sur-Glâne, Berra, Distance from stop:28.858380502018157
# Speed: 8.543128820862604
# Duration: 4.0
# Distance: 34.172515283450416
# End Time: 2019-03-26T09:43:27Z
# Finish Point: 123 Villars-sur-Glâne, Berra, Distance from stop:5.6550114781968785
#
# EDGE
# Start Time: 2019-03-26T09:43:27Z
# Start Point: 123 Villars-sur-Glâne, Berra, Distance from stop:5.6550114781968785
# Speed: 7.584014449475138
# Duration: 4.0
# Distance: 30.33605779790055
# End Time: 2019-03-26T09:43:31Z
# Finish Point: 124 Villars-sur-Glâne, Berra, Distance from stop:35.728334381529365
#
# EDGE
# Start Time: 2019-03-26T09:43:31Z
# Start Point: 124 Villars-sur-Glâne, Berra, Distance from stop:35.728334381529365
# Speed: 12.54698346079521
# Duration: 3.0
# Distance: 37.64095038238563
# End Time: 2019-03-26T09:43:34Z
# Finish Point: 125 Villars-sur-Glâne, Berra, Distance from stop:73.2410121201648
#
# EDGE
# Start Time: 2019-03-26T09:43:34Z
# Start Point: 125 Villars-sur-Glâne, Berra, Distance from stop:73.2410121201648
# Speed: 11.313861625828778
# Duration: 3.0
# Distance: 33.941584877486335
# End Time: 2019-03-26T09:43:37Z
# Finish Point: 126 Villars-sur-Glâne, Berra, Distance from stop:107.14393497933833
#
# EDGE
# Start Time: 2019-03-26T09:43:37Z
# Start Point: 126 Villars-sur-Glâne, Berra, Distance from stop:107.14393497933833
# Speed: 11.84329287356748
# Duration: 3.0
# Distance: 35.52987862070244
# End Time: 2019-03-26T09:43:40Z
# Finish Point: 127 Villars-sur-Glâne, Berra, Distance from stop:142.6531379893131
#
# EDGE
# Start Time: 2019-03-26T09:43:40Z
# Start Point: 127 Villars-sur-Glâne, Berra, Distance from stop:142.6531379893131
# Speed: 12.161934552752761
# Duration: 3.0
# Distance: 36.485803658258284
# End Time: 2019-03-26T09:43:43Z
# Finish Point: 128 Villars-sur-Glâne, Martinets, Distance from stop:170.41322362182478
#
# EDGE
# Start Time: 2019-03-26T09:43:43Z
# Start Point: 128 Villars-sur-Glâne, Martinets, Distance from stop:170.41322362182478
# Speed: 11.724904738876923
# Duration: 3.0
# Distance: 35.17471421663077
# End Time: 2019-03-26T09:43:46Z
# Finish Point: 129 Villars-sur-Glâne, Martinets, Distance from stop:135.24788477883928
#
# EDGE
# Start Time: 2019-03-26T09:43:46Z
# Start Point: 129 Villars-sur-Glâne, Martinets, Distance from stop:135.24788477883928
# Speed: 10.97035382098411
# Duration: 3.0
# Distance: 32.91106146295233
# End Time: 2019-03-26T09:43:49Z
# Finish Point: 130 Villars-sur-Glâne, Martinets, Distance from stop:102.3782219208546
#
# EDGE
# Start Time: 2019-03-26T09:43:49Z
# Start Point: 130 Villars-sur-Glâne, Martinets, Distance from stop:102.3782219208546
# Speed: 10.62982997642789
# Duration: 3.0
# Distance: 31.889489929283673
# End Time: 2019-03-26T09:43:52Z
# Finish Point: 131 Villars-sur-Glâne, Martinets, Distance from stop:70.50691671605428
#
# EDGE
# Start Time: 2019-03-26T09:43:52Z
# Start Point: 131 Villars-sur-Glâne, Martinets, Distance from stop:70.50691671605428
# Speed: 10.294591075051496
# Duration: 3.0
# Distance: 30.88377322515449
# End Time: 2019-03-26T09:43:55Z
# Finish Point: 132 Villars-sur-Glâne, Martinets, Distance from stop:39.65191431892868
#
# EDGE
# Start Time: 2019-03-26T09:43:55Z
# Start Point: 132 Villars-sur-Glâne, Martinets, Distance from stop:39.65191431892868
# Speed: 8.292128178591577
# Duration: 4.0
# Distance: 33.16851271436631
# End Time: 2019-03-26T09:43:59Z
# Finish Point: 133 Villars-sur-Glâne, Martinets, Distance from stop:6.812224183989918
#
# EDGE
# Start Time: 2019-03-26T09:43:59Z
# Start Point: 133 Villars-sur-Glâne, Martinets, Distance from stop:6.812224183989918
# Speed: 1.6917408941124237
# Duration: 11.999000072479248
# Distance: 20.29919911107108
# End Time: 2019-03-26T09:44:10.999000Z
# Finish Point: 134 Villars-sur-Glâne, Martinets, Distance from stop:13.95879185192298
#
# EDGE
# Start Time: 2019-03-26T09:44:10.999000Z
# Start Point: 134 Villars-sur-Glâne, Martinets, Distance from stop:13.95879185192298
# Speed: 1.3532698657929505
# Duration: 8.0
# Distance: 10.826158926343604
# End Time: 2019-03-26T09:44:18.999000Z
# Finish Point: 135 Villars-sur-Glâne, Martinets, Distance from stop:24.702362287600458
#
# EDGE
# Start Time: 2019-03-26T09:44:18.999000Z
# Start Point: 135 Villars-sur-Glâne, Martinets, Distance from stop:24.702362287600458
# Speed: 6.769269458933526
# Duration: 3.0
# Distance: 20.30780837680058
# End Time: 2019-03-26T09:44:21.999000Z
# Finish Point: 136 Villars-sur-Glâne, Martinets, Distance from stop:44.95643400867542
#
# EDGE
# Start Time: 2019-03-26T09:44:21.999000Z
# Start Point: 136 Villars-sur-Glâne, Martinets, Distance from stop:44.95643400867542
# Speed: 8.515473195316309
# Duration: 4.0
# Distance: 34.061892781265236
# End Time: 2019-03-26T09:44:25.999000Z
# Finish Point: 137 Villars-sur-Glâne, Martinets, Distance from stop:78.92857983746997
#
# EDGE
# Start Time: 2019-03-26T09:44:25.999000Z
# Start Point: 137 Villars-sur-Glâne, Martinets, Distance from stop:78.92857983746997
# Speed: 8.41044574199583
# Duration: 4.0
# Distance: 33.64178296798332
# End Time: 2019-03-26T09:44:29.999000Z
# Finish Point: 138 Villars-sur-Glâne, Marteray, Distance from stop:100.49090274564537
#
# EDGE
# Start Time: 2019-03-26T09:44:29.999000Z
# Start Point: 138 Villars-sur-Glâne, Marteray, Distance from stop:100.49090274564537
# Speed: 5.56552551700317
# Duration: 4.0
# Distance: 22.26210206801268
# End Time: 2019-03-26T09:44:33.999000Z
# Finish Point: 139 Villars-sur-Glâne, Marteray, Distance from stop:78.43249995530924
#
# EDGE
# Start Time: 2019-03-26T09:44:33.999000Z
# Start Point: 139 Villars-sur-Glâne, Marteray, Distance from stop:78.43249995530924
# Speed: 3.8901147559067497
# Duration: 6.0
# Distance: 23.3406885354405
# End Time: 2019-03-26T09:44:39.999000Z
# Finish Point: 140 Villars-sur-Glâne, Marteray, Distance from stop:55.146249101743756
#
# EDGE
# Start Time: 2019-03-26T09:44:39.999000Z
# Start Point: 140 Villars-sur-Glâne, Marteray, Distance from stop:55.146249101743756
# Speed: 5.099060941166425
# Duration: 4.0
# Distance: 20.3962437646657
# End Time: 2019-03-26T09:44:43.999000Z
# Finish Point: 141 Villars-sur-Glâne, Marteray, Distance from stop:34.85484714337211
#
# EDGE
# Start Time: 2019-03-26T09:44:43.999000Z
# Start Point: 141 Villars-sur-Glâne, Marteray, Distance from stop:34.85484714337211
# Speed: 6.647491565972313
# Duration: 4.0
# Distance: 26.589966263889252
# End Time: 2019-03-26T09:44:47.999000Z
# Finish Point: 142 Villars-sur-Glâne, Marteray, Distance from stop:8.426293464644028
#
# EDGE
# Start Time: 2019-03-26T09:44:47.999000Z
# Start Point: 142 Villars-sur-Glâne, Marteray, Distance from stop:8.426293464644028
# Speed: 6.090786169327962
# Duration: 4.0
# Distance: 24.363144677311848
# End Time: 2019-03-26T09:44:51.999000Z
# Finish Point: 143 Villars-sur-Glâne, Marteray, Distance from stop:16.193240167439793
#
# EDGE
# Start Time: 2019-03-26T09:44:51.999000Z
# Start Point: 143 Villars-sur-Glâne, Marteray, Distance from stop:16.193240167439793
# Speed: 6.524912406808689
# Duration: 4.0
# Distance: 26.099649627234754
# End Time: 2019-03-26T09:44:55.999000Z
# Finish Point: 144 Villars-sur-Glâne, Marteray, Distance from stop:42.190861154123105
#
# EDGE
# Start Time: 2019-03-26T09:44:55.999000Z
# Start Point: 144 Villars-sur-Glâne, Marteray, Distance from stop:42.190861154123105
# Speed: 6.812631175968729
# Duration: 3.0
# Distance: 20.437893527906187
# End Time: 2019-03-26T09:44:58.999000Z
# Finish Point: 145 Villars-sur-Glâne, Marteray, Distance from stop:62.59093747408356
#
# EDGE
# Start Time: 2019-03-26T09:44:58.999000Z
# Start Point: 145 Villars-sur-Glâne, Marteray, Distance from stop:62.59093747408356
# Speed: 7.583579474104396
# Duration: 3.0
# Distance: 22.750738422313187
# End Time: 2019-03-26T09:45:01.999000Z
# Finish Point: 146 Villars-sur-Glâne, Marteray, Distance from stop:85.31342947461316
#
# EDGE
# Start Time: 2019-03-26T09:45:01.999000Z
# Start Point: 146 Villars-sur-Glâne, Marteray, Distance from stop:85.31342947461316
# Speed: 7.636015793262506
# Duration: 4.0
# Distance: 30.544063173050024
# End Time: 2019-03-26T09:45:05.999000Z
# Finish Point: 147 Villars-sur-Glâne, Marteray, Distance from stop:115.8195086243255
#
# EDGE
# Start Time: 2019-03-26T09:45:05.999000Z
# Start Point: 147 Villars-sur-Glâne, Marteray, Distance from stop:115.8195086243255
# Speed: 7.775582683898717
# Duration: 4.0
# Distance: 31.10233073559487
# End Time: 2019-03-26T09:45:09.999000Z
# Finish Point: 148 Villars-sur-Glâne, Marteray, Distance from stop:146.89220406307462
#
# EDGE
# Start Time: 2019-03-26T09:45:09.999000Z
# Start Point: 148 Villars-sur-Glâne, Marteray, Distance from stop:146.89220406307462
# Speed: 7.851898851634487
# Duration: 4.0
# Distance: 31.407595406537947
# End Time: 2019-03-26T09:45:13.999000Z
# Finish Point: 149 Villars-sur-Glâne, Marteray, Distance from stop:178.29244539613381
#
# EDGE
# Start Time: 2019-03-26T09:45:13.999000Z
# Start Point: 149 Villars-sur-Glâne, Marteray, Distance from stop:178.29244539613381
# Speed: 7.632374986547797
# Duration: 4.0
# Distance: 30.529499946191187
# End Time: 2019-03-26T09:45:17.999000Z
# Finish Point: 150 Fribourg, Rte de la Glâne, Distance from stop:151.3637976728006
#
# EDGE
# Start Time: 2019-03-26T09:45:17.999000Z
# Start Point: 150 Fribourg, Rte de la Glâne, Distance from stop:151.3637976728006
# Speed: 2.9637106689221686
# Duration: 7.0
# Distance: 20.74597468245518
# End Time: 2019-03-26T09:45:24.999000Z
# Finish Point: 151 Fribourg, Rte de la Glâne, Distance from stop:130.85222996819945
#
# EDGE
# Start Time: 2019-03-26T09:45:24.999000Z
# Start Point: 151 Fribourg, Rte de la Glâne, Distance from stop:130.85222996819945
# Speed: 1.8717570560193524
# Duration: 11.0
# Distance: 20.589327616212877
# End Time: 2019-03-26T09:45:35.999000Z
# Finish Point: 152 Fribourg, Rte de la Glâne, Distance from stop:128.13924405518753
#
# EDGE
# Start Time: 2019-03-26T09:45:35.999000Z
# Start Point: 152 Fribourg, Rte de la Glâne, Distance from stop:128.13924405518753
# Speed: 0.2279956535335571
# Duration: 45.0
# Distance: 10.25980440901007
# End Time: 2019-03-26T09:46:20.999000Z
# Finish Point: 153 Fribourg, Rte de la Glâne, Distance from stop:135.42593225769608
#
# EDGE
# Start Time: 2019-03-26T09:46:20.999000Z
# Start Point: 153 Fribourg, Rte de la Glâne, Distance from stop:135.42593225769608
# Speed: 1.645892669505244
# Duration: 17.0
# Distance: 27.98017538158915
# End Time: 2019-03-26T09:46:37.999000Z
# Finish Point: 154 Fribourg, Rte de la Glâne, Distance from stop:127.69422407659329
#
# EDGE
# Start Time: 2019-03-26T09:46:37.999000Z
# Start Point: 154 Fribourg, Rte de la Glâne, Distance from stop:127.69422407659329
# Speed: 4.0288939909162
# Duration: 5.0
# Distance: 20.144469954580998
# End Time: 2019-03-26T09:46:42.999000Z
# Finish Point: 155 Fribourg, Rte de la Glâne, Distance from stop:114.35078742107731
#
# EDGE
# Start Time: 2019-03-26T09:46:42.999000Z
# Start Point: 155 Fribourg, Rte de la Glâne, Distance from stop:114.35078742107731
# Speed: 5.931729024864192
# Duration: 4.0
# Distance: 23.72691609945677
# End Time: 2019-03-26T09:46:46.999000Z
# Finish Point: 156 Fribourg, Rte de la Glâne, Distance from stop:106.69530325036871
#
# EDGE
# Start Time: 2019-03-26T09:46:46.999000Z
# Start Point: 156 Fribourg, Rte de la Glâne, Distance from stop:106.69530325036871
# Speed: 6.97127083223125
# Duration: 4.0
# Distance: 27.885083328925
# End Time: 2019-03-26T09:46:50.999000Z
# Finish Point: 157 Fribourg, Champriond, Distance from stop:121.64077255129791
#
# EDGE
# Start Time: 2019-03-26T09:46:50.999000Z
# Start Point: 157 Fribourg, Champriond, Distance from stop:121.64077255129791
# Speed: 10.248215115818068
# Duration: 3.0
# Distance: 30.744645347454203
# End Time: 2019-03-26T09:46:53.999000Z
# Finish Point: 158 Fribourg, Champriond, Distance from stop:91.03273435174712
#
# EDGE
# Start Time: 2019-03-26T09:46:53.999000Z
# Start Point: 158 Fribourg, Champriond, Distance from stop:91.03273435174712
# Speed: 10.258959886635926
# Duration: 3.0
# Distance: 30.776879659907777
# End Time: 2019-03-26T09:46:56.999000Z
# Finish Point: 159 Fribourg, Champriond, Distance from stop:60.39622482984856
#
# EDGE
# Start Time: 2019-03-26T09:46:56.999000Z
# Start Point: 159 Fribourg, Champriond, Distance from stop:60.39622482984856
# Speed: 8.762307683155912
# Duration: 4.0
# Distance: 35.04923073262365
# End Time: 2019-03-26T09:47:00.999000Z
# Finish Point: 160 Fribourg, Champriond, Distance from stop:25.53399045976846
#
# EDGE
# Start Time: 2019-03-26T09:47:00.999000Z
# Start Point: 160 Fribourg, Champriond, Distance from stop:25.53399045976846
# Speed: 4.15256004708616
# Duration: 5.0
# Distance: 20.762800235430802
# End Time: 2019-03-26T09:47:05.999000Z
# Finish Point: 161 Fribourg, Champriond, Distance from stop:4.811390382369072
#
# EDGE
# Start Time: 2019-03-26T09:47:05.999000Z
# Start Point: 161 Fribourg, Champriond, Distance from stop:4.811390382369072
# Speed: 4.0258921842043405
# Duration: 5.0
# Distance: 20.129460921021703
# End Time: 2019-03-26T09:47:10.999000Z
# Finish Point: 162 Fribourg, Champriond, Distance from stop:15.433547967938162
#
# EDGE
# Start Time: 2019-03-26T09:47:10.999000Z
# Start Point: 162 Fribourg, Champriond, Distance from stop:15.433547967938162
# Speed: 3.435071929460616
# Duration: 6.0
# Distance: 20.610431576763695
# End Time: 2019-03-26T09:47:16.999000Z
# Finish Point: 163 Fribourg, Champriond, Distance from stop:36.03527964550481
#
# EDGE
# Start Time: 2019-03-26T09:47:16.999000Z
# Start Point: 163 Fribourg, Champriond, Distance from stop:36.03527964550481
# Speed: 0.26417500544619954
# Duration: 38.00099992752075
# Distance: 10.038914362813824
# End Time: 2019-03-26T09:47:55Z
# Finish Point: 164 Fribourg, Champriond, Distance from stop:46.07278660996926
#
# EDGE
# Start Time: 2019-03-26T09:47:55Z
# Start Point: 164 Fribourg, Champriond, Distance from stop:46.07278660996926
# Speed: 0.8002030489004047
# Duration: 13.0
# Distance: 10.402639635705262
# End Time: 2019-03-26T09:48:08Z
# Finish Point: 165 Fribourg, Champriond, Distance from stop:56.47448395322474
#
# EDGE
# Start Time: 2019-03-26T09:48:08Z
# Start Point: 165 Fribourg, Champriond, Distance from stop:56.47448395322474
# Speed: 0.35852164498784
# Duration: 33.0
# Distance: 11.83121428459872
# End Time: 2019-03-26T09:48:41Z
# Finish Point: 166 Fribourg, Champriond, Distance from stop:68.30498135164544
#
# EDGE
# Start Time: 2019-03-26T09:48:41Z
# Start Point: 166 Fribourg, Champriond, Distance from stop:68.30498135164544
# Speed: 3.1794593307529806
# Duration: 8.0
# Distance: 25.435674646023845
# End Time: 2019-03-26T09:48:49Z
# Finish Point: 167 Fribourg, Champriond, Distance from stop:93.73957283145816
#
# EDGE
# Start Time: 2019-03-26T09:48:49Z
# Start Point: 167 Fribourg, Champriond, Distance from stop:93.73957283145816
# Speed: 4.4037736966865975
# Duration: 5.0
# Distance: 22.01886848343299
# End Time: 2019-03-26T09:48:54Z
# Finish Point: 168 Fribourg, Beaumont-Centre, Distance from stop:78.60801391402025
#
# EDGE
# Start Time: 2019-03-26T09:48:54Z
# Start Point: 168 Fribourg, Beaumont-Centre, Distance from stop:78.60801391402025
# Speed: 4.3380434205152145
# Duration: 5.0
# Distance: 21.690217102576074
# End Time: 2019-03-26T09:48:59Z
# Finish Point: 169 Fribourg, Beaumont-Centre, Distance from stop:61.90355696554956
#
# EDGE
# Start Time: 2019-03-26T09:48:59Z
# Start Point: 169 Fribourg, Beaumont-Centre, Distance from stop:61.90355696554956
# Speed: 5.630887852231157
# Duration: 4.0
# Distance: 22.52355140892463
# End Time: 2019-03-26T09:49:03Z
# Finish Point: 170 Fribourg, Beaumont-Centre, Distance from stop:49.646476899373184
#
# EDGE
# Start Time: 2019-03-26T09:49:03Z
# Start Point: 170 Fribourg, Beaumont-Centre, Distance from stop:49.646476899373184
# Speed: 5.188443371647273
# Duration: 5.0
# Distance: 25.942216858236367
# End Time: 2019-03-26T09:49:08Z
# Finish Point: 171 Fribourg, Beaumont-Centre, Distance from stop:49.330834992500805
#
# EDGE
# Start Time: 2019-03-26T09:49:08Z
# Start Point: 171 Fribourg, Beaumont-Centre, Distance from stop:49.330834992500805
# Speed: 4.420909155321152
# Duration: 5.0
# Distance: 22.10454577660576
# End Time: 2019-03-26T09:49:13Z
# Finish Point: 172 Fribourg, Beaumont-Est, Distance from stop:55.77445694558353
#
# EDGE
# Start Time: 2019-03-26T09:49:13Z
# Start Point: 172 Fribourg, Beaumont-Est, Distance from stop:55.77445694558353
# Speed: 0.373875233274949
# Duration: 30.0
# Distance: 11.21625699824847
# End Time: 2019-03-26T09:49:43Z
# Finish Point: 173 Fribourg, Beaumont-Est, Distance from stop:45.456078943255456
#
# EDGE
# Start Time: 2019-03-26T09:49:43Z
# Start Point: 173 Fribourg, Beaumont-Est, Distance from stop:45.456078943255456
# Speed: 4.2514762403243385
# Duration: 107.25
# Distance: 455.97082677478534
# End Time: 2019-03-26T09:51:30.250000Z
# Finish Point: 174 Fribourg, Passage du Cardinal, Distance from stop:31.296828346879586
#
# EDGE
# Start Time: 2019-03-26T09:51:30.250000Z
# Start Point: 174 Fribourg, Passage du Cardinal, Distance from stop:31.296828346879586
# Speed: 17.039162925778854
# Duration: 5.75
# Distance: 97.97518682322841
# End Time: 2019-03-26T09:51:36Z
# Finish Point: 175 Fribourg, Passage du Cardinal, Distance from stop:103.61069053818673
#
# EDGE
# Start Time: 2019-03-26T09:51:36Z
# Start Point: 175 Fribourg, Passage du Cardinal, Distance from stop:103.61069053818673
# Speed: 11.833278234143293
# Duration: 3.0
# Distance: 35.49983470242988
# End Time: 2019-03-26T09:51:39Z
# Finish Point: 176 Fribourg, Midi, Distance from stop:94.64193330999608
#
# EDGE
# Start Time: 2019-03-26T09:51:39Z
# Start Point: 176 Fribourg, Midi, Distance from stop:94.64193330999608
# Speed: 12.33943089268242
# Duration: 3.0
# Distance: 37.01829267804726
# End Time: 2019-03-26T09:51:42Z
# Finish Point: 177 Fribourg, Midi, Distance from stop:57.652900193956874
#
# EDGE
# Start Time: 2019-03-26T09:51:42Z
# Start Point: 177 Fribourg, Midi, Distance from stop:57.652900193956874
# Speed: 10.846965776467286
# Duration: 3.0
# Distance: 32.54089732940186
# End Time: 2019-03-26T09:51:45Z
# Finish Point: 178 Fribourg, Midi, Distance from stop:25.209699206380968
#
# EDGE
# Start Time: 2019-03-26T09:51:45Z
# Start Point: 178 Fribourg, Midi, Distance from stop:25.209699206380968
# Speed: 8.146310135201931
# Duration: 4.0
# Distance: 32.585240540807725
# End Time: 2019-03-26T09:51:49Z
# Finish Point: 179 Fribourg, Midi, Distance from stop:9.897318120540987
#
# EDGE
# Start Time: 2019-03-26T09:51:49Z
# Start Point: 179 Fribourg, Midi, Distance from stop:9.897318120540987
# Speed: 2.0584658373635105
# Duration: 10.0
# Distance: 20.584658373635104
# End Time: 2019-03-26T09:51:59Z
# Finish Point: 180 Fribourg, Midi, Distance from stop:29.526369962026674
#
# EDGE
# Start Time: 2019-03-26T09:51:59Z
# Start Point: 180 Fribourg, Midi, Distance from stop:29.526369962026674
# Speed: 1.1879585825954182
# Duration: 13.0
# Distance: 15.443461573740436
# End Time: 2019-03-26T09:52:12Z
# Finish Point: 181 Fribourg, Midi, Distance from stop:44.16755126127349
#
# EDGE
# Start Time: 2019-03-26T09:52:12Z
# Start Point: 181 Fribourg, Midi, Distance from stop:44.16755126127349
# Speed: 6.418426721204043
# Duration: 4.0
# Distance: 25.673706884816173
# End Time: 2019-03-26T09:52:16Z
# Finish Point: 182 Fribourg, Midi, Distance from stop:67.64517283350582
#
# EDGE
# Start Time: 2019-03-26T09:52:16Z
# Start Point: 182 Fribourg, Midi, Distance from stop:67.64517283350582
# Speed: 6.946646190280217
# Duration: 3.0
# Distance: 20.83993857084065
# End Time: 2019-03-26T09:52:19Z
# Finish Point: 183 Fribourg, Midi, Distance from stop:88.14802978259544
#
# EDGE
# Start Time: 2019-03-26T09:52:19Z
# Start Point: 183 Fribourg, Midi, Distance from stop:88.14802978259544
# Speed: 5.297854828667906
# Duration: 4.0
# Distance: 21.191419314671624
# End Time: 2019-03-26T09:52:23Z
# Finish Point: 184 Fribourg, Midi, Distance from stop:109.26994754447547
#
# EDGE
# Start Time: 2019-03-26T09:52:23Z
# Start Point: 184 Fribourg, Midi, Distance from stop:109.26994754447547
# Speed: 6.375464519414401
# Duration: 4.0
# Distance: 25.501858077657605
# End Time: 2019-03-26T09:52:27Z
# Finish Point: 185 Fribourg, Midi, Distance from stop:134.68927860014512
#
# EDGE
# Start Time: 2019-03-26T09:52:27Z
# Start Point: 185 Fribourg, Midi, Distance from stop:134.68927860014512
# Speed: 6.737988419839124
# Duration: 3.0
# Distance: 20.213965259517373
# End Time: 2019-03-26T09:52:30Z
# Finish Point: 186 Fribourg, Midi, Distance from stop:154.86261705123104
#
# EDGE
# Start Time: 2019-03-26T09:52:30Z
# Start Point: 186 Fribourg, Midi, Distance from stop:154.86261705123104
# Speed: 6.4364972433398595
# Duration: 4.0
# Distance: 25.745988973359438
# End Time: 2019-03-26T09:52:34Z
# Finish Point: 187 Fribourg, Beauregard, Distance from stop:175.82956954380947
#
# EDGE
# Start Time: 2019-03-26T09:52:34Z
# Start Point: 187 Fribourg, Beauregard, Distance from stop:175.82956954380947
# Speed: 6.031138426176687
# Duration: 5.0
# Distance: 30.155692130883434
# End Time: 2019-03-26T09:52:39Z
# Finish Point: 188 Fribourg, gare, Distance from stop:153.5995907587416
#
# EDGE
# Start Time: 2019-03-26T09:52:39Z
# Start Point: 188 Fribourg, gare, Distance from stop:153.5995907587416
# Speed: 5.304384087276239
# Duration: 4.0
# Distance: 21.217536349104957
# End Time: 2019-03-26T09:52:43Z
# Finish Point: 189 Fribourg, gare, Distance from stop:132.59844930362564
#
# EDGE
# Start Time: 2019-03-26T09:52:43Z
# Start Point: 189 Fribourg, gare, Distance from stop:132.59844930362564
# Speed: 3.127666147533446
# Duration: 7.0
# Distance: 21.89366303273412
# End Time: 2019-03-26T09:52:50Z
# Finish Point: 190 Fribourg, gare, Distance from stop:111.06331221076137
#
# EDGE
# Start Time: 2019-03-26T09:52:50Z
# Start Point: 190 Fribourg, gare, Distance from stop:111.06331221076137
# Speed: 5.436691969872033
# Duration: 2.0
# Distance: 10.873383939744066
# End Time: 2019-03-26T09:52:52Z
# Finish Point: 191 Fribourg, gare, Distance from stop:100.42368873746392
#
# EDGE
# Start Time: 2019-03-26T09:52:52Z
# Start Point: 191 Fribourg, gare, Distance from stop:100.42368873746392
# Speed: 2.406888730115679
# Duration: 46.0
# Distance: 110.71688158532123
# End Time: 2019-03-26T09:53:38Z
# Finish Point: 192 Fribourg, gare CFF, Distance from stop:60.30905288808251
#
# ----------------------------------------------------------------------------------------------------SEGMENT
# EDGE
# Start Time: 2019-03-26T09:55:41Z
# Start Point: 198 Fribourg, gare CFF, Distance from stop:13.100134280428064
# Speed: 3.3595752131367322
# Duration: 3.0
# Distance: 10.078725639410196
# End Time: 2019-03-26T09:55:44Z
# Finish Point: 199 Fribourg, gare CFF, Distance from stop:19.15311050365862
#
# EDGE
# Start Time: 2019-03-26T09:55:44Z
# Start Point: 199 Fribourg, gare CFF, Distance from stop:19.15311050365862
# Speed: 1.752530100784524
# Duration: 12.0
# Distance: 21.030361209414288
# End Time: 2019-03-26T09:55:56Z
# Finish Point: 200 Fribourg, gare CFF, Distance from stop:36.28983411072681
#
# EDGE
# Start Time: 2019-03-26T09:55:56Z
# Start Point: 200 Fribourg, gare CFF, Distance from stop:36.28983411072681
# Speed: 3.1640777111402123
# Duration: 4.0
# Distance: 12.65631084456085
# End Time: 2019-03-26T09:56:00Z
# Finish Point: 201 Fribourg, gare CFF, Distance from stop:47.87156252318644
#
# EDGE
# Start Time: 2019-03-26T09:56:00Z
# Start Point: 201 Fribourg, gare CFF, Distance from stop:47.87156252318644
# Speed: 5.8385580894866145
# Duration: 4.0
# Distance: 23.354232357946458
# End Time: 2019-03-26T09:56:04Z
# Finish Point: 202 Fribourg, gare CFF, Distance from stop:70.53253251522864
#
# EDGE
# Start Time: 2019-03-26T09:56:04Z
# Start Point: 202 Fribourg, gare CFF, Distance from stop:70.53253251522864
# Speed: 7.14223468204657
# Duration: 3.0
# Distance: 21.426704046139708
# End Time: 2019-03-26T09:56:07Z
# Finish Point: 203 Fribourg, gare CFF, Distance from stop:91.48669291531823
#
# EDGE
# Start Time: 2019-03-26T09:56:07Z
# Start Point: 203 Fribourg, gare CFF, Distance from stop:91.48669291531823
# Speed: 6.752285320115651
# Duration: 3.0
# Distance: 20.256855960346954
# End Time: 2019-03-26T09:56:10Z
# Finish Point: 204 Fribourg, Tivoli, Distance from stop:103.15963898945009
#
# EDGE
# Start Time: 2019-03-26T09:56:10Z
# Start Point: 204 Fribourg, Tivoli, Distance from stop:103.15963898945009
# Speed: 6.347527205622431
# Duration: 4.0
# Distance: 25.390108822489722
# End Time: 2019-03-26T09:56:14Z
# Finish Point: 205 Fribourg, Tivoli, Distance from stop:110.39390644258872
#
# EDGE
# Start Time: 2019-03-26T09:56:14Z
# Start Point: 205 Fribourg, Tivoli, Distance from stop:110.39390644258872
# Speed: 5.943250500923841
# Duration: 4.0
# Distance: 23.773002003695364
# End Time: 2019-03-26T09:56:18Z
# Finish Point: 206 Fribourg, Tivoli, Distance from stop:125.69353363586691
#
# EDGE
# Start Time: 2019-03-26T09:56:18Z
# Start Point: 206 Fribourg, Tivoli, Distance from stop:125.69353363586691
# Speed: 4.282098173895752
# Duration: 5.0
# Distance: 21.41049086947876
# End Time: 2019-03-26T09:56:23Z
# Finish Point: 207 Fribourg, St-Pierre, Distance from stop:147.12786119230293
#
# EDGE
# Start Time: 2019-03-26T09:56:23Z
# Start Point: 207 Fribourg, St-Pierre, Distance from stop:147.12786119230293
# Speed: 3.5871986648253977
# Duration: 6.0
# Distance: 21.523191988952387
# End Time: 2019-03-26T09:56:29Z
# Finish Point: 208 Fribourg, St-Pierre, Distance from stop:136.23709911107468
#
# EDGE
# Start Time: 2019-03-26T09:56:29Z
# Start Point: 208 Fribourg, St-Pierre, Distance from stop:136.23709911107468
# Speed: 2.9962167848221695
# Duration: 8.000999927520752
# Distance: 23.97273027819864
# End Time: 2019-03-26T09:56:37.001000Z
# Finish Point: 209 Fribourg, St-Pierre, Distance from stop:127.7996249202325
#
# EDGE
# Start Time: 2019-03-26T09:56:37.001000Z
# Start Point: 209 Fribourg, St-Pierre, Distance from stop:127.7996249202325
# Speed: 2.915261813222879
# Duration: 7.0
# Distance: 20.40683269256015
# End Time: 2019-03-26T09:56:44.001000Z
# Finish Point: 210 Fribourg, St-Pierre, Distance from stop:113.69019861859323
#
# EDGE
# Start Time: 2019-03-26T09:56:44.001000Z
# Start Point: 210 Fribourg, St-Pierre, Distance from stop:113.69019861859323
# Speed: 4.73254782590806
# Duration: 5.0
# Distance: 23.6627391295403
# End Time: 2019-03-26T09:56:49.001000Z
# Finish Point: 211 Fribourg, St-Pierre, Distance from stop:90.18648437527688
#
# EDGE
# Start Time: 2019-03-26T09:56:49.001000Z
# Start Point: 211 Fribourg, St-Pierre, Distance from stop:90.18648437527688
# Speed: 3.1604757114132775
# Duration: 7.0
# Distance: 22.123329979892944
# End Time: 2019-03-26T09:56:56.001000Z
# Finish Point: 212 Fribourg, St-Pierre, Distance from stop:69.76036020984341
#
# EDGE
# Start Time: 2019-03-26T09:56:56.001000Z
# Start Point: 212 Fribourg, St-Pierre, Distance from stop:69.76036020984341
# Speed: 3.4735294123233733
# Duration: 3.0
# Distance: 10.42058823697012
# End Time: 2019-03-26T09:56:59.001000Z
# Finish Point: 213 Fribourg, St-Pierre, Distance from stop:60.6138601736356
#
# EDGE
# Start Time: 2019-03-26T09:56:59.001000Z
# Start Point: 213 Fribourg, St-Pierre, Distance from stop:60.6138601736356
# Speed: 3.556619795875365
# Duration: 3.0
# Distance: 10.669859387626095
# End Time: 2019-03-26T09:57:02.001000Z
# Finish Point: 214 Fribourg, St-Pierre, Distance from stop:52.17576888728133
#
# EDGE
# Start Time: 2019-03-26T09:57:02.001000Z
# Start Point: 214 Fribourg, St-Pierre, Distance from stop:52.17576888728133
# Speed: 4.149689504898067
# Duration: 3.0
# Distance: 12.4490685146942
# End Time: 2019-03-26T09:57:05.001000Z
# Finish Point: 215 Fribourg, St-Pierre, Distance from stop:42.24316634631226
#
# EDGE
# Start Time: 2019-03-26T09:57:05.001000Z
# Start Point: 215 Fribourg, St-Pierre, Distance from stop:42.24316634631226
# Speed: 3.440442415300455
# Duration: 3.0
# Distance: 10.321327245901365
# End Time: 2019-03-26T09:57:08.001000Z
# Finish Point: 216 Fribourg, St-Pierre, Distance from stop:33.9438316376357
#
# EDGE
# Start Time: 2019-03-26T09:57:08.001000Z
# Start Point: 216 Fribourg, St-Pierre, Distance from stop:33.9438316376357
# Speed: 1.7648142788681604
# Duration: 8.0
# Distance: 14.118514230945284
# End Time: 2019-03-26T09:57:16.001000Z
# Finish Point: 217 Fribourg, St-Pierre, Distance from stop:25.78966393312327
#
# EDGE
# Start Time: 2019-03-26T09:57:16.001000Z
# Start Point: 217 Fribourg, St-Pierre, Distance from stop:25.78966393312327
# Speed: 5.030935154662227
# Duration: 2.0
# Distance: 10.061870309324455
# End Time: 2019-03-26T09:57:18.001000Z
# Finish Point: 218 Fribourg, St-Pierre, Distance from stop:25.56230040684685
#
# EDGE
# Start Time: 2019-03-26T09:57:18.001000Z
# Start Point: 218 Fribourg, St-Pierre, Distance from stop:25.56230040684685
# Speed: 2.755689085508805
# Duration: 4.0
# Distance: 11.02275634203522
# End Time: 2019-03-26T09:57:22.001000Z
# Finish Point: 219 Fribourg, St-Pierre, Distance from stop:29.19976836607284
#
# EDGE
# Start Time: 2019-03-26T09:57:22.001000Z
# Start Point: 219 Fribourg, St-Pierre, Distance from stop:29.19976836607284
# Speed: 2.8592760672993904
# Duration: 5.0
# Distance: 14.296380336496952
# End Time: 2019-03-26T09:57:27.001000Z
# Finish Point: 220 Fribourg, St-Pierre, Distance from stop:33.18244103001232
#
# ----------------------------------------------------------------------------------------------------SEGMENT
# EDGE
# Start Time: 2019-03-26T10:05:46.999000Z
# Start Point: 266 Fribourg, Université, Distance from stop:4.624426754904689
# Speed: 1.0689308467921017
# Duration: 250.0899999141693
# Distance: 267.32891538248964
# End Time: 2019-03-26T10:09:57.089000Z
# Finish Point: 267 Fribourg, Place Georges Python, Distance from stop:69.7570212518722
#
# EDGE
# Start Time: 2019-03-26T10:09:57.089000Z
# Start Point: 267 Fribourg, Place Georges Python, Distance from stop:69.7570212518722
# Speed: 13.275322209582123
# Duration: 4.974999904632568
# Distance: 66.04472672663768
# End Time: 2019-03-26T10:10:02.064000Z
# Finish Point: 268 Fribourg, Place Georges Python, Distance from stop:52.02908881755284
#
# EDGE
# Start Time: 2019-03-26T10:10:02.064000Z
# Start Point: 268 Fribourg, Place Georges Python, Distance from stop:52.02908881755284
# Speed: 28.77414806559281
# Duration: 2.116000175476074
# Distance: 60.88610235596893
# End Time: 2019-03-26T10:10:04.180000Z
# Finish Point: 269 Fribourg, Place Georges Python, Distance from stop:51.743656391879384
#
# EDGE
# Start Time: 2019-03-26T10:10:04.180000Z
# Start Point: 269 Fribourg, Place Georges Python, Distance from stop:51.743656391879384
# Speed: 0.5237831988913608
# Duration: 32.819000005722046
# Distance: 17.190040807412682
# End Time: 2019-03-26T10:10:36.999000Z
# Finish Point: 270 Fribourg, Place Georges Python, Distance from stop:35.67210936668827
#
# EDGE
# Start Time: 2019-03-26T10:10:36.999000Z
# Start Point: 270 Fribourg, Place Georges Python, Distance from stop:35.67210936668827
# Speed: 1.6235732883465694
# Duration: 213.96599984169006
# Distance: 347.3894819573343
# End Time: 2019-03-26T10:14:10.965000Z
# Finish Point: 271 Fribourg, gare CFF, Distance from stop:38.19474254753702
#
# EDGE
# Start Time: 2019-03-26T10:14:10.965000Z
# Start Point: 271 Fribourg, gare CFF, Distance from stop:38.19474254753702
# Speed: 11.683149845214427
# Duration: 6.03600001335144
# Distance: 70.51949262170116
# End Time: 2019-03-26T10:14:17.001000Z
# Finish Point: 272 Fribourg, gare CFF, Distance from stop:36.26680854039285
#
# EDGE
# Start Time: 2019-03-26T10:14:17.001000Z
# Start Point: 272 Fribourg, gare CFF, Distance from stop:36.26680854039285
# Speed: 3.438884560724545
# Duration: 7.0
# Distance: 24.072191925071813
# End Time: 2019-03-26T10:14:24.001000Z
# Finish Point: 273 Fribourg, gare CFF, Distance from stop:17.124881402754156
#
# ----------------------------------------------------------------------------------------------------SEGMENT
# EDGE
# Start Time: 2019-03-26T10:17:14.001000Z
# Start Point: 279 Fribourg, gare CFF, Distance from stop:44.51484556753066
# Speed: 15.025899433382396
# Duration: 4.6570000648498535
# Distance: 69.9756146356892
# End Time: 2019-03-26T10:17:18.658000Z
# Finish Point: 280 Fribourg, gare CFF, Distance from stop:11.992451579837416
#
# EDGE
# Start Time: 2019-03-26T10:17:18.658000Z
# Start Point: 280 Fribourg, gare CFF, Distance from stop:11.992451579837416
# Speed: 8.423964271508412
# Duration: 10.342000007629395
# Distance: 87.12063856020974
# End Time: 2019-03-26T10:17:29Z
# Finish Point: 281 Fribourg, gare CFF, Distance from stop:2.639618364778133
#
# EDGE
# Start Time: 2019-03-26T10:17:29Z
# Start Point: 281 Fribourg, gare CFF, Distance from stop:2.639618364778133
# Speed: 3.7631140423096774
# Duration: 9.000999927520752
# Distance: 33.87178922208173
# End Time: 2019-03-26T10:17:38.001000Z
# Finish Point: 282 Fribourg, gare CFF, Distance from stop:9.125334276077004
#
# EDGE
# Start Time: 2019-03-26T10:17:38.001000Z
# Start Point: 282 Fribourg, gare CFF, Distance from stop:9.125334276077004
# Speed: 1.497648005711149
# Duration: 7.0
# Distance: 10.483536039978043
# End Time: 2019-03-26T10:17:45.001000Z
# Finish Point: 283 Fribourg, gare CFF, Distance from stop:18.897834075807076
#
# EDGE
# Start Time: 2019-03-26T10:17:45.001000Z
# Start Point: 283 Fribourg, gare CFF, Distance from stop:18.897834075807076
# Speed: 0.9601458117079327
# Duration: 403.26900005340576
# Distance: 387.1970413929236
# End Time: 2019-03-26T10:24:28.270000Z
# Finish Point: 284 Fribourg, St-Pierre, Distance from stop:263.02936492059234
#
# EDGE
# Start Time: 2019-03-26T10:24:28.270000Z
# Start Point: 284 Fribourg, St-Pierre, Distance from stop:263.02936492059234
# Speed: 6.917691466861749
# Duration: 4.733000040054321
# Distance: 32.741433989740095
# End Time: 2019-03-26T10:24:33.003000Z
# Finish Point: 285 Fribourg, St-Pierre, Distance from stop:253.57564229326258
#
# EDGE
# Start Time: 2019-03-26T10:24:33.003000Z
# Start Point: 285 Fribourg, St-Pierre, Distance from stop:253.57564229326258
# Speed: 9.596814941305032
# Duration: 4.0
# Distance: 38.38725976522013
# End Time: 2019-03-26T10:24:37.003000Z
# Finish Point: 286 Fribourg, St-Pierre, Distance from stop:223.39399718759924
#
# EDGE
# Start Time: 2019-03-26T10:24:37.003000Z
# Start Point: 286 Fribourg, St-Pierre, Distance from stop:223.39399718759924
# Speed: 7.906330296920711
# Duration: 4.0
# Distance: 31.625321187682843
# End Time: 2019-03-26T10:24:41.003000Z
# Finish Point: 287 Fribourg, Pertuis, Distance from stop:173.9194857899508
#
# EDGE
# Start Time: 2019-03-26T10:24:41.003000Z
# Start Point: 287 Fribourg, Pertuis, Distance from stop:173.9194857899508
# Speed: 5.412678024266615
# Duration: 4.0
# Distance: 21.65071209706646
# End Time: 2019-03-26T10:24:45.003000Z
# Finish Point: 288 Fribourg, Pertuis, Distance from stop:153.37046235648907
#
# EDGE
# Start Time: 2019-03-26T10:24:45.003000Z
# Start Point: 288 Fribourg, Pertuis, Distance from stop:153.37046235648907
# Speed: 7.248392076291177
# Duration: 4.0
# Distance: 28.993568305164708
# End Time: 2019-03-26T10:24:49.003000Z
# Finish Point: 289 Fribourg, Pertuis, Distance from stop:125.64598413700432
#
# EDGE
# Start Time: 2019-03-26T10:24:49.003000Z
# Start Point: 289 Fribourg, Pertuis, Distance from stop:125.64598413700432
# Speed: 7.783200493168728
# Duration: 4.0
# Distance: 31.132801972674912
# End Time: 2019-03-26T10:24:53.003000Z
# Finish Point: 290 Fribourg, Pertuis, Distance from stop:95.65245106053325
#
# EDGE
# Start Time: 2019-03-26T10:24:53.003000Z
# ...
# Speed: 10.65723669791504
# Duration: 4.0
# Distance: 42.62894679166016
# End Time: 2019-03-26T10:27:25.004000Z
# Finish Point: 316 Fribourg, Eglise-St-Jean, Distance from stop:106.5330790867168
#
# EDGE
# Start Time: 2019-03-26T10:27:25.004000Z
# Start Point: 316 Fribourg, Eglise-St-Jean, Distance from stop:106.5330790867168
# Speed: 9.97084156943875
# Duration: 4.0
# Distance: 39.883366277755
# End Time: 2019-03-26T10:27:29.004000Z
# Finish Point: 317 Fribourg, Planche-Inférieure, Distance from stop:97.53926458974792
#
# EDGE
# Start Time: 2019-03-26T10:27:29.004000Z
# Start Point: 317 Fribourg, Planche-Inférieure, Distance from stop:97.53926458974792
# Speed: 6.766431918152352
# Duration: 3.0
# Distance: 20.299295754457056
# End Time: 2019-03-26T10:27:32.004000Z
# Finish Point: 318 Fribourg, Planche-Inférieure, Distance from stop:84.42145797753878
#
# EDGE
# Start Time: 2019-03-26T10:27:32.004000Z
# Start Point: 318 Fribourg, Planche-Inférieure, Distance from stop:84.42145797753878
# Speed: 4.53004821255698
# Duration: 5.0
# Distance: 22.6502410627849
# End Time: 2019-03-26T10:27:37.004000Z
# Finish Point: 319 Fribourg, Planche-Inférieure, Distance from stop:72.12420808122842
#
# EDGE
# Start Time: 2019-03-26T10:27:37.004000Z
# Start Point: 319 Fribourg, Planche-Inférieure, Distance from stop:72.12420808122842
# Speed: 6.759958708944107
# Duration: 4.0
# Distance: 27.03983483577643
# End Time: 2019-03-26T10:27:41.004000Z
# Finish Point: 320 Fribourg, Planche-Inférieure, Distance from stop:64.46804523101326
#
# EDGE
# Start Time: 2019-03-26T10:27:41.004000Z
# Start Point: 320 Fribourg, Planche-Inférieure, Distance from stop:64.46804523101326
# Speed: 7.755006686301519
# Duration: 4.0
# Distance: 31.020026745206074
# End Time: 2019-03-26T10:27:45.004000Z
# Finish Point: 321 Fribourg, Planche-Inférieure, Distance from stop:70.28889216574706
#
# EDGE
# Start Time: 2019-03-26T10:27:45.004000Z
# Start Point: 321 Fribourg, Planche-Inférieure, Distance from stop:70.28889216574706
# Speed: 5.940565331002748
# Duration: 3.999000072479248
# Distance: 23.756321189247696
# End Time: 2019-03-26T10:27:49.003000Z
# Finish Point: 322 Fribourg, Karrweg, Distance from stop:59.73088045878616
#
# EDGE
# Start Time: 2019-03-26T10:27:49.003000Z
# Start Point: 322 Fribourg, Karrweg, Distance from stop:59.73088045878616
# Speed: 5.304093056254056
# Duration: 5.0
# Distance: 26.52046528127028
# End Time: 2019-03-26T10:27:54.003000Z
# Finish Point: 323 Fribourg, Karrweg, Distance from stop:33.55638511502122
#
# EDGE
# Start Time: 2019-03-26T10:27:54.003000Z
# Start Point: 323 Fribourg, Karrweg, Distance from stop:33.55638511502122
# Speed: 7.555805098479199
# Duration: 4.0
# Distance: 30.223220393916797
# End Time: 2019-03-26T10:27:58.003000Z
# Finish Point: 324 Fribourg, Karrweg, Distance from stop:5.281859221255421
#
# EDGE
# Start Time: 2019-03-26T10:27:58.003000Z
# Start Point: 324 Fribourg, Karrweg, Distance from stop:5.281859221255421
# Speed: 5.37156528885352
# Duration: 4.0
# Distance: 21.48626115541408
# End Time: 2019-03-26T10:28:02.003000Z
# Finish Point: 325 Fribourg, Karrweg, Distance from stop:15.747746052674378
#
# EDGE
# Start Time: 2019-03-26T10:28:02.003000Z
# Start Point: 325 Fribourg, Karrweg, Distance from stop:15.747746052674378
# Speed: 6.150333542323071
# Duration: 4.0
# Distance: 24.601334169292283
# End Time: 2019-03-26T10:28:06.003000Z
# Finish Point: 326 Fribourg, Karrweg, Distance from stop:39.412558692289046
#
# EDGE
# Start Time: 2019-03-26T10:28:06.003000Z
# Start Point: 326 Fribourg, Karrweg, Distance from stop:39.412558692289046
# Speed: 7.365054493232447
# Duration: 3.0
# Distance: 22.09516347969734
# End Time: 2019-03-26T10:28:09.003000Z
# Finish Point: 327 Fribourg, Karrweg, Distance from stop:60.8571722870922
#
# EDGE
# Start Time: 2019-03-26T10:28:09.003000Z
# Start Point: 327 Fribourg, Karrweg, Distance from stop:60.8571722870922
# Speed: 5.417825033646866
# Duration: 4.0
# Distance: 21.671300134587465
# End Time: 2019-03-26T10:28:13.003000Z
# Finish Point: 328 Fribourg, Karrweg, Distance from stop:82.12619487114866
#
# EDGE
# Start Time: 2019-03-26T10:28:13.003000Z
# Start Point: 328 Fribourg, Karrweg, Distance from stop:82.12619487114866
# Speed: 5.161730772411624
# Duration: 7.0
# Distance: 36.13211540688137
# End Time: 2019-03-26T10:28:20.003000Z
# Finish Point: 329 Fribourg, Petit-St-Jean, Distance from stop:64.76647033789796
#
# EDGE
# Start Time: 2019-03-26T10:28:20.003000Z
# Start Point: 329 Fribourg, Petit-St-Jean, Distance from stop:64.76647033789796
# Speed: 4.597142012321888
# Duration: 6.0
# Distance: 27.58285207393133
# End Time: 2019-03-26T10:28:26.003000Z
# Finish Point: 330 Fribourg, Petit-St-Jean, Distance from stop:37.79527306350323
#
# EDGE
# Start Time: 2019-03-26T10:28:26.003000Z
# Start Point: 330 Fribourg, Petit-St-Jean, Distance from stop:37.79527306350323
# Speed: 5.957241331831425
# Duration: 4.0
# Distance: 23.8289653273257
# End Time: 2019-03-26T10:28:30.003000Z
# Finish Point: 331 Fribourg, Petit-St-Jean, Distance from stop:14.524722015470058
#
# EDGE
# Start Time: 2019-03-26T10:28:30.003000Z
# Start Point: 331 Fribourg, Petit-St-Jean, Distance from stop:14.524722015470058
# Speed: 1.3820405438879149
# Duration: 17.0
# Distance: 23.494689246094552
# End Time: 2019-03-26T10:28:47.003000Z
# Finish Point: 332 Fribourg, Petit-St-Jean, Distance from stop:9.12354976494374
#
# ----------------------------------------------------------------------------------------------------SEGMENT
# EDGE
# Start Time: 2019-03-26T10:54:13.465000Z
# Start Point: 383 Fribourg, Neuveville, Distance from stop:7.991357937608585
# Speed: 28.80816100221713
# Duration: 1.9660000801086426
# Distance: 56.63684683814155
# End Time: 2019-03-26T10:54:15.431000Z
# Finish Point: 384 Fribourg, Neuveville, Distance from stop:4.5001956930577744
#
# EDGE
# Start Time: 2019-03-26T10:54:15.431000Z
# Start Point: 384 Fribourg, Neuveville, Distance from stop:4.5001956930577744
# Speed: 0.5359771446274083
# Duration: 26.727999925613403
# Distance: 14.325597081731853
# End Time: 2019-03-26T10:54:42.159000Z
# Finish Point: 385 Fribourg, Neuveville, Distance from stop:15.951091087615604
#
# EDGE
# Start Time: 2019-03-26T10:54:42.159000Z
# Start Point: 385 Fribourg, Neuveville, Distance from stop:15.951091087615604
# Speed: 3.1033989304756213
# Duration: 14.98800015449524
# Distance: 46.513743649428974
# End Time: 2019-03-26T10:54:57.147000Z
# Finish Point: 386 Fribourg, Neuveville, Distance from stop:59.93892719060968
#
# EDGE
# Start Time: 2019-03-26T10:54:57.147000Z
# Start Point: 386 Fribourg, Neuveville, Distance from stop:59.93892719060968
# Speed: 4.386180169247384
# Duration: 65.81399989128113
# Distance: 288.67206118198675
# End Time: 2019-03-26T10:56:02.961000Z
# Finish Point: 387 Fribourg, Pertuis, Distance from stop:139.66843561573367
#
# EDGE
# Start Time: 2019-03-26T10:56:02.961000Z
# Start Point: 387 Fribourg, Pertuis, Distance from stop:139.66843561573367
# Speed: 8.880002596734233
# Duration: 4.013000011444092
# Distance: 35.63545052231804
# End Time: 2019-03-26T10:56:06.974000Z
# Finish Point: 388 Fribourg, Pertuis, Distance from stop:171.26580024705862
#
# EDGE
# Start Time: 2019-03-26T10:56:06.974000Z
# Start Point: 388 Fribourg, Pertuis, Distance from stop:171.26580024705862
# Speed: 17.968317374515987
# Duration: 4.075000047683716
# Distance: 73.22089415794879
# End Time: 2019-03-26T10:56:11.049000Z
# Finish Point: 389 Fribourg, St-Pierre, Distance from stop:239.7775071188408
#
# EDGE
# Start Time: 2019-03-26T10:56:11.049000Z
# Start Point: 389 Fribourg, St-Pierre, Distance from stop:239.7775071188408
# Speed: 10.309090258135274
# Duration: 2.0360000133514404
# Distance: 20.989307903204622
# End Time: 2019-03-26T10:56:13.085000Z
# Finish Point: 390 Fribourg, St-Pierre, Distance from stop:246.86260754663832
#
# EDGE
# Start Time: 2019-03-26T10:56:13.085000Z
# Start Point: 390 Fribourg, St-Pierre, Distance from stop:246.86260754663832
# Speed: 6.772862396669222
# Duration: 5.023000001907349
# Distance: 34.02008783138771
# End Time: 2019-03-26T10:56:18.108000Z
# Finish Point: 391 Fribourg, St-Pierre, Distance from stop:262.09439504423875
#
# EDGE
# Start Time: 2019-03-26T10:56:18.108000Z
# Start Point: 391 Fribourg, St-Pierre, Distance from stop:262.09439504423875
# Speed: 8.499792144518551
# Duration: 3.001999855041504
# Distance: 25.516374785727603
# End Time: 2019-03-26T10:56:21.110000Z
# Finish Point: 392 Fribourg, St-Pierre, Distance from stop:256.24337246757386
#
# EDGE
# Start Time: 2019-03-26T10:56:21.110000Z
# Start Point: 392 Fribourg, St-Pierre, Distance from stop:256.24337246757386
# Speed: 9.109124958457393
# Duration: 4.0
# Distance: 36.43649983382957
# End Time: 2019-03-26T10:56:25.110000Z
# Finish Point: 393 Fribourg, St-Pierre, Distance from stop:251.410917179871
#
# EDGE
# Start Time: 2019-03-26T10:56:25.110000Z
# Start Point: 393 Fribourg, St-Pierre, Distance from stop:251.410917179871
# Speed: 10.876697836114108
# Duration: 3.008000135421753
# Distance: 32.71710856397272
# End Time: 2019-03-26T10:56:28.118000Z
# Finish Point: 394 Fribourg, St-Pierre, Distance from stop:260.39002618954333
#
# EDGE
# Start Time: 2019-03-26T10:56:28.118000Z
# Start Point: 394 Fribourg, St-Pierre, Distance from stop:260.39002618954333
# Speed: 10.27647849626276
# Duration: 4.0320000648498535
# Distance: 41.43476196335957
# End Time: 2019-03-26T10:56:32.150000Z
# Finish Point: 395 Fribourg, Fries, Distance from stop:193.99963505635503
#
# EDGE
# Start Time: 2019-03-26T10:56:32.150000Z
# Start Point: 395 Fribourg, Fries, Distance from stop:193.99963505635503
# Speed: 8.69332430976834
# Duration: 4.003000020980835
# Distance: 34.79937739439587
# End Time: 2019-03-26T10:56:36.153000Z
# Finish Point: 396 Fribourg, Fries, Distance from stop:165.72844831973822
#
# EDGE
# Start Time: 2019-03-26T10:56:36.153000Z
# Start Point: 396 Fribourg, Fries, Distance from stop:165.72844831973822
# Speed: 8.166413181588524
# Duration: 4.005999803543091
# Distance: 32.71464960109534
# End Time: 2019-03-26T10:56:40.159000Z
# Finish Point: 397 Fribourg, Fries, Distance from stop:155.72245925946177
#
# EDGE
# Start Time: 2019-03-26T10:56:40.159000Z
# Start Point: 397 Fribourg, Fries, Distance from stop:155.72245925946177
# Speed: 8.530038511913666
# Duration: 3.996000051498413
# Distance: 34.086034332890456
# End Time: 2019-03-26T10:56:44.155000Z
# Finish Point: 398 Fribourg, Fries, Distance from stop:159.95419745856046
#
# EDGE
# Start Time: 2019-03-26T10:56:44.155000Z
# Start Point: 398 Fribourg, Fries, Distance from stop:159.95419745856046
# Speed: 8.39232195140782
# Duration: 3.995000123977661
# Distance: 33.527327236334685
# End Time: 2019-03-26T10:56:48.150000Z
# Finish Point: 399 Fribourg, gare CFF, Distance from stop:136.37222174897687
#
# EDGE
# Start Time: 2019-03-26T10:56:48.150000Z
# Start Point: 399 Fribourg, gare CFF, Distance from stop:136.37222174897687
# Speed: 1.9776464872587431
# Duration: 16.997999906539917
# Distance: 33.61603480559311
# End Time: 2019-03-26T10:57:05.148000Z
# Finish Point: 400 Fribourg, Fries, Distance from stop:144.88908539947226
#
# EDGE
# Start Time: 2019-03-26T10:57:05.148000Z
# Start Point: 400 Fribourg, Fries, Distance from stop:144.88908539947226
# Speed: 7.158008253024442
# Duration: 2.997999906539917
# Distance: 21.459708073579232
# End Time: 2019-03-26T10:57:08.146000Z
# Finish Point: 401 Fribourg, Fries, Distance from stop:127.81168162658935
#
# EDGE
# Start Time: 2019-03-26T10:57:08.146000Z
# Start Point: 401 Fribourg, Fries, Distance from stop:127.81168162658935
# Speed: 10.039459144868633
# Duration: 3.008000135421753
# Distance: 30.198694467326003
# End Time: 2019-03-26T10:57:11.154000Z
# Finish Point: 402 Fribourg, Fries, Distance from stop:99.6003701196161
#
# EDGE
# Start Time: 2019-03-26T10:57:11.154000Z
# Start Point: 402 Fribourg, Fries, Distance from stop:99.6003701196161
# Speed: 4.404310377615891
# Duration: 5.000999927520752
# Distance: 22.02595587923597
# End Time: 2019-03-26T10:57:16.155000Z
# Finish Point: 403 Fribourg, Fries, Distance from stop:80.80750646355145
#
# EDGE
# Start Time: 2019-03-26T10:57:16.155000Z
# Start Point: 403 Fribourg, Fries, Distance from stop:80.80750646355145
# Speed: 2.566581619281545
# Duration: 9.995000123977661
# Distance: 25.65298360291783
# End Time: 2019-03-26T10:57:26.150000Z
# Finish Point: 404 Fribourg, Fries, Distance from stop:90.06688627355081
#
# EDGE
# Start Time: 2019-03-26T10:57:26.150000Z
# Start Point: 404 Fribourg, Fries, Distance from stop:90.06688627355081
# Speed: 3.950925639072247
# Duration: 6.000999927520752
# Distance: 23.709504473712435
# End Time: 2019-03-26T10:57:32.151000Z
# Finish Point: 405 Fribourg, Fries, Distance from stop:112.77283177436348
#
# EDGE
# Start Time: 2019-03-26T10:57:32.151000Z
# Start Point: 405 Fribourg, Fries, Distance from stop:112.77283177436348
# Speed: 7.6391506259452235
# Duration: 3.0
# Distance: 22.91745187783567
# End Time: 2019-03-26T10:57:35.151000Z
# Finish Point: 406 Fribourg, Fries, Distance from stop:134.9208834915306
#
# EDGE
# Start Time: 2019-03-26T10:57:35.151000Z
# Start Point: 406 Fribourg, Fries, Distance from stop:134.9208834915306
# Speed: 6.808264752741972
# Duration: 3.002000093460083
# Distance: 20.438411424032388
# End Time: 2019-03-26T10:57:38.153000Z
# Finish Point: 407 Fribourg, gare CFF, Distance from stop:118.10040964653261
#
# EDGE
# Start Time: 2019-03-26T10:57:38.153000Z
# Start Point: 407 Fribourg, gare CFF, Distance from stop:118.10040964653261
# Speed: 11.145983779420327
# Duration: 2.0
# Distance: 22.291967558840653
# End Time: 2019-03-26T10:57:40.153000Z
# Finish Point: 408 Fribourg, gare CFF, Distance from stop:95.8313230740912
#
# EDGE
# Start Time: 2019-03-26T10:57:40.153000Z
# Start Point: 408 Fribourg, gare CFF, Distance from stop:95.8313230740912
# Speed: 3.951310662827351
# Duration: 5.996999979019165
# Distance: 23.696009962073827
# End Time: 2019-03-26T10:57:46.150000Z
# Finish Point: 409 Fribourg, gare CFF, Distance from stop:74.38598051095072
#
# EDGE
# Start Time: 2019-03-26T10:57:46.150000Z
# Start Point: 409 Fribourg, gare CFF, Distance from stop:74.38598051095072
# Speed: 2.5969411985102715
# Duration: 8.003999948501587
# Distance: 20.78591721913786
# End Time: 2019-03-26T10:57:54.154000Z
# Finish Point: 410 Fribourg, gare CFF, Distance from stop:65.53702806364397
#
# EDGE
# Start Time: 2019-03-26T10:57:54.154000Z
# Start Point: 410 Fribourg, gare CFF, Distance from stop:65.53702806364397
# Speed: 5.303303932314798
# Duration: 3.999000072479248
# Distance: 21.20791280970636
# End Time: 2019-03-26T10:57:58.153000Z
# Finish Point: 411 Fribourg, gare CFF, Distance from stop:68.7278159169036
#
# EDGE
# Start Time: 2019-03-26T10:57:58.153000Z
# Start Point: 411 Fribourg, gare CFF, Distance from stop:68.7278159169036
# Speed: 6.049721210443008
# Duration: 5.996999979019165
# Distance: 36.280177972098514
# End Time: 2019-03-26T10:58:04.150000Z
# Finish Point: 412 Fribourg, gare CFF, Distance from stop:63.28334725276673
#
# EDGE
# Start Time: 2019-03-26T10:58:04.150000Z
# Start Point: 412 Fribourg, gare CFF, Distance from stop:63.28334725276673
# Speed: 0.994726152939098
# Duration: 26.9689998626709
# Distance: 26.826769482009688
# End Time: 2019-03-26T10:58:31.119000Z
# Finish Point: 413 Fribourg, gare CFF, Distance from stop:38.63346315836265
#
# EDGE
# Start Time: 2019-03-26T10:58:31.119000Z
# Start Point: 413 Fribourg, gare CFF, Distance from stop:38.63346315836265
# Speed: 8.45922864256911
# Duration: 3.993000030517578
# Distance: 33.77770022793363
# End Time: 2019-03-26T10:58:35.112000Z
# Finish Point: 414 Fribourg, gare CFF, Distance from stop:60.65004625694339
#
# EDGE
# Start Time: 2019-03-26T10:58:35.112000Z
# Start Point: 414 Fribourg, gare CFF, Distance from stop:60.65004625694339
# Speed: 1.0274420288450357
# Duration: 11.036999940872192
# Distance: 11.339877611612264
# End Time: 2019-03-26T10:58:46.149000Z
# Finish Point: 415 Fribourg, gare CFF, Distance from stop:50.37169933891903
#
# EDGE
# Start Time: 2019-03-26T10:58:46.149000Z
# Start Point: 415 Fribourg, gare CFF, Distance from stop:50.37169933891903
# Speed: 2.265791303596617
# Duration: 4.993000030517578
# Distance: 11.31309604800437
# End Time: 2019-03-26T10:58:51.142000Z
# Finish Point: 416 Fribourg, gare CFF, Distance from stop:42.29154947638536
#
# EDGE
# Start Time: 2019-03-26T10:58:51.142000Z
# Start Point: 416 Fribourg, gare CFF, Distance from stop:42.29154947638536
# Speed: 2.1608612871714747
# Duration: 5.006999969482422
# Distance: 10.81943239892332
# End Time: 2019-03-26T10:58:56.149000Z
# Finish Point: 417 Fribourg, gare CFF, Distance from stop:37.74631045908596

# %% [markdown]
# # Map plot

# %%
def edge_to_point_id(df, walk_segs, non_walk_segs):
    if len(non_walk_segs)==0:
        return [list(range(0, df.shape[0]+1))], None
    
    if len(walk_segs)==0:
        return None, [list(range(0, df.shape[0]+1))]
    
    # Generate gps point indices from edge indices
    non_walk_points = []
    for nws in non_walk_segs:
        # Non-walk segments' extremeties are inclusive
        nwp = list(set(df.loc[nws][['index_s', 'index_f']].values.reshape(-1)))
        nwp.sort()
        non_walk_points.append(nwp)
        
    walk_points = []
    # Every point between two non-walk segments is a walk point
    for segs in zip(non_walk_points[:-1], non_walk_points[1:]):
        # Walk segments' extremeties are exclusive
        walk_points.append(list(range(segs[0][-1]+1, segs[1][0])))
                
    # If trip starts with walk segment, generate those initial gps point ids
    if non_walk_points[0][0] != 0:
        # In this case the first point is included
        walk_points = list(range(0, non_walk_points[0][0])) + walk_points

    # If trip ends with walk segment, generate those ending gps point ids
    trip_max_id = df.index_f.max()
    if non_walk_points[-1][-1] != trip_max_id:
        # In this case the last point is included
        walk_points.append(list(range(non_walk_points[-1][-1]+1, trip_max_id+1)))
        
    return walk_points, non_walk_points

# %%
walk_points, non_walk_points = edge_to_point_id(edge_df, walk_segments, non_walk_segments)

# %%
latlon = user_gps_df.join(edge_df[['is_walk']])

locationOfFribourg = [46.805498, 7.142255]
mapFribourg = folium.Map(location=locationOfFribourg, zoom_start=15)

for i, coord in latlon.iterrows():
    if coord.is_walk:
        color = 'green'
    else:
        color = 'red'
    #mapFribourg.add_child(folium.Marker(location=[coord.latitude, coord.longitude], popup=i, icon=folium.Icon(color=color)))
    mapFribourg.add_child(folium.CircleMarker(location=[coord.latitude, coord.longitude], popup=i, radius=3, color=color))
    
plot_segments = list(zip(non_walk_points, walk_points+[None]))
plot_segments = [x for a in plot_segments for x in a if x!=None]

for s in plot_segments:
    points = user_gps_df.loc[s][['latitude', 'longitude']].values
    
    if s in walk_points:
        color="green"
    else:
        color="red"
        
    folium.PolyLine(points, color=color, weight=2.5, opacity=1).add_to(mapFribourg)

mapFribourg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Transport Public Fribourgeois - OpenStreetMap Data

# %%
with open('fribourg_routes.geojson') as f:
    data = json.load(f)

# %%
# taken from OSM documentation
transport_types = ["train", "subway", "monorail", "tram", "light_rail", "bus", "trolleybus", "railway"]

# %%
# Does not contain bus line 8, verified on http://www.xn--pnvkarte-m4a.de/?lat=46.8&lon=7.15&zoom=10#7.1501;46.801;14
fribourg_routes = dict()
i=0
for route in data['features']:
    route_dict = dict()
    
    if route['geometry']['type'] != 'Point' \
    and route['properties']['route'] in transport_types \
    and route['properties'].get('network') != 'Flixbus':
        
        route_dict['name'] = route['properties'].get('name')
        route_dict['description'] = route['properties'].get('description')
        route_dict['network'] = route['properties'].get('network')
        route_dict['operator'] = route['properties'].get('operator')
        route_dict['ref'] = route['properties'].get('ref')
        route_dict['type'] = route['properties'].get('route')
        route_dict['line'] = route['geometry']['coordinates']
        
        fribourg_routes[i] = route_dict
        i += 1

# %%
latlon = [x for a in fribourg_routes.get(21).get('line')[-34:] for x in a]
#latlon = fribourg_routes.get(21).get('line')[-1]

locationOfFribourg = [46.805498, 7.142255]
mapFribourg = folium.Map(location=locationOfFribourg, zoom_start=15)

for coord in latlon:
    mapFribourg.add_child(folium.Marker(location=[coord[1], coord[0]]))

mapFribourg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
labeled_points = []
for r in fribourg_routes:
    coordinates = fribourg_routes.get(r).get('line')
    if type(coordinates[0][0]) == list:
        labeled_points.append([x+[r] for a in coordinates for x in a])
    else:
        labeled_points.append([x+[r] for x in coordinates])

# %%
labeled_points = np.array([np.array(x) for a in labeled_points for x in a])

# %%
fbg_tree = scipy.spatial.KDTree(labeled_points[:, :2])

# %%
def get_closest_pt_lines(tree, segments, user_gps, labeled_points, lat=True, lon=True, dist_threshold=70):

    possible_transports = []
    path_id = 0
    
    # Each degree of the radius line of the earth corresponds to 111,139 meters
    dist_threshold = dist_threshold / 111139

    for path in segments:

        closest_points = tree.query_ball_point(user_gps.loc[path, ['longitude', 'latitude']].values, dist_threshold)

        if len([x for a in closest_points for x in a])==0:
            return None

        path_length = len(path)

        for i in range(path_length):
            for p in closest_points[i]:
                gps_id = path[i]

                user_lat, user_lon = user_gps.loc[gps_id].latitude, user_gps.loc[gps_id].longitude

                close_point_lat, close_point_lon = labeled_points[p][1], labeled_points[p][0]
                
                if lat and lon:
                    dist = calc_dist(user_lat, user_lon, close_point_lat, close_point_lon)
                elif lat:
                    dist = calc_dist(user_lat, close_point_lon, close_point_lat, close_point_lon)
                elif lon:
                    dist = calc_dist(close_point_lat, user_lon, close_point_lat, close_point_lon)
                else:
                    raise ValueError('Need to use at least one of latitude/longitude')
                    
                possible_transports.append([path_id, gps_id, labeled_points[p][-1], dist])

        path_id += 1
        
    pt_overlap = pd.DataFrame(possible_transports, columns=['path_id', 'gps_id', 'transport_id', 'dist'])
    pt_overlap = pt_overlap.sort_values(['path_id', 'gps_id', 'transport_id', 'dist'])
    pt_overlap = pt_overlap.groupby(['path_id', 'gps_id', 'transport_id'], as_index=False).agg({'dist': 'min'})
    
    return pt_overlap

# %%
def score_lines(overlap, nw_points, threshold=0.65, discount_factor=0.99, route_dict=fribourg_routes):
    closest_points = dict(overlap.groupby('gps_id', as_index=False).agg({'dist': 'min'}).values)
    path_lengths = dict(zip(range(len(nw_points)), [len(x) for x in nw_points]))
    
    overlap['score'] = overlap\
    .apply(lambda x: discount_factor**((x.dist - closest_points[x.gps_id])/closest_points[x.gps_id]), axis=1)
    
    overlap = overlap.groupby(['path_id', 'transport_id'], as_index=False)\
    .agg({'score': 'prod', 'gps_id': ['count', 'first', 'last']})

    overlap.columns = ['path_id', 'transport_id', 'score', 'overlap', 'first_point_id', 'last_point_id']

    overlap['overlap'] = overlap.apply(lambda x: x.overlap / path_lengths[x.path_id], axis=1)
    
    overlap['score'] = overlap['score'] * overlap['overlap']
    overlap = overlap.drop(columns=['overlap'])
    overlap = overlap[overlap.score>threshold]
    
    overlap = overlap.sort_values(['path_id', 'score'], ascending=[True, False]).reset_index(drop=True)
    
    overlap['ref'] = overlap.apply(lambda x: route_dict[x.transport_id].get('ref'), axis=1)
    
    return overlap

# %% [markdown]
# # GTFS - Timetable data

# %%
travel_day = datetime(2019,3,26)

# %%
fribourg_sbb['arrival_timestamp'] = fribourg_sbb['arrival_time'].apply(lambda x: timezone.localize(travel_day + timedelta(hours=int(x[:2]), minutes=int(x[3:5]), seconds=int(x[6:]))).timestamp())
fribourg_sbb['departure_timestamp'] = fribourg_sbb['departure_time'].apply(lambda x: timezone.localize(travel_day + timedelta(hours=int(x[:2]), minutes=int(x[3:5]), seconds=int(x[6:]))).timestamp())

# %%
def check_direction(trip_id, source_stop_ID, min_start_dist, seg_start_id, seg_end_id, route_name, trips):

    trip = trips[trips.trip_id==trip_id].copy()
    
    segment_end_coords = user_gps_df.loc[seg_end_id][['latitude', 'longitude']].values
    
    dist2end = []
    
    for stop in trip.itertuples():
            dist2end.append(calc_dist(stop[14], stop[15], segment_end_coords[0], segment_end_coords[1]))
            
    trip['dist2end'] = dist2end
    min_end_dist = trip.dist2end.min()
    
    destination_stop_ID = trip[trip.dist2end==min_end_dist].stop_sequence.values[0]
    
    start = [trip_id, source_stop_ID, seg_start_id, min_start_dist, True]
    end = [trip_id, destination_stop_ID, seg_end_id, min_end_dist, False]
    
    if destination_stop_ID > source_stop_ID:
        return [start, end]
    else:
        return None

# %%
def gen_candidates(scores_df, user_df, transport_df, lat=True, lon=True):
    candidates = []

    for tup in scores_df.itertuples():

        start_time = user_df.loc[tup[4]].timestamp_unix
        
        # filter to trips that could be up to 15 minutes late or up to 5 minutes early
        trip_ids = transport_df[(transport_df.departure_timestamp>start_time-900)
                                &(transport_df.departure_timestamp<start_time+300)].trip_id.unique()
        
        line_trips = transport_df[(transport_df.route_short_name==tup[6])&(transport_df.trip_id.isin(trip_ids))].copy()
        
        if lat and lon:
            start_loc = user_df.loc[tup[4]][['latitude', 'longitude']].values
            distances = [calc_dist(start_loc[0], start_loc[1], x[14], x[15]) for x in line_trips.itertuples()]
        elif lat:
            start_loc = user_df.loc[tup[4]][['latitude']].values
            distances = [calc_dist(start_loc[0], x[15], x[14], x[15]) for x in line_trips.itertuples()]
        elif lon:
            start_loc = user_df.loc[tup[4]][['longitude']].values
            distances = [calc_dist(x[14], start_loc[0], x[14], x[15]) for x in line_trips.itertuples()]
        else:
            raise ValueError('Need to use at least one of latitude/longitude')

        line_trips['dist2start'] = distances

        line_trips = line_trips.sort_values(['trip_id', 'dist2start'])

        candidate_line_trips = line_trips.groupby('trip_id', as_index=False).agg({'stop_sequence':'first', 
                                                                                  'departure_timestamp':'first',
                                                                                  'dist2start': 'first'})

        candidate_line_trips = candidate_line_trips[(candidate_line_trips.departure_timestamp>start_time-900)
                                                    &(candidate_line_trips.departure_timestamp<start_time+300)]

        candidate_line_trips = candidate_line_trips[['trip_id', 'stop_sequence', 'dist2start']].values

        direction = [check_direction(x[0], x[1], x[2], tup[4], tup[5], tup[6], line_trips) for x in candidate_line_trips]

        candidate_line_trips = [x for a in direction if a !=None for x in a]
        candidate_line_trips = [np.append(x, tup[1]) for x in candidate_line_trips]

        candidates = candidates + candidate_line_trips
        
    candidates_df = pd.DataFrame(candidates, columns=['trip_id', 'stop_sequence', 'gps_id', 'dist_to_stop', 'is_start', 'path_id'])
    candidates_df = candidates_df.astype(dtype={'stop_sequence': int, 'dist_to_stop': float})
    candidates_df = pd.merge(fribourg_sbb, candidates_df, on=['trip_id', 'stop_sequence'])
    candidates_df = candidates_df.sort_values(['path_id', 'trip_id', 'arrival_timestamp', 'stop_sequence'])
    candidates_df = candidates_df.reset_index(drop=True)
    
    return candidates_df

# %%
def top_candidates(candidates_df, user_df):
    candidates_df = candidates_df.copy()
    time_diffs = []
    for tup in candidates_df.itertuples():
        if tup[-2]:
            time_diffs.append(abs(tup[-5]-user_df.loc[int(tup[-4])].timestamp_unix))
        else:
            time_diffs.append(abs(tup[-6]-user_df.loc[int(tup[-4])].timestamp_unix))
            
    candidates_df['time_diff'] = time_diffs
    
    candidates_df = candidates_df.groupby(['path_id', 'route_short_name', 'trip_id'], as_index=False)\
    .agg({'time_diff': 'mean', 'dist_to_stop': 'mean'})
    
    candidates_df = candidates_df.round(2)
    
    candidates_df = candidates_df.sort_values(['path_id', 'dist_to_stop', 'time_diff'])
    
    candidates_df = candidates_df.groupby(['path_id', 'route_short_name'], as_index=False)\
    .agg({'time_diff': 'first', 'dist_to_stop': 'first'})
    
    return candidates_df

# %% [markdown]
# # Transport Public Fribourgeois - Live Data

# %%
import os
from datetime import timedelta

# %%
def read_tpc(path, date=None):
    filenames = os.listdir(path)
    
    if date is not None:
        filenames = [x for x in filenames if date in x]
    
    files = []
    for f in filenames:
        try:
            files.append(pd.read_csv(path+f, sep=';'))
        except:
            print("Empty file: ", f)
            continue

    return pd.concat(files)

# %%
date = datetime.fromtimestamp(user_gps_df.iloc[0].timestamp_unix).strftime("%Y-%m-%d")
print(date)
# Out:
# 2019-03-26

# %%
citylines_df = read_tpc('./TPF/CityLine_2019-03/', '2019-03-26')
regionallines_df = read_tpc('./TPF/RegionalLine 2019-03/', '2019-03-26')
# Out:
# Empty file:  2019-03-26_1002_1.plc

# %%
lines_df = pd.concat([citylines_df, regionallines_df])

# %%
tpf_df = lines_df[['Vehicle', 'Day', 'Arrival', 'Departure', 'Latitude', 'Longitude', 'Line', 
                   'Journey', 'Block', 'JourneySeq', 'Stop', 'StopName', 'StopSeq']].copy()

# %%
tpf_df['Day'] = tpf_df['Day'].apply(lambda x: timezone.localize(datetime.strptime(x, "%Y-%m-%d")))

# %%
actual_arrivals = []
actual_arrival_timestamps = []
actual_departures = []
actual_departure_timestamps = []

for tup in tpf_df.itertuples():
    actual_arrival = tup[2] + timedelta(hours=int(tup[3][:2]), minutes=int(tup[3][3:5]), seconds=int(tup[3][6:8]))
    actual_arrivals.append(actual_arrival)
    actual_arrival_timestamps.append(actual_arrival.timestamp())
    
    actual_departure = tup[2] + timedelta(hours=int(tup[4][:2]), minutes=int(tup[4][3:5]), seconds=int(tup[4][6:8]))
    actual_departures.append(actual_departure)
    actual_departure_timestamps.append(actual_departure.timestamp())
    
tpf_df.loc[: ,'actual_arrival'] = actual_arrivals
tpf_df.loc[: ,'actual_departure'] = actual_departures

tpf_df.loc[:, 'arrival_timestamp'] = actual_arrival_timestamps
tpf_df.loc[:, 'departure_timestamp'] = actual_departure_timestamps

# %%
stop_dict = tpf_df[~tpf_df.Stop.isnull()][['Stop', 'Latitude', 'Longitude']]
stop_dict = stop_dict.groupby('Stop').agg({'Latitude': 'mean', 'Longitude': 'mean'})
stop_dict = stop_dict.to_dict('index')

# %%
tpf_df.loc[(tpf_df.Latitude.isnull())&(~tpf_df.Stop.isnull()), 'Latitude'] = tpf_df[(tpf_df.Latitude.isnull())&(~tpf_df.Stop.isnull())].apply(lambda x: stop_dict.get(x.Stop)['Latitude'], axis=1)
tpf_df.loc[(tpf_df.Longitude.isnull())&(~tpf_df.Stop.isnull()), 'Longitude'] = tpf_df[(tpf_df.Longitude.isnull())&(~tpf_df.Stop.isnull())].apply(lambda x: stop_dict.get(x.Stop)['Longitude'], axis=1)
tpf_df = tpf_df[(~tpf_df.Latitude.isnull())&(~tpf_df.Longitude.isnull())]

# %%
def dtw(s, t, window):
    n, m = len(s), len(t)
    w = np.max([window, abs(n-m)])
    dtw_matrix = np.zeros((n+1, m+1))
    
    for i in range(n+1):
        for j in range(m+1):
            dtw_matrix[i, j] = np.inf
    dtw_matrix[0, 0] = 0
    
    for i in range(1, n+1):
        for j in range(np.max([1, i-w]), np.min([m, i+w])+1):
            dtw_matrix[i, j] = 0
    
    for i in range(1, n+1):
        for j in range(np.max([1, i-w]), np.min([m, i+w])+1):
            cost = abs(s[i-1] - t[j-1])
            # take last min from a square box
            last_min = np.min([dtw_matrix[i-1, j], dtw_matrix[i, j-1], dtw_matrix[i-1, j-1]])
            dtw_matrix[i, j] = sum(cost) + last_min
    return dtw_matrix[-1][-1]

# %%
def get_top_scorers(nw_points, transport_df, user_df, max_dist=0.2, threshold=1.25, lat=True, lon=True):
    first = []
    top = []
    for s in nw_points:
        # filter the day's gps data to time window of non walk segment with 30s buffer on each end
        candidates = transport_df[(transport_df.departure_timestamp>user_df.loc[s[0]].timestamp_unix-30)
                                  &(transport_df.arrival_timestamp<user_df.loc[s[-1]].timestamp_unix+30)]

        candidate_vehicles = candidates.Vehicle.unique()
        
        # use specified information
        if lat and lon:
            user_coords = user_df.loc[s][['latitude', 'longitude']].values
        elif lat:
            user_coords = user_df.loc[s][['latitude']].values
        elif lon:
            user_coords = user_df.loc[s][['longitude']].values
        else:
            raise ValueError('Need to make use of at least one of latitude or longitude')
        
        scores = []
        lines = []
        vehicles = []
        
        # for each vehicle in time window compute distance using dynamic time warping
        for v in candidate_vehicles:

            bus = candidates[(candidates.Vehicle==v)]
            line = bus[~bus.Line.isnull()].Line.unique()
            
            # if vehicle covers multiple lines in time window or there is only one GPS point for it, skip vehicle
            if len(line) != 1 or len(bus)==1:
                continue
            
            # use specified information
            if lat and lon:
                bus_coords = bus[['Latitude', 'Longitude']].values
            elif lat:
                bus_coords = bus[['Latitude']].values
            elif lon:
                bus_coords = bus[['Longitude']].values
            
            # compute distance
            score = dtw(user_coords, bus_coords, 2)

            lines.append(line[0])
            scores.append(score)
            vehicles.append(v)

        min_score = min(scores)
        
        # collect results for those vehicles having a distance of less than max_dist with user segment
        # additionally discard vehicles having a score significantly worse than the best
        first.append([x for x in list(zip(vehicles, scores, lines)) if x[1]==min_score][0]) 
        top.append([x for x in list(zip(vehicles, scores, lines)) if x[1]<max_dist and x[1] < threshold*min_score])
        
    return first, top

# %% [markdown]
# # Testing

# %% [markdown]
# ### OSM

# %%
overlap_lat_lon_df = get_closest_pt_lines(fbg_tree, non_walk_points, user_gps_df, labeled_points)
overlap_lat_df = get_closest_pt_lines(fbg_tree, non_walk_points, user_gps_df, labeled_points, 
                                      lon=False, dist_threshold=50)
overlap_lon_df = get_closest_pt_lines(fbg_tree, non_walk_points, user_gps_df, labeled_points, 
                                      lat=False, dist_threshold=50)

# %%
overlap_lat_lon_scores_df = score_lines(overlap_lat_lon_df, non_walk_points)
overlap_lat_scores_df = score_lines(overlap_lat_df, non_walk_points, discount_factor=1, threshold=0.5)
overlap_lon_scores_df = score_lines(overlap_lon_df, non_walk_points, discount_factor=1, threshold=0.5)

# %%
overlap_lat_lon_scores_df
# Out:
#     path_id  transport_id     score  first_point_id  last_point_id  ref
# 0         0          17.0  1.000000               0              8    2
# 1         0          21.0  1.000000               0              8  338
# 2         0          25.0  1.000000               0              8  340
# 3         0          29.0  1.000000               0              8  339
# 4         1           1.0  0.981308              86            192    5
# 5         2           1.0  1.000000             198            220    5
# 6         2          17.0  1.000000             198            220    2
# 7         2          22.0  1.000000             198            220    3
# 8         2          23.0  1.000000             198            220    1
# 9         2          27.0  1.000000             198            220    6
# 10        3           1.0  1.000000             266            273    5
# 11        3          22.0  0.987564             266            273    3
# 12        4          16.0  0.896995             279            332    4
# 13        5          16.0  0.825863             383            417    4

# %%
overlap_lon_scores_df
# Out:
#     path_id  transport_id     score  first_point_id  last_point_id  ref
# 0         0          17.0  1.000000               0              8    2
# 1         0          21.0  1.000000               0              8  338
# 2         0          25.0  1.000000               0              8  340
# 3         0          29.0  1.000000               0              8  339
# 4         1           1.0  0.953271              86            192    5
# 5         2           1.0  1.000000             198            220    5
# 6         2          17.0  1.000000             198            220    2
# 7         2          22.0  1.000000             198            220    3
# 8         2          23.0  1.000000             198            220    1
# 9         2          27.0  1.000000             198            220    6
# 10        2           2.0  0.695652             205            220  125
# 11        2           6.0  0.695652             205            220  123
# 12        2           7.0  0.695652             205            220  127
# 13        2           8.0  0.695652             205            220  181
# 14        3           1.0  1.000000             266            273    5
# 15        3          22.0  1.000000             266            273    3
# 16        4          16.0  0.907407             279            332    4
# 17        5          16.0  0.885714             383            417    4

# %% [markdown]
# ### Timetable

# %%
candidates_lat_lon_df = gen_candidates(overlap_lat_lon_scores_df, user_gps_df, fribourg_sbb)
candidates_lat_df = gen_candidates(overlap_lat_scores_df, user_gps_df, fribourg_sbb, lon=False)
candidates_lon_df = gen_candidates(overlap_lon_scores_df, user_gps_df, fribourg_sbb, lat=False)

# %%
top_candidates_lat_lon_df = top_candidates(candidates_lat_lon_df, user_gps_df)
top_candidates_lat_df = top_candidates(candidates_lat_df, user_gps_df)
top_candidates_lon_df = top_candidates(candidates_lon_df, user_gps_df)

# %%
top_candidates_lat_lon_df
# Out:
#    path_id route_short_name  time_diff  dist_to_stop
# 0        0                2      37.50         92.40
# 1        1                5      29.00         33.09
# 2        2                1     146.00         23.14
# 3        2                2      26.00         23.14
# 4        2                3     266.00         23.14
# 5        2                5     154.00         23.14
# 6        2                6     154.00         23.14
# 7        3                3      54.50         10.87
# 8        3                5      54.50         10.87
# 9        4                4     136.50         98.32
# 10       5                4      68.66         76.83

# %%
top_candidates_lat_df
# Out:
#    path_id route_short_name  time_diff  dist_to_stop
# 0        0                2       37.5         84.66
# 1        0              340      560.5       1639.42
# 2        1                5      269.0         30.37
# 3        2                1      146.0         20.45
# 4        2                2       26.0         20.45
# 5        2                3      266.0         20.45
# 6        2                5      154.0         20.45
# 7        2                6      154.0         20.45
# 8        3                3       54.5         10.53
# 9        3                5       54.5         10.53
# 10       4                4      630.5         13.47

# %%
top_candidates_lon_df
# Out:
#    path_id route_short_name  time_diff  dist_to_stop
# 0        0                2      37.50         91.62
# 1        1                5      29.00         33.05
# 2        2                1     146.00         21.88
# 3        2                2      26.00         21.88
# 4        2                3     266.00         21.88
# 5        2                5     154.00         21.88
# 6        2                6     154.00         21.88
# 7        3                3     725.50          9.40
# 8        3                5      54.50          9.78
# 9        4                4     136.50         73.50
# 10       5                4      68.66         72.98

# %% [markdown]
# ### Bus GPS

# %%
first_lat_lon, top_lat_lon = get_top_scorers(non_walk_points, tpf_df, user_gps_df)
first_lat, top_lat = get_top_scorers(non_walk_points, tpf_df, user_gps_df, lon=False)
first_lon, top_lon = get_top_scorers(non_walk_points, tpf_df, user_gps_df, lat=False)

# %%
first_lat_lon
# Out:
# [(523, 0.045611639999983744, 2.0),
#  (557, 0.12298649999999434, 5.0),
#  (513, 0.026181810000018402, 2.0),
#  (590, 0.03828858999998097, 5.0),
#  (354, 0.07024600999997421, 4.0),
#  (352, 0.08015671000003977, 4.0)]

# %%
first_lat
# Out:
# [(152, 0.008447480000000951, 9.0),
#  (557, 0.04131083999999419, 5.0),
#  (513, 0.005876129999975888, 2.0),
#  (561, 0.009034050000011007, 6.0),
#  (354, 0.01980236444445893, 4.0),
#  (562, 0.016072079999993605, 6.0)]

# %%
first_lon
# Out:
# [(108, 0.02638009000000263, 9.0),
#  (557, 0.06342796000000916, 5.0),
#  (530, 0.01383340000000377, 3.0),
#  (530, 0.007549339999999738, 3.0),
#  (354, 0.04511093888888684, 4.0),
#  (558, 0.025735729999997403, 1.0)]

# %% [markdown]
# ### GPS Noise

# %%
def blur_location(lat, lon, radius_m, fixed=True):
    original_point = geopy.Point(lat, lon)
    
    if not fixed:
        radius_m = random.uniform(0, radius_m)
        
    angle = random.uniform(0, 360)
    distance_vec = distance(meters=radius_m)

    new_point = distance_vec.destination(original_point, angle)
    
    return new_point.latitude, new_point.longitude

# %%
blurred_user_gps_df = user_gps_df.copy()

blurred_coords = []
for tup in blurred_user_gps_df.itertuples():
    blurred_coords.append(blur_location(tup[3], tup[4], radius_m=100, fixed=True))
    
blurred_user_gps_df[['latitude', 'longitude']] = blurred_coords

# %%
# GPS
first_blurred, top_blurred = get_top_scorers(non_walk_points, tpf_df, blurred_user_gps_df)
first_blurred
# Out:
# [(523, 0.05188740273533465, 2.0),
#  (557, 0.18630421121611107, 5.0),
#  (513, 0.038094349817748174, 2.0),
#  (590, 0.04413520036877383, 5.0),
#  (354, 0.09840392828920574, 4.0),
#  (554, 0.09065729058839711, 5.0)]

# %%
# OSM
overlap_blur_df = get_closest_pt_lines(fbg_tree, non_walk_points, blurred_user_gps_df, labeled_points, 
                                       dist_threshold=100)

overlap_blur_scores_df = score_lines(overlap_blur_df, non_walk_points, threshold=0.5)

overlap_blur_scores_df
# Out:
#     path_id  transport_id     score  first_point_id  last_point_id  ref
# 0         0          17.0  1.000000               0              8    2
# 1         0          21.0  1.000000               0              8  338
# 2         0          25.0  1.000000               0              8  340
# 3         0          29.0  1.000000               0              8  339
# 4         2          22.0  0.677585             198            220    3
# 5         2          23.0  0.657150             198            220    1
# 6         2           1.0  0.591366             200            220    5
# 7         2          17.0  0.571762             200            220    2
# 8         2          27.0  0.571762             200            220    6
# 9         2           8.0  0.571000             200            220  181
# 10        2           2.0  0.535475             200            220  125
# 11        2           6.0  0.535475             200            220  123
# 12        2           7.0  0.535475             200            220  127
# 13        3           1.0  0.753391             266            273    5
# 14        3          22.0  0.722990             266            273    3
# 15        4          16.0  0.688126             279            331    4
# 16        5          16.0  0.625935             383            417    4

# %%
# Timetable
candidates_blur_df = gen_candidates(overlap_blur_scores_df, blurred_user_gps_df, fribourg_sbb)

top_candidates_blur_df = top_candidates(candidates_blur_df, blurred_user_gps_df)

top_candidates_blur_df
# Out:
#   path_id route_short_name  time_diff  dist_to_stop
# 0       0                2      37.50        130.42
# 1       2                1     146.00         71.49
# 2       2                2      18.50         72.44
# 3       2                3     266.00         71.49
# 4       2                5     161.50         72.44
# 5       2                6     161.50         72.44
# 6       3                3      54.50         60.64
# 7       3                5      54.50         60.64
# 8       4                4     128.00        150.41
# 9       5                4      68.66        126.76

# %% [markdown]
# ### Time split

# %%
splits = 10
total_rows = user_gps_df.shape[0]
frag_size = round(total_rows/splits)
res_df = None

start_index = 0

for s in range(splits):
    frag_user_gps_df = user_gps_df.iloc[start_index:start_index+frag_size].reset_index(drop=True)
    start_index += frag_size
    
    frag_edge_df = points_to_edges(frag_user_gps_df)
    frag_edge_df, frag_walk_points, frag_non_walk_points = generate_segment_ids(frag_edge_df)
    frag_walk_points, frag_non_walk_points = edge_to_point_id(frag_edge_df, frag_walk_points, frag_non_walk_points)
    
    if frag_non_walk_points is None:
        continue
        
    overlap_frag_df = get_closest_pt_lines(fbg_tree, frag_non_walk_points, frag_user_gps_df, labeled_points, 
                                          dist_threshold=70)

    overlap_frag_scores_df = score_lines(overlap_frag_df, frag_non_walk_points, threshold=0.65)
    candidates_frag_df = gen_candidates(overlap_frag_scores_df, frag_user_gps_df, fribourg_sbb)
    top_candidates_frag_df = top_candidates(candidates_frag_df, frag_user_gps_df)
    
    top_candidates_frag_df['frag_id'] = s
    
    if res_df is None:
        res_df = top_candidates_frag_df
    else:
        res_df = pd.concat([res_df, top_candidates_frag_df])
